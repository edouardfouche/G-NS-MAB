# %%
import math

import matplotlib as mpl
mpl.rcParams['text.usetex'] = True 
mpl.rcParams['text.latex.preamble'] = [r'\usepackage{libertine}', r'\usepackage{newtxmath}'] 
mpl.rc('font', family='serif')

import numpy as np
import pandas as pd
import seaborn as sns


import matplotlib.pyplot as plt
from matplotlib import rc

from cycler import cycler


mpl.rcParams['ps.usedistiller'] = 'xpdf' 

plt.style.use('seaborn-notebook')
# sns.set_palette("Blues_r")

plt.rcParams['axes.titlesize'] = '25'
plt.rcParams['axes.labelsize'] = '25'
plt.rcParams['legend.fontsize'] = '15'
plt.rcParams['xtick.labelsize'] = '15'
plt.rcParams['ytick.labelsize'] = '15'

monochrome=(cycler('color', sns.color_palette("husl", 8))*2+(cycler('marker', ['v', 's', "o"])*7)[0:16])
plt.rc('axes', prop_cycle=monochrome)

pd.options.display.max_rows = 999
# Out:
# <ipython-input-1-56d1c1821bb1>:5: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   mpl.rcParams['text.latex.preamble'] = [r'\usepackage{libertine}', r'\usepackage{newtxmath}']

# %%
# Change if required
folder = "../experiments/2021-06-09-15-16_BanditStatic_"
dataset = "Static"

# %%
masterdata = pd.read_csv("%s/BanditStatic.csv"%folder, sep=",")
narms = masterdata.iloc[0]['k']

# %%
sorted(masterdata.bandit.unique())
# Out:
# ['MP-ADR-Elimination-UCB-ADWIN1; d=0.001',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=0.01',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=0.1',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5',
#  'MP-ADS-TS-ADWIN1; d=0.001; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.001; r=true',
#  'MP-ADS-TS-ADWIN1; d=0.01; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.01; r=true',
#  'MP-ADS-TS-ADWIN1; d=0.1; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.1; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-4; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-4; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-5; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-5; r=true',
#  'MP-D-TS; g=0.7',
#  'MP-D-TS; g=0.8',
#  'MP-D-TS; g=0.9',
#  'MP-D-TS; g=0.99',
#  'MP-D-UCB; g=0.7',
#  'MP-D-UCB; g=0.8',
#  'MP-D-UCB; g=0.9',
#  'MP-D-UCB; g=0.99',
#  'MP-E-G; e=0.7',
#  'MP-E-G; e=0.8',
#  'MP-E-G; e=0.9',
#  'MP-E-G; e=0.99',
#  'MP-GLR-KL-UCB-G',
#  'MP-GLR-KL-UCB-G-F',
#  'MP-GLR-KL-UCB-L',
#  'MP-GLR-KL-UCB-L-F',
#  'MP-KLUCB',
#  'MP-M-UCB; w=1000; m=10',
#  'MP-M-UCB; w=1000; m=100',
#  'MP-M-UCB; w=5000; m=10',
#  'MP-M-UCB; w=5000; m=100',
#  'MP-RExp3; b=100.0',
#  'MP-RExp3; b=1000.0',
#  'MP-RExp3; b=500.0',
#  'MP-RExp3; b=5000.0',
#  'MP-SW-TS; w=100',
#  'MP-SW-TS; w=1000',
#  'MP-SW-TS; w=500',
#  'MP-SW-TS; w=5000',
#  'MP-SW-UCB#-A; nu=0.1; l=12.3',
#  'MP-SW-UCB#-A; nu=0.2; l=12.3',
#  'MP-SW-UCB#-G; ka=0.1; l=4.3',
#  'MP-SW-UCB#-G; ka=0.2; l=4.3',
#  'MP-SW-UCB; w=100',
#  'MP-SW-UCB; w=1000',
#  'MP-SW-UCB; w=500',
#  'MP-SW-UCB; w=5000',
#  'MP-TS',
#  'OD',
#  'OR',
#  'OS']

# %%
masterdata.columns
# Out:
# Index(['bandit', 'dataset', 'scalingstrategy', 'k', 'gain', 'cputime',
#        'iteration'],
#       dtype='object')

# %%
masterdata['reward/arm'] = masterdata['gain']/masterdata['k']

# %%
masterdata.shape
# Out:
# (1680000, 8)

# %%
masterdata.groupby(["scalingstrategy", "bandit"])[['gain', 'k', 'reward/arm', 'cputime']].mean()
# Out:
#                                                              gain       k  \
# scalingstrategy bandit
# No-1            MP-ADR-Elimination-UCB-ADWIN1; d=0.001   0.794974  1.0099
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    0.789094  1.0099
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     0.657083  1.0099
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  0.795082  1.0099
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  0.794842  1.0099
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       0.998604  1.0099
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true        0.998566  1.0099
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        0.998661  1.0099
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         0.998604  1.0099
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         0.998343  1.0099
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true          0.997254  1.0099
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      0.998647  1.0099
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       0.998616  1.0099
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      0.998578  1.0099
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       0.998545  1.0099
#                 MP-D-TS; g=0.7                           0.100691  1.0099
#                 MP-D-TS; g=0.8                           0.136674  1.0099
#                 MP-D-TS; g=0.9                           0.223723  1.0099
#                 MP-D-TS; g=0.99                          0.717197  1.0099
#                 MP-D-UCB; g=0.7                          0.801686  1.0099
#                 MP-D-UCB; g=0.8                          0.802066  1.0099
#                 MP-D-UCB; g=0.9                          0.801978  1.0099
#                 MP-D-UCB; g=0.99                         0.802098  1.0099
#                 MP-E-G; e=0.7                            0.851980  1.0099
#                 MP-E-G; e=0.8                            0.901233  1.0099
#                 MP-E-G; e=0.9                            0.950453  1.0099
#                 MP-E-G; e=0.99                           0.995034  1.0099
#                 MP-GLR-KL-UCB-G                          0.510262  1.0099
#                 MP-GLR-KL-UCB-G-F                        0.584960  1.0099
#                 MP-GLR-KL-UCB-L                          0.438227  1.0099
#                 MP-GLR-KL-UCB-L-F                        0.514403  1.0099
#                 MP-KLUCB                                 1.000000  1.0099
#                 MP-M-UCB; w=1000; m=10                   0.510373  1.0099
#                 MP-M-UCB; w=1000; m=100                  0.510373  1.0099
#                 MP-M-UCB; w=5000; m=10                   0.510373  1.0099
#                 MP-M-UCB; w=5000; m=100                  0.510373  1.0099
#                 MP-RExp3; b=100.0                        0.518478  1.0099
#                 MP-RExp3; b=1000.0                       0.520848  1.0099
#                 MP-RExp3; b=500.0                        0.519651  1.0099
#                 MP-RExp3; b=5000.0                       0.519828  1.0099
#                 MP-SW-TS; w=100                          0.625108  1.0099
#                 MP-SW-TS; w=1000                         0.918217  1.0099
#                 MP-SW-TS; w=500                          0.840570  1.0099
#                 MP-SW-TS; w=5000                         0.992423  1.0099
#                 MP-SW-UCB#-A; nu=0.1; l=12.3             0.610056  1.0099
#                 MP-SW-UCB#-A; nu=0.2; l=12.3             0.590908  1.0099
#                 MP-SW-UCB#-G; ka=0.1; l=4.3              0.510608  1.0099
#                 MP-SW-UCB#-G; ka=0.2; l=4.3              0.510037  1.0099
#                 MP-SW-UCB; w=100                         0.510887  1.0099
#                 MP-SW-UCB; w=1000                        0.763968  1.0099
#                 MP-SW-UCB; w=500                         0.678809  1.0099
#                 MP-SW-UCB; w=5000                        0.858995  1.0099
#                 MP-TS                                    0.998599  1.0099
#                 OD                                       1.004946  1.0099
#                 OR                                       0.510513  1.0099
#                 OS                                       1.004946  1.0099
# No-2            MP-ADR-Elimination-UCB-ADWIN1; d=0.001   1.705930  2.0098
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    1.670727  2.0098
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     1.320034  2.0098
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  1.706173  2.0098
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  1.706493  2.0098
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       1.978948  2.0098
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true        1.979174  2.0098
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        1.979132  2.0098
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         1.978621  2.0098
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         1.974981  2.0098
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true          1.964892  2.0098
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      1.979240  2.0098
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       1.979125  2.0098
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      1.979313  2.0098
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       1.979614  2.0098
#                 MP-D-TS; g=0.7                           0.340680  2.0098
#                 MP-D-TS; g=0.8                           0.457988  2.0098
#                 MP-D-TS; g=0.9                           0.719246  2.0098
#                 MP-D-TS; g=0.99                          1.683497  2.0098
#                 MP-D-UCB; g=0.7                          1.702519  2.0098
#                 MP-D-UCB; g=0.8                          1.701673  2.0098
#                 MP-D-UCB; g=0.9                          1.702398  2.0098
#                 MP-D-UCB; g=0.99                         1.702684  2.0098
#                 MP-E-G; e=0.7                            1.696247  2.0098
#                 MP-E-G; e=0.8                            1.792174  2.0098
#                 MP-E-G; e=0.9                            1.888799  2.0098
#                 MP-E-G; e=0.99                           1.975897  2.0098
#                 MP-GLR-KL-UCB-G                          1.087788  2.0098
#                 MP-GLR-KL-UCB-G-F                        1.246969  2.0098
#                 MP-GLR-KL-UCB-L                          1.110730  2.0098
#                 MP-GLR-KL-UCB-L-F                        1.184005  2.0098
#                 MP-KLUCB                                 1.965163  2.0098
#                 MP-M-UCB; w=1000; m=10                   1.428278  2.0098
#                 MP-M-UCB; w=1000; m=100                  1.428009  2.0098
#                 MP-M-UCB; w=5000; m=10                   1.428156  2.0098
#                 MP-M-UCB; w=5000; m=100                  1.428607  2.0098
#                 MP-RExp3; b=100.0                        1.034607  2.0098
#                 MP-RExp3; b=1000.0                       1.033743  2.0098
#                 MP-RExp3; b=500.0                        1.034537  2.0098
#                 MP-RExp3; b=5000.0                       1.034743  2.0098
#                 MP-SW-TS; w=100                          1.457603  2.0098
#                 MP-SW-TS; w=1000                         1.903092  2.0098
#                 MP-SW-TS; w=500                          1.803406  2.0098
#                 MP-SW-TS; w=5000                         1.964188  2.0098
#                 MP-SW-UCB#-A; nu=0.1; l=12.3             1.310432  2.0098
#                 MP-SW-UCB#-A; nu=0.2; l=12.3             1.256920  2.0098
#                 MP-SW-UCB#-G; ka=0.1; l=4.3              1.014675  2.0098
#                 MP-SW-UCB#-G; ka=0.2; l=4.3              1.014688  2.0098
#                 MP-SW-UCB; w=100                         1.237843  2.0098
#                 MP-SW-UCB; w=1000                        1.660257  2.0098
#                 MP-SW-UCB; w=500                         1.601033  2.0098
#                 MP-SW-UCB; w=5000                        1.812123  2.0098
#                 MP-TS                                    1.979280  2.0098
#                 OD                                       2.004846  2.0098
#                 OR                                       1.014639  2.0098
#                 OS                                       1.994768  2.0098
# No-5            MP-ADR-Elimination-UCB-ADWIN1; d=0.001   4.552230  5.0095
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    4.365684  5.0095
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     3.309061  5.0095
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  4.556638  5.0095
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  4.557013  5.0095
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       4.873307  5.0095
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true        4.872893  5.0095
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        4.871046  5.0095
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         4.870072  5.0095
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         4.821508  5.0095
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true          4.700706  5.0095
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      4.872846  5.0095
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       4.873998  5.0095
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      4.873804  5.0095
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       4.873088  5.0095
#                 MP-D-TS; g=0.7                           1.690012  5.0095
#                 MP-D-TS; g=0.8                           2.159546  5.0095
#                 MP-D-TS; g=0.9                           3.012751  5.0095
#                 MP-D-TS; g=0.99                          4.269209  5.0095
#                 MP-D-UCB; g=0.7                          4.525052  5.0095
#                 MP-D-UCB; g=0.8                          4.525461  5.0095
#                 MP-D-UCB; g=0.9                          4.525170  5.0095
#                 MP-D-UCB; g=0.99                         4.525470  5.0095
#                 MP-E-G; e=0.7                            4.193778  5.0095
#                 MP-E-G; e=0.8                            4.427126  5.0095
#                 MP-E-G; e=0.9                            4.656383  5.0095
#                 MP-E-G; e=0.99                           4.845226  5.0095
#                 MP-GLR-KL-UCB-G                          3.021512  5.0095
#                 MP-GLR-KL-UCB-G-F                        3.447086  5.0095
#                 MP-GLR-KL-UCB-L                          4.013658  5.0095
#                 MP-GLR-KL-UCB-L-F                        4.090014  5.0095
#                 MP-KLUCB                                 4.854933  5.0095
#                 MP-M-UCB; w=1000; m=10                   4.266328  5.0095
#                 MP-M-UCB; w=1000; m=100                  4.266670  5.0095
#                 MP-M-UCB; w=5000; m=10                   4.266401  5.0095
#                 MP-M-UCB; w=5000; m=100                  4.266831  5.0095
#                 MP-RExp3; b=100.0                        2.580872  5.0095
#                 MP-RExp3; b=1000.0                       2.578899  5.0095
#                 MP-RExp3; b=500.0                        2.579464  5.0095
#                 MP-RExp3; b=5000.0                       2.578751  5.0095
#                 MP-SW-TS; w=100                          4.391712  5.0095
#                 MP-SW-TS; w=1000                         4.757589  5.0095
#                 MP-SW-TS; w=500                          4.660625  5.0095
#                 MP-SW-TS; w=5000                         4.849006  5.0095
#                 MP-SW-UCB#-A; nu=0.1; l=12.3             3.654632  5.0095
#                 MP-SW-UCB#-A; nu=0.2; l=12.3             3.502618  5.0095
#                 MP-SW-UCB#-G; ka=0.1; l=4.3              2.530679  5.0095
#                 MP-SW-UCB#-G; ka=0.2; l=4.3              2.531645  5.0095
#                 MP-SW-UCB; w=100                         3.502584  5.0095
#                 MP-SW-UCB; w=1000                        4.390552  5.0095
#                 MP-SW-UCB; w=500                         4.140202  5.0095
#                 MP-SW-UCB; w=5000                        4.709063  5.0095
#                 MP-TS                                    4.873180  5.0095
#                 OD                                       5.004546  5.0095
#                 OR                                       2.529704  5.0095
#                 OS                                       4.904446  5.0095
#
#                                                          reward/arm   cputime
# scalingstrategy bandit
# No-1            MP-ADR-Elimination-UCB-ADWIN1; d=0.001     0.789978  0.738746
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01      0.784098  0.740171
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1       0.652087  0.071575
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4    0.790086  0.895431
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5    0.789846  0.508370
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false         0.993608  0.535367
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true          0.993570  0.527140
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false          0.993665  0.924492
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true           0.993608  0.604139
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false           0.993347  0.334835
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true            0.992258  0.680405
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false        0.993651  0.126545
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true         0.993620  0.933581
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false        0.993582  0.635692
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true         0.993549  0.579366
#                 MP-D-TS; g=0.7                             0.095695  0.159849
#                 MP-D-TS; g=0.8                             0.131678  0.254048
#                 MP-D-TS; g=0.9                             0.218727  0.218194
#                 MP-D-TS; g=0.99                            0.712201  0.287450
#                 MP-D-UCB; g=0.7                            0.796690  0.612108
#                 MP-D-UCB; g=0.8                            0.797070  0.508330
#                 MP-D-UCB; g=0.9                            0.796982  0.376312
#                 MP-D-UCB; g=0.99                           0.797102  0.398140
#                 MP-E-G; e=0.7                              0.846984  0.155488
#                 MP-E-G; e=0.8                              0.896237  0.180899
#                 MP-E-G; e=0.9                              0.945457  0.147853
#                 MP-E-G; e=0.99                             0.990038  0.156298
#                 MP-GLR-KL-UCB-G                            0.505266  0.356968
#                 MP-GLR-KL-UCB-G-F                          0.579964  0.346242
#                 MP-GLR-KL-UCB-L                            0.433231  0.287978
#                 MP-GLR-KL-UCB-L-F                          0.509407  0.554253
#                 MP-KLUCB                                   0.995004  0.147375
#                 MP-M-UCB; w=1000; m=10                     0.505377  0.210986
#                 MP-M-UCB; w=1000; m=100                    0.505377  0.121145
#                 MP-M-UCB; w=5000; m=10                     0.505377  0.196631
#                 MP-M-UCB; w=5000; m=100                    0.505377  0.136036
#                 MP-RExp3; b=100.0                          0.513482  0.277578
#                 MP-RExp3; b=1000.0                         0.515852  0.523381
#                 MP-RExp3; b=500.0                          0.514655  0.294629
#                 MP-RExp3; b=5000.0                         0.514832  0.309659
#                 MP-SW-TS; w=100                            0.620112  0.389593
#                 MP-SW-TS; w=1000                           0.913221  0.168734
#                 MP-SW-TS; w=500                            0.835574  0.336320
#                 MP-SW-TS; w=5000                           0.987427  0.316341
#                 MP-SW-UCB#-A; nu=0.1; l=12.3               0.605060  0.177453
#                 MP-SW-UCB#-A; nu=0.2; l=12.3               0.585912  0.194247
#                 MP-SW-UCB#-G; ka=0.1; l=4.3                0.505612  0.144914
#                 MP-SW-UCB#-G; ka=0.2; l=4.3                0.505041  0.212105
#                 MP-SW-UCB; w=100                           0.505891  0.229264
#                 MP-SW-UCB; w=1000                          0.758972  0.292099
#                 MP-SW-UCB; w=500                           0.673813  0.241190
#                 MP-SW-UCB; w=5000                          0.853999  0.178104
#                 MP-TS                                      0.993603  0.296090
#                 OD                                         0.999950  0.151578
#                 OR                                         0.505517  0.051306
#                 OS                                         0.999950  0.008120
# No-2            MP-ADR-Elimination-UCB-ADWIN1; d=0.001     0.850492  0.692293
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01      0.832891  1.059629
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1       0.657544  0.306650
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4    0.850614  0.813273
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5    0.850774  0.612495
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false         0.987001  0.770317
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true          0.987114  0.759222
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false          0.987093  0.790699
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true           0.986838  0.832570
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false           0.985018  0.551249
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true            0.979973  0.792417
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false        0.987147  0.740384
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true         0.987090  1.248792
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false        0.987184  0.938592
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true         0.987334  0.872534
#                 MP-D-TS; g=0.7                             0.167867  0.321768
#                 MP-D-TS; g=0.8                             0.226521  0.192468
#                 MP-D-TS; g=0.9                             0.357150  0.223306
#                 MP-D-TS; g=0.99                            0.839276  0.323801
#                 MP-D-UCB; g=0.7                            0.848787  0.461995
#                 MP-D-UCB; g=0.8                            0.848364  0.420081
#                 MP-D-UCB; g=0.9                            0.848726  0.600966
#                 MP-D-UCB; g=0.99                           0.848869  0.324369
#                 MP-E-G; e=0.7                              0.845651  0.125258
#                 MP-E-G; e=0.8                              0.893614  0.077333
#                 MP-E-G; e=0.9                              0.941927  0.175066
#                 MP-E-G; e=0.99                             0.985476  0.203728
#                 MP-GLR-KL-UCB-G                            0.541421  0.483025
#                 MP-GLR-KL-UCB-G-F                          0.621012  0.319113
#                 MP-GLR-KL-UCB-L                            0.552892  0.336977
#                 MP-GLR-KL-UCB-L-F                          0.589530  0.440608
#                 MP-KLUCB                                   0.980109  0.311769
#                 MP-M-UCB; w=1000; m=10                     0.711666  0.383085
#                 MP-M-UCB; w=1000; m=100                    0.711532  0.204376
#                 MP-M-UCB; w=5000; m=10                     0.711605  0.317673
#                 MP-M-UCB; w=5000; m=100                    0.711831  0.222284
#                 MP-RExp3; b=100.0                          0.514831  0.379106
#                 MP-RExp3; b=1000.0                         0.514399  0.417340
#                 MP-RExp3; b=500.0                          0.514796  0.343960
#                 MP-RExp3; b=5000.0                         0.514899  0.260967
#                 MP-SW-TS; w=100                            0.726329  0.384583
#                 MP-SW-TS; w=1000                           0.949073  0.177536
#                 MP-SW-TS; w=500                            0.899230  0.326796
#                 MP-SW-TS; w=5000                           0.979621  0.163908
#                 MP-SW-UCB#-A; nu=0.1; l=12.3               0.652743  0.191771
#                 MP-SW-UCB#-A; nu=0.2; l=12.3               0.625987  0.221389
#                 MP-SW-UCB#-G; ka=0.1; l=4.3                0.504865  0.221013
#                 MP-SW-UCB#-G; ka=0.2; l=4.3                0.504871  0.248519
#                 MP-SW-UCB; w=100                           0.616449  0.183684
#                 MP-SW-UCB; w=1000                          0.827656  0.180480
#                 MP-SW-UCB; w=500                           0.798044  0.174505
#                 MP-SW-UCB; w=5000                          0.903589  0.150601
#                 MP-TS                                      0.987167  0.330272
#                 OD                                         0.999950  0.173402
#                 OR                                         0.504847  0.030216
#                 OS                                         0.994911  0.015370
# No-5            MP-ADR-Elimination-UCB-ADWIN1; d=0.001     0.909487  0.621847
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01      0.872178  1.436785
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1       0.660853  0.430970
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4    0.910369  1.462817
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5    0.910444  0.631454
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false         0.973703  0.986414
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true          0.973620  1.092121
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false          0.973250  1.590260
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true           0.973056  1.398465
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false           0.963343  0.768851
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true            0.939182  0.444170
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false        0.973610  0.927206
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true         0.973841  1.131540
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false        0.973802  1.505745
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true         0.973659  1.603964
#                 MP-D-TS; g=0.7                             0.337044  0.211135
#                 MP-D-TS; g=0.8                             0.430950  0.291597
#                 MP-D-TS; g=0.9                             0.601591  0.297912
#                 MP-D-TS; g=0.99                            0.852883  0.311428
#                 MP-D-UCB; g=0.7                            0.904052  0.555870
#                 MP-D-UCB; g=0.8                            0.904133  0.462327
#                 MP-D-UCB; g=0.9                            0.904075  0.456123
#                 MP-D-UCB; g=0.99                           0.904135  0.534895
#                 MP-E-G; e=0.7                              0.837797  0.127148
#                 MP-E-G; e=0.8                              0.884466  0.240514
#                 MP-E-G; e=0.9                              0.930318  0.141504
#                 MP-E-G; e=0.99                             0.968086  0.113184
#                 MP-GLR-KL-UCB-G                            0.603344  0.451925
#                 MP-GLR-KL-UCB-G-F                          0.688458  0.373769
#                 MP-GLR-KL-UCB-L                            0.801773  0.783499
#                 MP-GLR-KL-UCB-L-F                          0.817044  0.636504
#                 MP-KLUCB                                   0.970028  0.271750
#                 MP-M-UCB; w=1000; m=10                     0.852307  0.449249
#                 MP-M-UCB; w=1000; m=100                    0.852375  0.320343
#                 MP-M-UCB; w=5000; m=10                     0.852321  0.456496
#                 MP-M-UCB; w=5000; m=100                    0.852407  0.475144
#                 MP-RExp3; b=100.0                          0.515216  0.463812
#                 MP-RExp3; b=1000.0                         0.514821  0.379612
#                 MP-RExp3; b=500.0                          0.514934  0.343898
#                 MP-RExp3; b=5000.0                         0.514791  0.290914
#                 MP-SW-TS; w=100                            0.877384  0.201027
#                 MP-SW-TS; w=1000                           0.950559  0.264056
#                 MP-SW-TS; w=500                            0.931166  0.252757
#                 MP-SW-TS; w=5000                           0.968842  0.219883
#                 MP-SW-UCB#-A; nu=0.1; l=12.3               0.729968  0.192981
#                 MP-SW-UCB#-A; nu=0.2; l=12.3               0.699565  0.172414
#                 MP-SW-UCB#-G; ka=0.1; l=4.3                0.505177  0.294474
#                 MP-SW-UCB#-G; ka=0.2; l=4.3                0.505370  0.184534
#                 MP-SW-UCB; w=100                           0.699558  0.370190
#                 MP-SW-UCB; w=1000                          0.877152  0.283485
#                 MP-SW-UCB; w=500                           0.827082  0.285587
#                 MP-SW-UCB; w=5000                          0.940854  0.202829
#                 MP-TS                                      0.973677  0.272225
#                 OD                                         0.999950  0.254538
#                 OR                                         0.504982  0.094018
#                 OS                                         0.979930  0.029606

# %%
masterdata.describe()
# Out:
#                   k          gain       cputime     iteration    reward/arm
# count  1.680000e+06  1.680000e+06  1.680000e+06  1.680000e+06  1.680000e+06
# mean   2.676400e+00  2.122992e+00  4.244910e-01  4.999500e+03  7.718778e-01
# std    1.958542e+00  1.623854e+00  5.811976e-01  2.886752e+03  2.276423e-01
# min    1.000000e+00  0.000000e+00  2.700000e-03  0.000000e+00  0.000000e+00
# 25%    1.000000e+00  9.200000e-01  1.975000e-01  2.499750e+03  5.900000e-01
# 50%    2.000000e+00  1.700000e+00  3.022000e-01  4.999500e+03  8.540000e-01
# 75%    5.000000e+00  3.490000e+00  4.620000e-01  7.499250e+03  9.700000e-01
# max    1.000000e+02  5.046000e+01  1.222620e+01  9.999000e+03  1.000000e+00

# %%
masterdata['dataset'].unique()
# Out:
# array(['StaticGenerator-100'], dtype=object)

# %%
from matplotlib.markers import TICKLEFT, TICKRIGHT, TICKUP, TICKDOWN, CARETLEFT, CARETRIGHT, CARETUP, CARETDOWN
markers = [
#    '.',
#    ',',
    'v',
    'o',
    '^',
    '<',
    '>',
#    '1',
#    '2',
#    '3',
#    '4',
#    '8',
    's',
#    'p',
    '*',
#    'h',
    'H',
    '+',
    'x',
    'D',
#    'd',
    '|',
    '_',
    TICKLEFT,
    TICKRIGHT,
    TICKUP,
    TICKDOWN,
    CARETLEFT,
    CARETRIGHT,
    CARETUP,
    CARETDOWN,
]

# %%
algs_ours = [    
    # ours
    'MP-ADR-Elimination-UCB-ADWIN1; d=0.001',
    'MP-ADS-TS-ADWIN1; d=0.001; r=true',
#    'MP-ADS-TS-ADWIN1; d=0.001; r=false'
]
algs_pass = [
    # passive
    'MP-D-UCB; g=0.9',
    'MP-RExp3; b=1000.0',
    'MP-SW-TS; w=1000',
#    'MP-SW-UCB; w=1000',
    'MP-SW-UCB#-A; nu=0.1; l=12.3', 
    'MP-SW-UCB#-G; ka=0.1; l=4.3', 
    
    #'MP-SW-UCB#-A; nu=0.2; l=12.3', 
    #'MP-SW-UCB#-G; ka=0.2; l=4.3'
]
algs_act = [
    # active
    'MP-GLR-KL-UCB-G',
#    'MP-GLR-KL-UCB-L',
#    'MP-GLR-KL-UCB-G-F',
#    'MP-GLR-KL-UCB-L-F',
    'MP-M-UCB; w=1000; m=10',
#    'MP-M-UCB; w=5000; m=100',
]
algs_base = [
    # baselines
    'MP-TS',
    'MP-E-G; e=0.9',
    'OR',
    'OD',
    'OS',
    'CustomOracle'
]

# %%
prettynames = {
    'MP-ADR-Elimination-UCB-ADWIN1; d=0.001' : "ADR-E-UCB",
    'MP-ADS-TS-ADWIN1; d=0.001; r=true': "ADR-TS",
#    'MP-ADS-TS-ADWIN1; d=0.001; r=false': "ADS-TS",
    'MP-D-UCB; g=0.9': "D-UCB",
    'MP-RExp3; b=1000.0': "RExp3",
    'MP-SW-TS; w=1000': "SW-TS",
    'MP-SW-UCB; w=1000': "SW-UCB",
    'MP-SW-UCB#-A; nu=0.1; l=12.3': "SW-UCB\#-A",
    'MP-SW-UCB#-G; ka=0.1; l=4.3': "SW-UCB\#-G",
    # active
    'MP-GLR-KL-UCB-G': 'GLR-KL-UCB',
    'MP-GLR-KL-UCB-L': 'GLR-KL-UCB-L',
    'MP-GLR-KL-UCB-G-F': 'GLR-KL-UCB-G-F',
    'MP-GLR-KL-UCB-L-F': 'GLR-KL-UCB-L-F',
#    'MP-M-UCB; w=1000; m=10': 'M-UCB; w=1000; m=10',
#    'MP-M-UCB; w=5000; m=100': 'M-UCB; w=5000; m=100',
    'MP-M-UCB; w=1000; m=10': 'M-UCB',
    # baselines
    'MP-TS': 'MP-TS',
    'MP-E-G; e=0.9': 'Espilon-Greedy',
    'OR': "Random Oracle",
    'OD': "Dynamic Oracle",
    'OS': "Static Oracle",
    'CustomOracle': "Custom Oracle"
}

# %%
# compute regret against 'OD', or just the cumulative rewards

# %%
#  constrained_layout=True is for reducing space
fig, axes = plt.subplots(2, 2, sharey=True, sharex=True,  figsize=(14,10), constrained_layout=True) 

dataset = "Static"
L = 5

plt.sca(axes[0][0])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "OS"].gain.cumsum().reset_index(drop=True)
for bandit in algs_ours + algs_pass:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, marker=markers[i], 
                             alpha=0.7, markevery=(i*500,400), markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(ncol=1)
plt.ylabel("$R_T / L$")
plt.title("Ours vs. passive approaches ($L = %s$)"%L)

plt.sca(axes[1][0])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "OS"].gain.cumsum().reset_index(drop=True)
for bandit in algs_ours + algs_act:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, marker=markers[i], 
                             alpha=0.7, markevery=(i*500,400), markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(ncol=1)
plt.ylabel("$R_T / L$")
plt.title("Ours vs. active approaches ($L = %s$)"%L)
plt.xlabel("$T$")

plt.sca(axes[0][1])


L = 1
i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "OS"].gain.cumsum().reset_index(drop=True)
for bandit in algs_ours + algs_pass:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, marker=markers[i], 
                             alpha=0.7, markevery=(i*500,400), markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(ncol=1)
plt.title("Ours vs. passive approaches ($L = %s$)"%L)

plt.sca(axes[1][1])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "OS"].gain.cumsum().reset_index(drop=True)
for bandit in algs_ours + algs_act:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, marker=markers[i], 
                             alpha=0.7, markevery=(i*500,400), markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(ncol=1)
plt.title("Ours vs. active approaches ($L = %s$)"%L)
plt.xlabel("$T$")

#plt.tight_layout()

plt.suptitle("Cumulative regret over time (stationary)", fontsize=25)
plt.savefig("plots/%s_regret_full_Fig9.pdf"%dataset)

# %%
# L=1

#  constrained_layout=True is for reducing space
fig, axes = plt.subplots(1, 2, sharey=True, sharex=True,  figsize=(14,5), constrained_layout=True) 

dataset = "Static"

L = 1

plt.sca(axes[0])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "OS"].gain.cumsum().reset_index(drop=True)
for bandit in algs_ours + algs_pass:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, marker=markers[i], 
                             alpha=0.7, markevery=(i*500,400), markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(ncol=1)
plt.ylabel("$R_T / L$")
#plt.title("Ours vs. passive approaches ($L = %s$)"%L)
plt.title("Ours vs. passive approaches")
plt.xlabel("$T$")
plt.ylabel("$R_T$")

plt.sca(axes[1])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "OS"].gain.cumsum().reset_index(drop=True)
for bandit in algs_ours + algs_act:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, marker=markers[i], 
                             alpha=0.7, markevery=(i*500,400), markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(ncol=1)
#plt.title("Ours vs. active approaches ($L = %s$)"%L)
plt.title("Ours vs. active approaches")
plt.xlabel("$T$")


#plt.tight_layout()

plt.suptitle("Cumulative regret over time (stationary)", fontsize=25)
plt.savefig("plots/%s_regret_Fig5a.pdf"%dataset)
