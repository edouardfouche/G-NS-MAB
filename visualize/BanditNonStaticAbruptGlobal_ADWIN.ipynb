# %%
import math

import matplotlib as mpl
mpl.rcParams['text.usetex'] = True 
mpl.rcParams['text.latex.preamble'] = [r'\usepackage{libertine}', r'\usepackage{newtxmath}'] 
mpl.rc('font', family='serif')

import numpy as np
import pandas as pd
import seaborn as sns


import matplotlib.pyplot as plt
from matplotlib import rc

from cycler import cycler


mpl.rcParams['ps.usedistiller'] = 'xpdf' 

plt.style.use('seaborn-notebook')
# sns.set_palette("Blues_r")

plt.rcParams['axes.titlesize'] = '25'
plt.rcParams['axes.labelsize'] = '25'
plt.rcParams['legend.fontsize'] = '15'
plt.rcParams['xtick.labelsize'] = '15'
plt.rcParams['ytick.labelsize'] = '15'

monochrome=(cycler('color', sns.color_palette("husl", 8))*2+(cycler('marker', ['v', 's', "o"])*7)[0:16])
plt.rc('axes', prop_cycle=monochrome)

pd.options.display.max_rows = 999
# Out:
# <ipython-input-1-56d1c1821bb1>:5: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   mpl.rcParams['text.latex.preamble'] = [r'\usepackage{libertine}', r'\usepackage{newtxmath}']

# %%
# Change if required
folder = "../experiments/2021-06-09-14-04_BanditNonStaticAbruptGlobal_ADWIN_"
dataset = "AbruptGlobal_ADWIN"

# %%
masterdata = pd.read_csv("%s/BanditNonStaticAbruptGlobal_ADWIN.csv"%folder, sep=",")
narms = masterdata.iloc[0]['k']

# %%
sorted(masterdata.bandit.unique())
# Out:
# ['CustomOracle',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=0.001',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=0.01',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=0.1',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5',
#  'MP-ADS-TS-ADWIN1; d=0.001; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.001; r=true',
#  'MP-ADS-TS-ADWIN1; d=0.01; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.01; r=true',
#  'MP-ADS-TS-ADWIN1; d=0.1; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.1; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-4; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-4; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-5; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-5; r=true',
#  'OD',
#  'OR',
#  'OS']

# %%
sorted(masterdata.dataset.unique())
# Out:
# ['AbruptGlobalGenerator-100']

# %%
masterdata.columns
# Out:
# Index(['bandit', 'dataset', 'scalingstrategy', 'k', 'gain', 'cputime',
#        'historylength', 'iteration'],
#       dtype='object')

# %%
masterdata['reward/arm'] = masterdata['gain']/masterdata['k']

# %%
masterdata.shape
# Out:
# (570000, 9)

# %%
masterdata.groupby(["scalingstrategy", "bandit", "dataset"])[['gain', 'k', 'reward/arm', 'cputime']].mean()
# Out:
#                                                                                        gain  \
# scalingstrategy bandit                                  dataset
# No-1            CustomOracle                            AbruptGlobalGenerator-100  1.001607
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001  AbruptGlobalGenerator-100  0.696209
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01   AbruptGlobalGenerator-100  0.695760
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1    AbruptGlobalGenerator-100  0.642760
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4 AbruptGlobalGenerator-100  0.691538
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5 AbruptGlobalGenerator-100  0.689953
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false      AbruptGlobalGenerator-100  0.960270
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true       AbruptGlobalGenerator-100  0.965246
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false       AbruptGlobalGenerator-100  0.960334
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true        AbruptGlobalGenerator-100  0.964928
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false        AbruptGlobalGenerator-100  0.959692
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true         AbruptGlobalGenerator-100  0.956193
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false     AbruptGlobalGenerator-100  0.961077
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true      AbruptGlobalGenerator-100  0.965662
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false     AbruptGlobalGenerator-100  0.961718
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true      AbruptGlobalGenerator-100  0.964591
#                 OD                                      AbruptGlobalGenerator-100  1.004994
#                 OR                                      AbruptGlobalGenerator-100  0.506406
#                 OS                                      AbruptGlobalGenerator-100  0.671694
# No-2            CustomOracle                            AbruptGlobalGenerator-100  1.988091
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001  AbruptGlobalGenerator-100  1.504445
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01   AbruptGlobalGenerator-100  1.501444
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1    AbruptGlobalGenerator-100  1.300969
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4 AbruptGlobalGenerator-100  1.502817
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5 AbruptGlobalGenerator-100  1.505085
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false      AbruptGlobalGenerator-100  1.930338
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true       AbruptGlobalGenerator-100  1.934161
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false       AbruptGlobalGenerator-100  1.930367
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true        AbruptGlobalGenerator-100  1.933466
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false        AbruptGlobalGenerator-100  1.924787
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true         AbruptGlobalGenerator-100  1.906000
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false     AbruptGlobalGenerator-100  1.930270
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true      AbruptGlobalGenerator-100  1.934716
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false     AbruptGlobalGenerator-100  1.930714
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true      AbruptGlobalGenerator-100  1.931998
#                 OD                                      AbruptGlobalGenerator-100  2.004894
#                 OR                                      AbruptGlobalGenerator-100  1.007999
#                 OS                                      AbruptGlobalGenerator-100  1.335097
# No-5            CustomOracle                            AbruptGlobalGenerator-100  4.887872
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001  AbruptGlobalGenerator-100  4.168394
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01   AbruptGlobalGenerator-100  4.106158
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1    AbruptGlobalGenerator-100  3.277158
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4 AbruptGlobalGenerator-100  4.163908
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5 AbruptGlobalGenerator-100  4.162396
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false      AbruptGlobalGenerator-100  4.792293
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true       AbruptGlobalGenerator-100  4.792890
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false       AbruptGlobalGenerator-100  4.791065
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true        AbruptGlobalGenerator-100  4.792019
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false        AbruptGlobalGenerator-100  4.743639
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true         AbruptGlobalGenerator-100  4.597910
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false     AbruptGlobalGenerator-100  4.791956
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true      AbruptGlobalGenerator-100  4.793540
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false     AbruptGlobalGenerator-100  4.788313
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true      AbruptGlobalGenerator-100  4.788413
#                 OD                                      AbruptGlobalGenerator-100  5.004594
#                 OR                                      AbruptGlobalGenerator-100  2.513885
#                 OS                                      AbruptGlobalGenerator-100  3.305217
#
#                                                                                         k  \
# scalingstrategy bandit                                  dataset
# No-1            CustomOracle                            AbruptGlobalGenerator-100  1.0099
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001  AbruptGlobalGenerator-100  1.0099
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01   AbruptGlobalGenerator-100  1.0099
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1    AbruptGlobalGenerator-100  1.0099
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4 AbruptGlobalGenerator-100  1.0099
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5 AbruptGlobalGenerator-100  1.0099
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false      AbruptGlobalGenerator-100  1.0099
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true       AbruptGlobalGenerator-100  1.0099
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false       AbruptGlobalGenerator-100  1.0099
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true        AbruptGlobalGenerator-100  1.0099
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false        AbruptGlobalGenerator-100  1.0099
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true         AbruptGlobalGenerator-100  1.0099
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false     AbruptGlobalGenerator-100  1.0099
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true      AbruptGlobalGenerator-100  1.0099
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false     AbruptGlobalGenerator-100  1.0099
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true      AbruptGlobalGenerator-100  1.0099
#                 OD                                      AbruptGlobalGenerator-100  1.0099
#                 OR                                      AbruptGlobalGenerator-100  1.0099
#                 OS                                      AbruptGlobalGenerator-100  1.0099
# No-2            CustomOracle                            AbruptGlobalGenerator-100  2.0098
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001  AbruptGlobalGenerator-100  2.0098
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01   AbruptGlobalGenerator-100  2.0098
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1    AbruptGlobalGenerator-100  2.0098
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4 AbruptGlobalGenerator-100  2.0098
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5 AbruptGlobalGenerator-100  2.0098
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false      AbruptGlobalGenerator-100  2.0098
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true       AbruptGlobalGenerator-100  2.0098
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false       AbruptGlobalGenerator-100  2.0098
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true        AbruptGlobalGenerator-100  2.0098
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false        AbruptGlobalGenerator-100  2.0098
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true         AbruptGlobalGenerator-100  2.0098
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false     AbruptGlobalGenerator-100  2.0098
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true      AbruptGlobalGenerator-100  2.0098
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false     AbruptGlobalGenerator-100  2.0098
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true      AbruptGlobalGenerator-100  2.0098
#                 OD                                      AbruptGlobalGenerator-100  2.0098
#                 OR                                      AbruptGlobalGenerator-100  2.0098
#                 OS                                      AbruptGlobalGenerator-100  2.0098
# No-5            CustomOracle                            AbruptGlobalGenerator-100  5.0095
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001  AbruptGlobalGenerator-100  5.0095
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01   AbruptGlobalGenerator-100  5.0095
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1    AbruptGlobalGenerator-100  5.0095
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4 AbruptGlobalGenerator-100  5.0095
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5 AbruptGlobalGenerator-100  5.0095
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false      AbruptGlobalGenerator-100  5.0095
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true       AbruptGlobalGenerator-100  5.0095
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false       AbruptGlobalGenerator-100  5.0095
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true        AbruptGlobalGenerator-100  5.0095
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false        AbruptGlobalGenerator-100  5.0095
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true         AbruptGlobalGenerator-100  5.0095
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false     AbruptGlobalGenerator-100  5.0095
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true      AbruptGlobalGenerator-100  5.0095
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false     AbruptGlobalGenerator-100  5.0095
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true      AbruptGlobalGenerator-100  5.0095
#                 OD                                      AbruptGlobalGenerator-100  5.0095
#                 OR                                      AbruptGlobalGenerator-100  5.0095
#                 OS                                      AbruptGlobalGenerator-100  5.0095
#
#                                                                                    reward/arm  \
# scalingstrategy bandit                                  dataset
# No-1            CustomOracle                            AbruptGlobalGenerator-100    0.996564
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001  AbruptGlobalGenerator-100    0.691166
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01   AbruptGlobalGenerator-100    0.690717
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1    AbruptGlobalGenerator-100    0.637717
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4 AbruptGlobalGenerator-100    0.686495
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5 AbruptGlobalGenerator-100    0.684910
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false      AbruptGlobalGenerator-100    0.955227
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true       AbruptGlobalGenerator-100    0.960203
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false       AbruptGlobalGenerator-100    0.955291
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true        AbruptGlobalGenerator-100    0.959885
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false        AbruptGlobalGenerator-100    0.954649
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true         AbruptGlobalGenerator-100    0.951150
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false     AbruptGlobalGenerator-100    0.956034
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true      AbruptGlobalGenerator-100    0.960619
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false     AbruptGlobalGenerator-100    0.956675
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true      AbruptGlobalGenerator-100    0.959548
#                 OD                                      AbruptGlobalGenerator-100    0.999951
#                 OR                                      AbruptGlobalGenerator-100    0.501363
#                 OS                                      AbruptGlobalGenerator-100    0.666651
# No-2            CustomOracle                            AbruptGlobalGenerator-100    0.991549
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001  AbruptGlobalGenerator-100    0.749726
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01   AbruptGlobalGenerator-100    0.748226
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1    AbruptGlobalGenerator-100    0.647988
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4 AbruptGlobalGenerator-100    0.748912
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5 AbruptGlobalGenerator-100    0.750046
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false      AbruptGlobalGenerator-100    0.962673
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true       AbruptGlobalGenerator-100    0.964584
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false       AbruptGlobalGenerator-100    0.962687
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true        AbruptGlobalGenerator-100    0.964237
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false        AbruptGlobalGenerator-100    0.959897
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true         AbruptGlobalGenerator-100    0.950504
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false     AbruptGlobalGenerator-100    0.962639
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true      AbruptGlobalGenerator-100    0.964862
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false     AbruptGlobalGenerator-100    0.962861
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true      AbruptGlobalGenerator-100    0.963503
#                 OD                                      AbruptGlobalGenerator-100    0.999951
#                 OR                                      AbruptGlobalGenerator-100    0.501503
#                 OS                                      AbruptGlobalGenerator-100    0.665052
# No-5            CustomOracle                            AbruptGlobalGenerator-100    0.976607
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001  AbruptGlobalGenerator-100    0.832711
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01   AbruptGlobalGenerator-100    0.820264
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1    AbruptGlobalGenerator-100    0.654464
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4 AbruptGlobalGenerator-100    0.831814
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5 AbruptGlobalGenerator-100    0.831511
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false      AbruptGlobalGenerator-100    0.957491
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true       AbruptGlobalGenerator-100    0.957610
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false       AbruptGlobalGenerator-100    0.957245
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true        AbruptGlobalGenerator-100    0.957436
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false        AbruptGlobalGenerator-100    0.947760
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true         AbruptGlobalGenerator-100    0.918614
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false     AbruptGlobalGenerator-100    0.957423
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true      AbruptGlobalGenerator-100    0.957740
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false     AbruptGlobalGenerator-100    0.956695
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true      AbruptGlobalGenerator-100    0.956715
#                 OD                                      AbruptGlobalGenerator-100    0.999951
#                 OR                                      AbruptGlobalGenerator-100    0.501809
#                 OS                                      AbruptGlobalGenerator-100    0.660076
#
#                                                                                     cputime
# scalingstrategy bandit                                  dataset
# No-1            CustomOracle                            AbruptGlobalGenerator-100  0.021348
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001  AbruptGlobalGenerator-100  0.351427
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01   AbruptGlobalGenerator-100  0.359552
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1    AbruptGlobalGenerator-100  0.362825
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4 AbruptGlobalGenerator-100  0.397758
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5 AbruptGlobalGenerator-100  0.466904
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false      AbruptGlobalGenerator-100  0.333587
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true       AbruptGlobalGenerator-100  0.306807
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false       AbruptGlobalGenerator-100  0.350917
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true        AbruptGlobalGenerator-100  0.288942
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false        AbruptGlobalGenerator-100  0.342782
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true         AbruptGlobalGenerator-100  0.308627
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false     AbruptGlobalGenerator-100  0.303939
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true      AbruptGlobalGenerator-100  0.331255
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false     AbruptGlobalGenerator-100  0.307553
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true      AbruptGlobalGenerator-100  0.338390
#                 OD                                      AbruptGlobalGenerator-100  0.155062
#                 OR                                      AbruptGlobalGenerator-100  0.039496
#                 OS                                      AbruptGlobalGenerator-100  0.015770
# No-2            CustomOracle                            AbruptGlobalGenerator-100  0.019365
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001  AbruptGlobalGenerator-100  0.414308
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01   AbruptGlobalGenerator-100  0.388972
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1    AbruptGlobalGenerator-100  0.358416
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4 AbruptGlobalGenerator-100  0.411968
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5 AbruptGlobalGenerator-100  0.419415
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false      AbruptGlobalGenerator-100  0.349991
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true       AbruptGlobalGenerator-100  0.369304
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false       AbruptGlobalGenerator-100  0.374951
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true        AbruptGlobalGenerator-100  0.373546
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false        AbruptGlobalGenerator-100  0.348712
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true         AbruptGlobalGenerator-100  0.345793
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false     AbruptGlobalGenerator-100  0.332476
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true      AbruptGlobalGenerator-100  0.365769
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false     AbruptGlobalGenerator-100  0.376818
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true      AbruptGlobalGenerator-100  0.370841
#                 OD                                      AbruptGlobalGenerator-100  0.149362
#                 OR                                      AbruptGlobalGenerator-100  0.050101
#                 OS                                      AbruptGlobalGenerator-100  0.023205
# No-5            CustomOracle                            AbruptGlobalGenerator-100  0.020931
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001  AbruptGlobalGenerator-100  0.463556
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01   AbruptGlobalGenerator-100  0.470289
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1    AbruptGlobalGenerator-100  0.371675
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4 AbruptGlobalGenerator-100  0.471929
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5 AbruptGlobalGenerator-100  0.457610
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false      AbruptGlobalGenerator-100  0.450994
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true       AbruptGlobalGenerator-100  0.452131
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false       AbruptGlobalGenerator-100  0.427091
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true        AbruptGlobalGenerator-100  0.454245
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false        AbruptGlobalGenerator-100  0.411082
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true         AbruptGlobalGenerator-100  0.337573
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false     AbruptGlobalGenerator-100  0.446112
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true      AbruptGlobalGenerator-100  0.449567
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false     AbruptGlobalGenerator-100  0.452903
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true      AbruptGlobalGenerator-100  0.459205
#                 OD                                      AbruptGlobalGenerator-100  0.160242
#                 OR                                      AbruptGlobalGenerator-100  0.051036
#                 OS                                      AbruptGlobalGenerator-100  0.013023

# %%
from matplotlib.markers import TICKLEFT, TICKRIGHT, TICKUP, TICKDOWN, CARETLEFT, CARETRIGHT, CARETUP, CARETDOWN
markers = [
#    '.',
#    ',',
    'v',
    '<',
    '^',
    '>',
    'o',
#    '1',
#    '2',
#    '3',
#    '4',
#    '8',
    's',
    'p',
    '*',
#    'h',
    'H',
    '+',
    'x',
    'D',
#    'd',
    '|',
    '_',
    TICKLEFT,
    TICKRIGHT,
    TICKUP,
    TICKDOWN,
    CARETLEFT,
    CARETRIGHT,
    CARETUP,
    CARETDOWN,
]

# %%
from matplotlib import cm
colors = [cm.Reds((i+2)/4.0) for i in range(4)] + [cm.Greens((i+2)/4.0) for i in range(4)]

# %%
algs = [    
    # ours 
#     'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5',
#     'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4',
#     'MP-ADR-Elimination-UCB-ADWIN1; d=0.001',
#     'MP-ADR-Elimination-UCB-ADWIN1; d=0.01',
#     'MP-ADR-Elimination-UCB-ADWIN1; d=0.1',
    
     'MP-ADS-TS-ADWIN1; d=0.1; r=false',
     'MP-ADS-TS-ADWIN1; d=0.01; r=false',
     'MP-ADS-TS-ADWIN1; d=0.001; r=false',
     'MP-ADS-TS-ADWIN1; d=1.0E-4; r=false',
#     'MP-ADS-TS-ADWIN1; d=1.0E-5; r=false',
    
     'MP-ADS-TS-ADWIN1; d=0.1; r=true',
     'MP-ADS-TS-ADWIN1; d=0.01; r=true',
     'MP-ADS-TS-ADWIN1; d=0.001; r=true',
    'MP-ADS-TS-ADWIN1; d=1.0E-4; r=true',
#    'MP-ADS-TS-ADWIN1; d=1.0E-5; r=true',
]

# %%
prettynames = {
#     'MP-ADR-Elimination-UCB-ADWIN1; d=0.1':'ADR-Elimination-UCB; d=0.1',
#     'MP-ADR-Elimination-UCB-ADWIN1; d=0.01':'ADR-Elimination-UCB; d=0.01',
#     'MP-ADR-Elimination-UCB-ADWIN1; d=0.001':'ADR-Elimination-UCB; d=0.001',
#     'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4':'ADR-Elimination-UCB; d=1.0E-4',
#     'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5':'ADR-Elimination-UCB; d=1.0E-5',
    
     'MP-ADS-TS-ADWIN1; d=0.1; r=false':'ADS-TS; $\delta$=0.1',
     'MP-ADS-TS-ADWIN1; d=0.01; r=false':'ADS-TS; $\delta$=0.01',
     'MP-ADS-TS-ADWIN1; d=0.001; r=false':'ADS-TS; $\delta$=0.001',
     'MP-ADS-TS-ADWIN1; d=1.0E-4; r=false':'ADS-TS; $\delta$=1.0E-4',
#     'MP-ADS-TS-ADWIN1; d=1.0E-5; r=false':'ADS-TS; d=1.0E-5',
    
     'MP-ADS-TS-ADWIN1; d=0.1; r=true':'ADR-TS; $\delta$=0.1',
     'MP-ADS-TS-ADWIN1; d=0.01; r=true':'ADR-TS; $\delta$=0.01',
     'MP-ADS-TS-ADWIN1; d=0.001; r=true':'ADR-TS; $\delta$=0.001',
    'MP-ADS-TS-ADWIN1; d=1.0E-4; r=true':'ADR-TS; $\delta$=1.0E-4',
#    'MP-ADS-TS-ADWIN1; d=1.0E-5; r=true':'ADR-TS; d=1.0E-5',
}

# %%
# compute regret against 'OD', or just the cumulative rewards

# %%
#  constrained_layout=True is for reducing space
fig, axes = plt.subplots(1, 2, sharex=True, figsize=(14,6), constrained_layout=True) 

L = 5

dataset = 'AbruptGlobalGenerator-100'

plt.sca(axes[0])

i = 0

subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]

for bandit in algs:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "CustomOracle"].gain.cumsum().reset_index(drop=True)
for bandit in algs:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                             markevery=(i*500,800), marker=markers[i], markersize=10, color=colors[i])
    i+=1
    
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(ncol=1)
plt.ylabel("$R_T / L$")
plt.title("($L = %s$)"%L)
plt.ylim((0,500))

plt.sca(axes[1])

L = 1

i = 0

subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]

for bandit in algs:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "CustomOracle"].gain.cumsum().reset_index(drop=True)
for bandit in algs:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                             markevery=(i*500,800), marker=markers[i], markersize=10, color=colors[i])
    i+=1

plt.legend(ncol=1)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel("$R_T / L$")
plt.title("($L = %s$)"%L)
plt.ylim((0,500))

plt.suptitle("Cumulative regret over time (abrupt)", fontsize=25)
plt.savefig("plots/ours_regret_abrupt_Fig8a.pdf")

# %%
fig, axes = plt.subplots(2, 2, sharex=True, figsize=(15,15))

L = 5

dataset = 'AbruptGlobalGenerator-100'

plt.sca(axes[0][0])

i = 0

subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]

for bandit in algs:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "CustomOracle"].gain.cumsum().reset_index(drop=True)
for bandit in algs:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, alpha=0.7, markevery=(i*500,400))
    i+=1

plt.legend(ncol=1)
plt.ylabel("$R_T / L$")
plt.title("Ours ($L = %s$)"%L)

plt.sca(axes[1][0])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
for bandit in algs:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.historylength.reset_index(drop=True)/L
    cumsum.plot(label=prettynames[bandit],linewidth=1, alpha=0.7, markevery=(i*500,400))
    i+=1
plt.legend(ncol=1)
plt.ylabel("Window size")
plt.title("Ours ($L = %s$)"%L)

L = 1

plt.sca(axes[0][1])

i = 0

subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]

for bandit in algs:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "CustomOracle"].gain.cumsum().reset_index(drop=True)
for bandit in algs:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, alpha=0.7, markevery=(i*500,400), color=colors[i])
    i+=1

plt.legend(ncol=1)
plt.ylabel("$R_T / L$")
plt.title("Ours ($L = %s$)"%L)

plt.sca(axes[1][1])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
for bandit in algs:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.historylength.reset_index(drop=True)/L
    cumsum.plot(label=prettynames[bandit],linewidth=1, alpha=0.7, markevery=(i*500,400), color=colors[i])
    i+=1
plt.legend(ncol=1)
plt.ylabel("Window size")
plt.title("Ours ($L = %s$)"%L)

plt.tight_layout()
plt.savefig("plots/ours_regret_abrupt_full.pdf")
