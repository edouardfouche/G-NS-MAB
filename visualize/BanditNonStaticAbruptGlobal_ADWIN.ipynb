# %%
import math

import matplotlib as mpl
mpl.rcParams['text.usetex'] = True 
mpl.rcParams['text.latex.preamble'] = [r'\usepackage{libertine}', r'\usepackage{newtxmath}'] 
mpl.rc('font', family='serif')

import numpy as np
import pandas as pd
import seaborn as sns


import matplotlib.pyplot as plt
from matplotlib import rc

from cycler import cycler


mpl.rcParams['ps.usedistiller'] = 'xpdf' 

plt.style.use('seaborn-notebook')
# sns.set_palette("Blues_r")

plt.rcParams['axes.titlesize'] = '25'
plt.rcParams['axes.labelsize'] = '25'
plt.rcParams['legend.fontsize'] = '15'
plt.rcParams['xtick.labelsize'] = '15'
plt.rcParams['ytick.labelsize'] = '15'

monochrome=(cycler('color', sns.color_palette("husl", 8))*2+(cycler('marker', ['v','<','^','>','o','s','p'])*7)[0:16])
plt.rc('axes', prop_cycle=monochrome)

pd.options.display.max_rows = 999
# Out:
# /var/folders/8v/5czrtjp134z_qn6j_jsmrnl80000gn/T/ipykernel_14066/1478693075.py:5: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   mpl.rcParams['text.latex.preamble'] = [r'\usepackage{libertine}', r'\usepackage{newtxmath}']
# /var/folders/8v/5czrtjp134z_qn6j_jsmrnl80000gn/T/ipykernel_14066/1478693075.py:21: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-notebook')

# %%
# Change if required
folder = "../experiments/2022-11-14-17-27_BanditNonStaticAbruptGlobal_ADWIN_"
dataset = "AbruptGlobal_ADWIN"

# %%
masterdata = pd.read_csv("%s/BanditNonStaticAbruptGlobal_ADWIN.csv"%folder, sep=",")
narms = masterdata.iloc[0]['k']

# %%
sorted(masterdata.bandit.unique())
# Out:
# ['CustomOracle',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=0.001',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=0.01',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=0.1',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-12',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-15',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-6',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-7',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-8',
#  'MP-ADS-KL-UCB-ADWIN1; d=0.001; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=0.001; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=0.01; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=0.01; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=0.1; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=0.1; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-15; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-15; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-5; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-5; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-7; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-7; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=true',
#  'MP-ADS-TS-ADWIN1; d=0.001; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.001; r=true',
#  'MP-ADS-TS-ADWIN1; d=0.01; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.01; r=true',
#  'MP-ADS-TS-ADWIN1; d=0.1; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.1; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-12; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-12; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-15; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-15; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-4; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-4; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-5; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-5; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-6; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-6; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-7; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-7; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-8; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-8; r=true',
#  'OD',
#  'OR',
#  'OS']

# %%
sorted(masterdata.dataset.unique())
# Out:
# ['AbruptGlobalGenerator-100']

# %%
masterdata.columns
# Out:
# Index(['bandit', 'dataset', 'scalingstrategy', 'k', 'gain', 'cputime',
#        'historylength', 'iteration'],
#       dtype='object')

# %%
masterdata['reward/arm'] = masterdata['gain']/masterdata['k']

# %%
masterdata.shape
# Out:
# (540000, 9)

# %%
masterdata.groupby(["scalingstrategy", "bandit", "dataset"])[['gain', 'k', 'reward/arm', 'cputime']].mean()
# Out:
#                                                                                         gain  \
# scalingstrategy bandit                                   dataset
# No-1            CustomOracle                             AbruptGlobalGenerator-100  0.996613
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001   AbruptGlobalGenerator-100  0.687323
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    AbruptGlobalGenerator-100  0.686992
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     AbruptGlobalGenerator-100  0.636530
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-12 AbruptGlobalGenerator-100  0.731082
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-15 AbruptGlobalGenerator-100  0.746730
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  AbruptGlobalGenerator-100  0.684361
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  AbruptGlobalGenerator-100  0.681906
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-6  AbruptGlobalGenerator-100  0.693934
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-7  AbruptGlobalGenerator-100  0.695213
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-8  AbruptGlobalGenerator-100  0.694951
#                 MP-ADS-KL-UCB-ADWIN1; d=0.001; r=false   AbruptGlobalGenerator-100  0.963704
#                 MP-ADS-KL-UCB-ADWIN1; d=0.001; r=true    AbruptGlobalGenerator-100  0.964490
#                 MP-ADS-KL-UCB-ADWIN1; d=0.01; r=false    AbruptGlobalGenerator-100  0.963532
#                 MP-ADS-KL-UCB-ADWIN1; d=0.01; r=true     AbruptGlobalGenerator-100  0.963623
#                 MP-ADS-KL-UCB-ADWIN1; d=0.1; r=false     AbruptGlobalGenerator-100  0.961217
#                 MP-ADS-KL-UCB-ADWIN1; d=0.1; r=true      AbruptGlobalGenerator-100  0.963184
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=false AbruptGlobalGenerator-100  0.961813
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=true  AbruptGlobalGenerator-100  0.961144
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-15; r=false AbruptGlobalGenerator-100  0.961285
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-15; r=true  AbruptGlobalGenerator-100  0.960569
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=false  AbruptGlobalGenerator-100  0.964336
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=true   AbruptGlobalGenerator-100  0.964261
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-5; r=false  AbruptGlobalGenerator-100  0.963459
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-5; r=true   AbruptGlobalGenerator-100  0.963131
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=false  AbruptGlobalGenerator-100  0.963124
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=true   AbruptGlobalGenerator-100  0.962734
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-7; r=false  AbruptGlobalGenerator-100  0.963455
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-7; r=true   AbruptGlobalGenerator-100  0.963460
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=false  AbruptGlobalGenerator-100  0.963140
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=true   AbruptGlobalGenerator-100  0.963123
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       AbruptGlobalGenerator-100  0.950357
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true        AbruptGlobalGenerator-100  0.955871
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        AbruptGlobalGenerator-100  0.949434
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         AbruptGlobalGenerator-100  0.955765
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         AbruptGlobalGenerator-100  0.950266
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true          AbruptGlobalGenerator-100  0.949333
#                 MP-ADS-TS-ADWIN1; d=1.0E-12; r=false     AbruptGlobalGenerator-100  0.949595
#                 MP-ADS-TS-ADWIN1; d=1.0E-12; r=true      AbruptGlobalGenerator-100  0.952367
#                 MP-ADS-TS-ADWIN1; d=1.0E-15; r=false     AbruptGlobalGenerator-100  0.950069
#                 MP-ADS-TS-ADWIN1; d=1.0E-15; r=true      AbruptGlobalGenerator-100  0.951141
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      AbruptGlobalGenerator-100  0.950732
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       AbruptGlobalGenerator-100  0.955473
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      AbruptGlobalGenerator-100  0.947867
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       AbruptGlobalGenerator-100  0.954841
#                 MP-ADS-TS-ADWIN1; d=1.0E-6; r=false      AbruptGlobalGenerator-100  0.949855
#                 MP-ADS-TS-ADWIN1; d=1.0E-6; r=true       AbruptGlobalGenerator-100  0.954819
#                 MP-ADS-TS-ADWIN1; d=1.0E-7; r=false      AbruptGlobalGenerator-100  0.949237
#                 MP-ADS-TS-ADWIN1; d=1.0E-7; r=true       AbruptGlobalGenerator-100  0.954273
#                 MP-ADS-TS-ADWIN1; d=1.0E-8; r=false      AbruptGlobalGenerator-100  0.950612
#                 MP-ADS-TS-ADWIN1; d=1.0E-8; r=true       AbruptGlobalGenerator-100  0.954127
#                 OD                                       AbruptGlobalGenerator-100  1.000000
#                 OR                                       AbruptGlobalGenerator-100  0.502852
#                 OS                                       AbruptGlobalGenerator-100  0.666700
#
#                                                                                       k  \
# scalingstrategy bandit                                   dataset
# No-1            CustomOracle                             AbruptGlobalGenerator-100  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001   AbruptGlobalGenerator-100  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    AbruptGlobalGenerator-100  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     AbruptGlobalGenerator-100  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-12 AbruptGlobalGenerator-100  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-15 AbruptGlobalGenerator-100  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  AbruptGlobalGenerator-100  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  AbruptGlobalGenerator-100  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-6  AbruptGlobalGenerator-100  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-7  AbruptGlobalGenerator-100  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-8  AbruptGlobalGenerator-100  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=0.001; r=false   AbruptGlobalGenerator-100  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=0.001; r=true    AbruptGlobalGenerator-100  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=0.01; r=false    AbruptGlobalGenerator-100  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=0.01; r=true     AbruptGlobalGenerator-100  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=0.1; r=false     AbruptGlobalGenerator-100  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=0.1; r=true      AbruptGlobalGenerator-100  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=false AbruptGlobalGenerator-100  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=true  AbruptGlobalGenerator-100  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-15; r=false AbruptGlobalGenerator-100  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-15; r=true  AbruptGlobalGenerator-100  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=false  AbruptGlobalGenerator-100  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=true   AbruptGlobalGenerator-100  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-5; r=false  AbruptGlobalGenerator-100  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-5; r=true   AbruptGlobalGenerator-100  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=false  AbruptGlobalGenerator-100  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=true   AbruptGlobalGenerator-100  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-7; r=false  AbruptGlobalGenerator-100  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-7; r=true   AbruptGlobalGenerator-100  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=false  AbruptGlobalGenerator-100  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=true   AbruptGlobalGenerator-100  1.0
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       AbruptGlobalGenerator-100  1.0
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true        AbruptGlobalGenerator-100  1.0
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        AbruptGlobalGenerator-100  1.0
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         AbruptGlobalGenerator-100  1.0
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         AbruptGlobalGenerator-100  1.0
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true          AbruptGlobalGenerator-100  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-12; r=false     AbruptGlobalGenerator-100  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-12; r=true      AbruptGlobalGenerator-100  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-15; r=false     AbruptGlobalGenerator-100  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-15; r=true      AbruptGlobalGenerator-100  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      AbruptGlobalGenerator-100  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       AbruptGlobalGenerator-100  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      AbruptGlobalGenerator-100  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       AbruptGlobalGenerator-100  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-6; r=false      AbruptGlobalGenerator-100  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-6; r=true       AbruptGlobalGenerator-100  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-7; r=false      AbruptGlobalGenerator-100  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-7; r=true       AbruptGlobalGenerator-100  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-8; r=false      AbruptGlobalGenerator-100  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-8; r=true       AbruptGlobalGenerator-100  1.0
#                 OD                                       AbruptGlobalGenerator-100  1.0
#                 OR                                       AbruptGlobalGenerator-100  1.0
#                 OS                                       AbruptGlobalGenerator-100  1.0
#
#                                                                                     reward/arm  \
# scalingstrategy bandit                                   dataset
# No-1            CustomOracle                             AbruptGlobalGenerator-100    0.996613
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001   AbruptGlobalGenerator-100    0.687323
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    AbruptGlobalGenerator-100    0.686992
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     AbruptGlobalGenerator-100    0.636530
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-12 AbruptGlobalGenerator-100    0.731082
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-15 AbruptGlobalGenerator-100    0.746730
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  AbruptGlobalGenerator-100    0.684361
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  AbruptGlobalGenerator-100    0.681906
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-6  AbruptGlobalGenerator-100    0.693934
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-7  AbruptGlobalGenerator-100    0.695213
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-8  AbruptGlobalGenerator-100    0.694951
#                 MP-ADS-KL-UCB-ADWIN1; d=0.001; r=false   AbruptGlobalGenerator-100    0.963704
#                 MP-ADS-KL-UCB-ADWIN1; d=0.001; r=true    AbruptGlobalGenerator-100    0.964490
#                 MP-ADS-KL-UCB-ADWIN1; d=0.01; r=false    AbruptGlobalGenerator-100    0.963532
#                 MP-ADS-KL-UCB-ADWIN1; d=0.01; r=true     AbruptGlobalGenerator-100    0.963623
#                 MP-ADS-KL-UCB-ADWIN1; d=0.1; r=false     AbruptGlobalGenerator-100    0.961217
#                 MP-ADS-KL-UCB-ADWIN1; d=0.1; r=true      AbruptGlobalGenerator-100    0.963184
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=false AbruptGlobalGenerator-100    0.961813
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=true  AbruptGlobalGenerator-100    0.961144
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-15; r=false AbruptGlobalGenerator-100    0.961285
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-15; r=true  AbruptGlobalGenerator-100    0.960569
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=false  AbruptGlobalGenerator-100    0.964336
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=true   AbruptGlobalGenerator-100    0.964261
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-5; r=false  AbruptGlobalGenerator-100    0.963459
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-5; r=true   AbruptGlobalGenerator-100    0.963131
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=false  AbruptGlobalGenerator-100    0.963124
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=true   AbruptGlobalGenerator-100    0.962734
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-7; r=false  AbruptGlobalGenerator-100    0.963455
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-7; r=true   AbruptGlobalGenerator-100    0.963460
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=false  AbruptGlobalGenerator-100    0.963140
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=true   AbruptGlobalGenerator-100    0.963123
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       AbruptGlobalGenerator-100    0.950357
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true        AbruptGlobalGenerator-100    0.955871
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        AbruptGlobalGenerator-100    0.949434
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         AbruptGlobalGenerator-100    0.955765
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         AbruptGlobalGenerator-100    0.950266
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true          AbruptGlobalGenerator-100    0.949333
#                 MP-ADS-TS-ADWIN1; d=1.0E-12; r=false     AbruptGlobalGenerator-100    0.949595
#                 MP-ADS-TS-ADWIN1; d=1.0E-12; r=true      AbruptGlobalGenerator-100    0.952367
#                 MP-ADS-TS-ADWIN1; d=1.0E-15; r=false     AbruptGlobalGenerator-100    0.950069
#                 MP-ADS-TS-ADWIN1; d=1.0E-15; r=true      AbruptGlobalGenerator-100    0.951141
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      AbruptGlobalGenerator-100    0.950732
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       AbruptGlobalGenerator-100    0.955473
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      AbruptGlobalGenerator-100    0.947867
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       AbruptGlobalGenerator-100    0.954841
#                 MP-ADS-TS-ADWIN1; d=1.0E-6; r=false      AbruptGlobalGenerator-100    0.949855
#                 MP-ADS-TS-ADWIN1; d=1.0E-6; r=true       AbruptGlobalGenerator-100    0.954819
#                 MP-ADS-TS-ADWIN1; d=1.0E-7; r=false      AbruptGlobalGenerator-100    0.949237
#                 MP-ADS-TS-ADWIN1; d=1.0E-7; r=true       AbruptGlobalGenerator-100    0.954273
#                 MP-ADS-TS-ADWIN1; d=1.0E-8; r=false      AbruptGlobalGenerator-100    0.950612
#                 MP-ADS-TS-ADWIN1; d=1.0E-8; r=true       AbruptGlobalGenerator-100    0.954127
#                 OD                                       AbruptGlobalGenerator-100    1.000000
#                 OR                                       AbruptGlobalGenerator-100    0.502852
#                 OS                                       AbruptGlobalGenerator-100    0.666700
#
#                                                                                      cputime
# scalingstrategy bandit                                   dataset
# No-1            CustomOracle                             AbruptGlobalGenerator-100  0.030257
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001   AbruptGlobalGenerator-100  0.280079
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    AbruptGlobalGenerator-100  0.375545
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     AbruptGlobalGenerator-100  0.331003
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-12 AbruptGlobalGenerator-100  0.411582
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-15 AbruptGlobalGenerator-100  0.427207
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  AbruptGlobalGenerator-100  0.345449
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  AbruptGlobalGenerator-100  0.370009
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-6  AbruptGlobalGenerator-100  0.380969
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-7  AbruptGlobalGenerator-100  0.302804
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-8  AbruptGlobalGenerator-100  0.374026
#                 MP-ADS-KL-UCB-ADWIN1; d=0.001; r=false   AbruptGlobalGenerator-100  0.234362
#                 MP-ADS-KL-UCB-ADWIN1; d=0.001; r=true    AbruptGlobalGenerator-100  0.336914
#                 MP-ADS-KL-UCB-ADWIN1; d=0.01; r=false    AbruptGlobalGenerator-100  0.332803
#                 MP-ADS-KL-UCB-ADWIN1; d=0.01; r=true     AbruptGlobalGenerator-100  0.309673
#                 MP-ADS-KL-UCB-ADWIN1; d=0.1; r=false     AbruptGlobalGenerator-100  0.226884
#                 MP-ADS-KL-UCB-ADWIN1; d=0.1; r=true      AbruptGlobalGenerator-100  0.301348
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=false AbruptGlobalGenerator-100  0.343251
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=true  AbruptGlobalGenerator-100  0.222647
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-15; r=false AbruptGlobalGenerator-100  0.319015
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-15; r=true  AbruptGlobalGenerator-100  0.224903
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=false  AbruptGlobalGenerator-100  0.312400
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=true   AbruptGlobalGenerator-100  0.294533
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-5; r=false  AbruptGlobalGenerator-100  0.226962
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-5; r=true   AbruptGlobalGenerator-100  0.316817
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=false  AbruptGlobalGenerator-100  0.269219
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=true   AbruptGlobalGenerator-100  0.336326
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-7; r=false  AbruptGlobalGenerator-100  0.344642
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-7; r=true   AbruptGlobalGenerator-100  0.218058
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=false  AbruptGlobalGenerator-100  0.291974
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=true   AbruptGlobalGenerator-100  0.330947
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       AbruptGlobalGenerator-100  0.300220
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true        AbruptGlobalGenerator-100  0.321508
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        AbruptGlobalGenerator-100  0.305987
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         AbruptGlobalGenerator-100  0.331050
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         AbruptGlobalGenerator-100  0.318432
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true          AbruptGlobalGenerator-100  0.294069
#                 MP-ADS-TS-ADWIN1; d=1.0E-12; r=false     AbruptGlobalGenerator-100  0.343839
#                 MP-ADS-TS-ADWIN1; d=1.0E-12; r=true      AbruptGlobalGenerator-100  0.338207
#                 MP-ADS-TS-ADWIN1; d=1.0E-15; r=false     AbruptGlobalGenerator-100  0.341609
#                 MP-ADS-TS-ADWIN1; d=1.0E-15; r=true      AbruptGlobalGenerator-100  0.317504
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      AbruptGlobalGenerator-100  0.337317
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       AbruptGlobalGenerator-100  0.310899
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      AbruptGlobalGenerator-100  0.325836
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       AbruptGlobalGenerator-100  0.258749
#                 MP-ADS-TS-ADWIN1; d=1.0E-6; r=false      AbruptGlobalGenerator-100  0.339478
#                 MP-ADS-TS-ADWIN1; d=1.0E-6; r=true       AbruptGlobalGenerator-100  0.326309
#                 MP-ADS-TS-ADWIN1; d=1.0E-7; r=false      AbruptGlobalGenerator-100  0.235468
#                 MP-ADS-TS-ADWIN1; d=1.0E-7; r=true       AbruptGlobalGenerator-100  0.216639
#                 MP-ADS-TS-ADWIN1; d=1.0E-8; r=false      AbruptGlobalGenerator-100  0.322669
#                 MP-ADS-TS-ADWIN1; d=1.0E-8; r=true       AbruptGlobalGenerator-100  0.342075
#                 OD                                       AbruptGlobalGenerator-100  0.121141
#                 OR                                       AbruptGlobalGenerator-100  0.057390
#                 OS                                       AbruptGlobalGenerator-100  0.010231

# %%
from matplotlib.markers import TICKLEFT, TICKRIGHT, TICKUP, TICKDOWN, CARETLEFT, CARETRIGHT, CARETUP, CARETDOWN
markers = [
#    '.',
#    ',',
    'v',
    '<',
    '^',
    '>',
    'o',
#    '1',
#    '2',
#    '3',
#    '4',
#    '8',
    's',
    'p',
    '*',
#    'h',
    'H',
    '+',
    'x',
    'D',
#    'd',
    '|',
    '_',
    TICKLEFT,
    TICKRIGHT,
    TICKUP,
    TICKDOWN,
    CARETLEFT,
    CARETRIGHT,
    CARETUP,
    CARETDOWN,
]

# %%
from matplotlib import cm
colors = [cm.Reds((i+2)/8.0) for i in range(8)] + [cm.Greens((i+2)/8.0) for i in range(8)]

# %%
algs = [    
    # ours 
#     'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5',
#     'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4',
#     'MP-ADR-Elimination-UCB-ADWIN1; d=0.001',
#     'MP-ADR-Elimination-UCB-ADWIN1; d=0.01',
#     'MP-ADR-Elimination-UCB-ADWIN1; d=0.1',
    
     'MP-ADS-TS-ADWIN1; d=0.1; r=false',
     'MP-ADS-TS-ADWIN1; d=0.01; r=false',
     'MP-ADS-TS-ADWIN1; d=0.001; r=false',
     'MP-ADS-TS-ADWIN1; d=1.0E-4; r=false',
     'MP-ADS-TS-ADWIN1; d=1.0E-6; r=false',
     'MP-ADS-TS-ADWIN1; d=1.0E-8; r=false',
     'MP-ADS-TS-ADWIN1; d=1.0E-12; r=false',
     'MP-ADS-TS-ADWIN1; d=1.0E-15; r=false',
#     'MP-ADS-TS-ADWIN1; d=1.0E-5; r=false',
    
     'MP-ADS-TS-ADWIN1; d=0.1; r=true',
     'MP-ADS-TS-ADWIN1; d=0.01; r=true',
     'MP-ADS-TS-ADWIN1; d=0.001; r=true',
     'MP-ADS-TS-ADWIN1; d=1.0E-4; r=true',
     'MP-ADS-TS-ADWIN1; d=1.0E-6; r=true',
     'MP-ADS-TS-ADWIN1; d=1.0E-8; r=true',
     'MP-ADS-TS-ADWIN1; d=1.0E-12; r=true',
     'MP-ADS-TS-ADWIN1; d=1.0E-15; r=true',
#    'MP-ADS-TS-ADWIN1; d=1.0E-5; r=true',
    
#     'MP-ADS-KL-UCB-ADWIN1; d=0.1; r=true',
#     'MP-ADS-KL-UCB-ADWIN1; d=0.01; r=true',
#     'MP-ADS-KL-UCB-ADWIN1; d=0.001; r=true',
#     'MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=true',
#     'MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=true',
#     'MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=true',
#     'MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=true',
]

# %%
prettynames = {
#     'MP-ADR-Elimination-UCB-ADWIN1; d=0.1':'ADR-Elimination-UCB; d=0.1',
#     'MP-ADR-Elimination-UCB-ADWIN1; d=0.01':'ADR-Elimination-UCB; d=0.01',
#     'MP-ADR-Elimination-UCB-ADWIN1; d=0.001':'ADR-Elimination-UCB; d=0.001',
#     'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4':'ADR-Elimination-UCB; d=1.0E-4',
#     'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5':'ADR-Elimination-UCB; d=1.0E-5',
    
     'MP-ADS-TS-ADWIN1; d=0.1; r=false':'ADS-TS; $\delta$=0.1',
     'MP-ADS-TS-ADWIN1; d=0.01; r=false':'ADS-TS; $\delta$=0.01',
     'MP-ADS-TS-ADWIN1; d=0.001; r=false':'ADS-TS; $\delta$=0.001',
     'MP-ADS-TS-ADWIN1; d=1.0E-4; r=false':'ADS-TS; $\delta$=1.0E-4',
     'MP-ADS-TS-ADWIN1; d=1.0E-6; r=false':'ADS-TS; $\delta$=1.0E-6',
     'MP-ADS-TS-ADWIN1; d=1.0E-8; r=false':'ADS-TS; $\delta$=1.0E-8',
     'MP-ADS-TS-ADWIN1; d=1.0E-12; r=false':'ADS-TS; $\delta$=1.0E-12',
     'MP-ADS-TS-ADWIN1; d=1.0E-15; r=false':'ADS-TS; $\delta$=1.0E-15',
#     'MP-ADS-TS-ADWIN1; d=1.0E-5; r=false':'ADS-TS; d=1.0E-5',
    
     'MP-ADS-TS-ADWIN1; d=0.1; r=true':'ADR-TS; $\delta$=0.1',
     'MP-ADS-TS-ADWIN1; d=0.01; r=true':'ADR-TS; $\delta$=0.01',
     'MP-ADS-TS-ADWIN1; d=0.001; r=true':'ADR-TS; $\delta$=0.001',
     'MP-ADS-TS-ADWIN1; d=1.0E-4; r=true':'ADR-TS; $\delta$=1.0E-4',
     'MP-ADS-TS-ADWIN1; d=1.0E-6; r=true':'ADR-TS; $\delta$=1.0E-6',
     'MP-ADS-TS-ADWIN1; d=1.0E-8; r=true':'ADR-TS; $\delta$=1.0E-8',
     'MP-ADS-TS-ADWIN1; d=1.0E-12; r=true':'ADR-TS; $\delta$=1.0E-12',
     'MP-ADS-TS-ADWIN1; d=1.0E-15; r=true':'ADR-TS; $\delta$=1.0E-15',
    
     'MP-ADS-KL-UCB-ADWIN1; d=0.1; r=true':'ADR-KL-UCB; $\delta$=0.1',
     'MP-ADS-KL-UCB-ADWIN1; d=0.01; r=true':'ADR-KL-UCB; $\delta$=0.01',
     'MP-ADS-KL-UCB-ADWIN1; d=0.001; r=true':'ADR-KL-UCB; $\delta$=0.001',
     'MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=true':'ADR-KL-UCB; $\delta$=1.0E-4',
     'MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=true':'ADR-KL-UCB; $\delta$=1.0E-6',
     'MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=true':'ADR-KL-UCB; $\delta$=1.0E-8',
     'MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=true':'ADR-KL-UCB; $\delta$=1.0E-12',
     'MP-ADS-KL-UCB-ADWIN1; d=1.0E-15; r=true':'ADR-KL-UCB; $\delta$=1.0E-15',
    
     'MP-ADS-KL-UCB-ADWIN1; d=0.1; r=false':'ADS-KL-UCB; $\delta$=0.1',
     'MP-ADS-KL-UCB-ADWIN1; d=0.01; r=false':'ADS-KL-UCB; $\delta$=0.01',
     'MP-ADS-KL-UCB-ADWIN1; d=0.001; r=false':'ADS-KL-UCB; $\delta$=0.001',
     'MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=false':'ADS-KL-UCB; $\delta$=1.0E-4',
     'MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=false':'ADS-KL-UCB; $\delta$=1.0E-6',
     'MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=false':'ADS-KL-UCB; $\delta$=1.0E-8',
     'MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=false':'ADS-KL-UCB; $\delta$=1.0E-12',
     'MP-ADS-KL-UCB-ADWIN1; d=1.0E-15; r=false':'ADS-KL-UCB; $\delta$=1.0E-15',
    
    
    
#    'MP-ADS-TS-ADWIN1; d=1.0E-5; r=true':'ADR-TS; d=1.0E-5',
}

# %%
# compute regret against 'OD', or just the cumulative rewards

# %%
fig, axes = plt.subplots(1, 2, sharex=True, figsize=(15,7))

L = 1

plt.sca(axes[0])

i = 0

subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]

for bandit in algs:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "CustomOracle"].gain.cumsum().reset_index(drop=True)
for bandit in algs:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, alpha=0.7, markevery=(i*500,400), color=colors[i])
    i+=1

plt.legend(ncol=1)
plt.ylabel("$R_T / L$")
plt.title("Ours ($L = %s$)"%L)

plt.sca(axes[1])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
for bandit in algs:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.historylength.reset_index(drop=True)/L
    cumsum.plot(label=prettynames[bandit],linewidth=1, alpha=0.7, markevery=(i*500,400), color=colors[i])
    i+=1
plt.legend(ncol=1)
plt.ylabel("Window size")
plt.title("Ours ($L = %s$)"%L)

plt.tight_layout()
plt.savefig("plots/ours_regret_abrupt_full.pdf")

# %%
algs = [    
    # ours 
#     'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5',
#     'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4',
#     'MP-ADR-Elimination-UCB-ADWIN1; d=0.001',
#     'MP-ADR-Elimination-UCB-ADWIN1; d=0.01',
#     'MP-ADR-Elimination-UCB-ADWIN1; d=0.1',
    
    # 'MP-ADS-TS-ADWIN1; d=0.1; r=false',
    # 'MP-ADS-TS-ADWIN1; d=0.01; r=false',
    # 'MP-ADS-TS-ADWIN1; d=0.001; r=false',
    # 'MP-ADS-TS-ADWIN1; d=1.0E-4; r=false',
    # 'MP-ADS-TS-ADWIN1; d=1.0E-6; r=false',
    # 'MP-ADS-TS-ADWIN1; d=1.0E-8; r=false',
    # 'MP-ADS-TS-ADWIN1; d=1.0E-12; r=false',
    
    # 'MP-ADS-TS-ADWIN1; d=0.1; r=true',
    # 'MP-ADS-TS-ADWIN1; d=0.01; r=true',
    # 'MP-ADS-TS-ADWIN1; d=0.001; r=true',
    # 'MP-ADS-TS-ADWIN1; d=1.0E-4; r=true',
    # 'MP-ADS-TS-ADWIN1; d=1.0E-6; r=true',
    # 'MP-ADS-TS-ADWIN1; d=1.0E-8; r=true',
    # 'MP-ADS-TS-ADWIN1; d=1.0E-12; r=true',
    
     'MP-ADS-KL-UCB-ADWIN1; d=0.1; r=false',
     'MP-ADS-KL-UCB-ADWIN1; d=0.01; r=false',
     'MP-ADS-KL-UCB-ADWIN1; d=0.001; r=false',
     'MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=false',
     'MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=false',
     'MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=false',
     'MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=false',
     'MP-ADS-KL-UCB-ADWIN1; d=1.0E-15; r=false',
    
     'MP-ADS-KL-UCB-ADWIN1; d=0.1; r=true',
     'MP-ADS-KL-UCB-ADWIN1; d=0.01; r=true',
     'MP-ADS-KL-UCB-ADWIN1; d=0.001; r=true',
     'MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=true',
     'MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=true',
     'MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=true',
     'MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=true',
     'MP-ADS-KL-UCB-ADWIN1; d=1.0E-15; r=true',
]

# %%
fig, axes = plt.subplots(1, 2, sharex=True, figsize=(15,7))

L = 1

plt.sca(axes[0])

i = 0

subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]

for bandit in algs:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "CustomOracle"].gain.cumsum().reset_index(drop=True)
for bandit in algs:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, alpha=0.7, markevery=(i*500,400), color=colors[i])
    i+=1

plt.legend(ncol=1)
plt.ylabel("$R_T / L$")
plt.title("Ours ($L = %s$)"%L)

plt.sca(axes[1])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
for bandit in algs:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.historylength.reset_index(drop=True)/L
    cumsum.plot(label=prettynames[bandit],linewidth=1, alpha=0.7, markevery=(i*500,400), color=colors[i])
    i+=1
plt.legend(ncol=1)
plt.ylabel("Window size")
plt.title("Ours ($L = %s$)"%L)

plt.tight_layout()
plt.savefig("plots/ours_regret_abrupt_full_KL_UCB.pdf")
