# %%
import math

import matplotlib as mpl
mpl.rcParams['text.usetex'] = True 
mpl.rcParams['text.latex.preamble'] = [r'\usepackage{libertine}', r'\usepackage{newtxmath}'] 
mpl.rc('font', family='serif')

import numpy as np
import pandas as pd
import seaborn as sns


import matplotlib.pyplot as plt
from matplotlib import rc

from cycler import cycler


mpl.rcParams['ps.usedistiller'] = 'xpdf' 

plt.style.use('seaborn-notebook')
# sns.set_palette("Blues_r")

plt.rcParams['axes.titlesize'] = '25'
plt.rcParams['axes.labelsize'] = '25'
plt.rcParams['legend.fontsize'] = '15'
plt.rcParams['xtick.labelsize'] = '15'
plt.rcParams['ytick.labelsize'] = '15'

monochrome=(cycler('color', sns.color_palette("husl", 8))*2+(cycler('marker', ['v', 's', "o"])*7)[0:16])
plt.rc('axes', prop_cycle=monochrome)

pd.options.display.max_rows = 999
# Out:
# <ipython-input-1-56d1c1821bb1>:5: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   mpl.rcParams['text.latex.preamble'] = [r'\usepackage{libertine}', r'\usepackage{newtxmath}']

# %%
# Change if required
folder = "../experiments/2021-06-30-18-13_BanditRealWorld_Zozo_unif_"
dataset = "BanditRealWorld-Zozo-unif"

# %%
masterdata = pd.read_csv("%s/BanditRealWorld_Zozo_unif.csv"%folder, sep=",")
narms = masterdata.iloc[0]['k']

# %%
sorted(masterdata.bandit.unique())
# Out:
# ['MP-ADR-Elimination-UCB-ADWIN1; d=0.001',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=0.01',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=0.1',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5',
#  'MP-ADS-TS-ADWIN1; d=0.001; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.001; r=true',
#  'MP-ADS-TS-ADWIN1; d=0.01; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.01; r=true',
#  'MP-ADS-TS-ADWIN1; d=0.1; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.1; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-4; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-4; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-5; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-5; r=true',
#  'MP-D-TS; g=0.7',
#  'MP-D-TS; g=0.8',
#  'MP-D-TS; g=0.9',
#  'MP-D-TS; g=0.99',
#  'MP-D-UCB; g=0.7',
#  'MP-D-UCB; g=0.8',
#  'MP-D-UCB; g=0.9',
#  'MP-D-UCB; g=0.99',
#  'MP-E-G; e=0.7',
#  'MP-E-G; e=0.8',
#  'MP-E-G; e=0.9',
#  'MP-E-G; e=0.99',
#  'MP-GLR-KL-UCB-G',
#  'MP-GLR-KL-UCB-G-F',
#  'MP-GLR-KL-UCB-L',
#  'MP-GLR-KL-UCB-L-F',
#  'MP-KLUCB',
#  'MP-M-UCB; w=1000; m=10',
#  'MP-M-UCB; w=1000; m=100',
#  'MP-M-UCB; w=5000; m=10',
#  'MP-M-UCB; w=5000; m=100',
#  'MP-RExp3; b=100.0',
#  'MP-RExp3; b=1000.0',
#  'MP-RExp3; b=500.0',
#  'MP-RExp3; b=5000.0',
#  'MP-SW-TS; w=100',
#  'MP-SW-TS; w=1000',
#  'MP-SW-TS; w=500',
#  'MP-SW-TS; w=5000',
#  'MP-SW-UCB#-A; nu=0.1; l=12.3',
#  'MP-SW-UCB#-A; nu=0.2; l=12.3',
#  'MP-SW-UCB#-G; ka=0.1; l=4.3',
#  'MP-SW-UCB#-G; ka=0.2; l=4.3',
#  'MP-SW-UCB; w=100',
#  'MP-SW-UCB; w=1000',
#  'MP-SW-UCB; w=500',
#  'MP-SW-UCB; w=5000',
#  'MP-TS',
#  'OD',
#  'OR',
#  'OS']

# %%
masterdata['reward/arm'] = masterdata['gain']/masterdata['k']

# %%
masterdata.shape
# Out:
# (2257920, 8)

# %%
masterdata.groupby(["scalingstrategy", "bandit"])[['gain', 'k', 'reward/arm', 'cputime']].mean()
# Out:
#                                                              gain           k  \
# scalingstrategy bandit
# No-1            MP-ADR-Elimination-UCB-ADWIN1; d=0.001   0.015520   17.718828
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    0.015609   17.822374
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     0.015634   17.234388
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  0.015763   17.995321
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  0.015230   17.884877
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       0.017327   12.492022
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true        0.017269   12.009642
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        0.017450   12.059822
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         0.017356   12.005873
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         0.016962   11.653398
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true          0.017110   11.402454
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      0.017348   12.299624
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       0.017365   12.171942
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      0.017266   11.939379
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       0.017540   12.230719
#                 MP-D-TS; g=0.7                           0.015327   10.702479
#                 MP-D-TS; g=0.8                           0.015852   10.679809
#                 MP-D-TS; g=0.9                           0.016622   11.089031
#                 MP-D-TS; g=0.99                          0.019049   17.545666
#                 MP-D-UCB; g=0.7                          0.015949   16.374260
#                 MP-D-UCB; g=0.8                          0.015984   16.639741
#                 MP-D-UCB; g=0.9                          0.016153   16.623353
#                 MP-D-UCB; g=0.99                         0.015931   16.795543
#                 MP-E-G; e=0.7                            0.017824   13.977410
#                 MP-E-G; e=0.8                            0.018355   16.246068
#                 MP-E-G; e=0.9                            0.018600   19.437689
#                 MP-E-G; e=0.99                           0.018270   31.606475
#                 MP-GLR-KL-UCB-G                          0.016440   18.098009
#                 MP-GLR-KL-UCB-G-F                        0.016512   16.640602
#                 MP-GLR-KL-UCB-L                          0.016461   19.553542
#                 MP-GLR-KL-UCB-L-F                        0.016801   19.601049
#                 MP-KLUCB                                 0.006944   73.875000
#                 MP-M-UCB; w=1000; m=10                   0.003671   75.043750
#                 MP-M-UCB; w=1000; m=100                  0.003671   75.043750
#                 MP-M-UCB; w=5000; m=10                   0.003671   75.043750
#                 MP-M-UCB; w=5000; m=100                  0.003671   75.043750
#                 MP-RExp3; b=100.0                        0.015999   11.752664
#                 MP-RExp3; b=1000.0                       0.016339   11.757932
#                 MP-RExp3; b=500.0                        0.015961   11.740071
#                 MP-RExp3; b=5000.0                       0.015998   11.745566
#                 MP-SW-TS; w=100                          0.016534   12.131690
#                 MP-SW-TS; w=1000                         0.016255   10.855624
#                 MP-SW-TS; w=500                          0.016955   12.170552
#                 MP-SW-TS; w=5000                         0.017532   12.251180
#                 MP-SW-UCB#-A; nu=0.1; l=12.3             0.015388   15.722607
#                 MP-SW-UCB#-A; nu=0.2; l=12.3             0.015519   15.260895
#                 MP-SW-UCB#-G; ka=0.1; l=4.3              0.014254   12.441288
#                 MP-SW-UCB#-G; ka=0.2; l=4.3              0.014879   14.704483
#                 MP-SW-UCB; w=100                         0.015166   15.301388
#                 MP-SW-UCB; w=1000                        0.016705   17.412125
#                 MP-SW-UCB; w=500                         0.016643   16.275578
#                 MP-SW-UCB; w=5000                        0.017043   16.758099
#                 MP-TS                                    0.017414   12.005824
#                 OD                                       0.047718    7.187500
#                 OR                                       0.014860   10.331299
#                 OS                                       0.011012   68.591071
# No-10           MP-ADR-Elimination-UCB-ADWIN1; d=0.001   0.000000  999.901786
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    0.000000  999.901786
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     0.000000  999.901786
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  0.000000  999.901786
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  0.000000  999.901786
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       0.000000  999.901786
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true        0.000000  999.901786
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        0.000000  999.901786
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         0.000000  999.901786
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         0.000000  999.901786
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true          0.000000  999.901786
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      0.000000  999.901786
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       0.000000  999.901786
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      0.000000  999.901786
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       0.000000  999.901786
#                 MP-D-TS; g=0.7                           0.000000  999.901786
#                 MP-D-TS; g=0.8                           0.000000  999.901786
#                 MP-D-TS; g=0.9                           0.000000  999.901786
#                 MP-D-TS; g=0.99                          0.000000  999.901786
#                 MP-D-UCB; g=0.7                          0.000000  999.901786
#                 MP-D-UCB; g=0.8                          0.000000  999.901786
#                 MP-D-UCB; g=0.9                          0.000000  999.901786
#                 MP-D-UCB; g=0.99                         0.000000  999.901786
#                 MP-E-G; e=0.7                            0.000000  999.901786
#                 MP-E-G; e=0.8                            0.000000  999.901786
#                 MP-E-G; e=0.9                            0.000000  999.901786
#                 MP-E-G; e=0.99                           0.000000  999.901786
#                 MP-GLR-KL-UCB-G                          0.000000  999.901786
#                 MP-GLR-KL-UCB-G-F                        0.000000  999.901786
#                 MP-GLR-KL-UCB-L                          0.000000  999.901786
#                 MP-GLR-KL-UCB-L-F                        0.000000  999.901786
#                 MP-KLUCB                                 0.000000  999.901786
#                 MP-M-UCB; w=1000; m=10                   0.000000  999.901786
#                 MP-M-UCB; w=1000; m=100                  0.000000  999.901786
#                 MP-M-UCB; w=5000; m=10                   0.000000  999.901786
#                 MP-M-UCB; w=5000; m=100                  0.000000  999.901786
#                 MP-RExp3; b=100.0                        0.000000  999.901786
#                 MP-RExp3; b=1000.0                       0.000000  999.901786
#                 MP-RExp3; b=500.0                        0.000000  999.901786
#                 MP-RExp3; b=5000.0                       0.000000  999.901786
#                 MP-SW-TS; w=100                          0.000000  999.901786
#                 MP-SW-TS; w=1000                         0.000000  999.901786
#                 MP-SW-TS; w=500                          0.000000  999.901786
#                 MP-SW-TS; w=5000                         0.000000  999.901786
#                 MP-SW-UCB#-A; nu=0.1; l=12.3             0.000000  999.901786
#                 MP-SW-UCB#-A; nu=0.2; l=12.3             0.000000  999.901786
#                 MP-SW-UCB#-G; ka=0.1; l=4.3              0.000000  999.901786
#                 MP-SW-UCB#-G; ka=0.2; l=4.3              0.000000  999.901786
#                 MP-SW-UCB; w=100                         0.000000  999.901786
#                 MP-SW-UCB; w=1000                        0.000000  999.901786
#                 MP-SW-UCB; w=500                         0.000000  999.901786
#                 MP-SW-UCB; w=5000                        0.000000  999.901786
#                 MP-TS                                    0.000000  999.901786
#                 OD                                       0.000000  999.901786
#                 OR                                       0.000000  999.901786
#                 OS                                       0.000000  999.901786
# No-2            MP-ADR-Elimination-UCB-ADWIN1; d=0.001   0.023308   89.970526
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    0.023090   89.060640
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     0.024385   88.860826
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  0.024140   88.888807
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  0.023986   89.193661
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       0.026200   82.853440
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true        0.026113   82.521928
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        0.026550   83.477528
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         0.026502   82.116696
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         0.027169   83.042079
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true          0.026761   81.588420
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      0.026410   84.670973
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       0.026685   83.996667
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      0.026126   82.529915
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       0.026395   83.110941
#                 MP-D-TS; g=0.7                           0.025782   76.419680
#                 MP-D-TS; g=0.8                           0.025156   78.643336
#                 MP-D-TS; g=0.9                           0.025312   83.442130
#                 MP-D-TS; g=0.99                          0.027277   94.150439
#                 MP-D-UCB; g=0.7                          0.023955   88.344210
#                 MP-D-UCB; g=0.8                          0.024211   88.114687
#                 MP-D-UCB; g=0.9                          0.023265   88.592239
#                 MP-D-UCB; g=0.99                         0.024197   88.487182
#                 MP-E-G; e=0.7                            0.026429   94.907043
#                 MP-E-G; e=0.8                            0.026532   97.072397
#                 MP-E-G; e=0.9                            0.025480  102.831172
#                 MP-E-G; e=0.99                           0.021998  120.275446
#                 MP-GLR-KL-UCB-G                          0.025059   90.147205
#                 MP-GLR-KL-UCB-G-F                        0.025022   86.952008
#                 MP-GLR-KL-UCB-L                          0.024820   91.332124
#                 MP-GLR-KL-UCB-L-F                        0.025139   91.774168
#                 MP-KLUCB                                 0.003869  180.710714
#                 MP-M-UCB; w=1000; m=10                   0.022440   93.428727
#                 MP-M-UCB; w=1000; m=100                  0.023499   93.006908
#                 MP-M-UCB; w=5000; m=10                   0.023187   93.131020
#                 MP-M-UCB; w=5000; m=100                  0.023252   93.602909
#                 MP-RExp3; b=100.0                        0.026125   79.299458
#                 MP-RExp3; b=1000.0                       0.026057   79.644229
#                 MP-RExp3; b=500.0                        0.026160   79.624203
#                 MP-RExp3; b=5000.0                       0.025949   79.742878
#                 MP-SW-TS; w=100                          0.025567   92.358546
#                 MP-SW-TS; w=1000                         0.026048   81.989057
#                 MP-SW-TS; w=500                          0.025733   77.487121
#                 MP-SW-TS; w=5000                         0.026074   82.206509
#                 MP-SW-UCB#-A; nu=0.1; l=12.3             0.023468   86.836627
#                 MP-SW-UCB#-A; nu=0.2; l=12.3             0.024627   86.285776
#                 MP-SW-UCB#-G; ka=0.1; l=4.3              0.023186   80.669524
#                 MP-SW-UCB#-G; ka=0.2; l=4.3              0.023987   85.185259
#                 MP-SW-UCB; w=100                         0.023709   91.409269
#                 MP-SW-UCB; w=1000                        0.024553   88.499947
#                 MP-SW-UCB; w=500                         0.024086   88.182408
#                 MP-SW-UCB; w=5000                        0.024965   88.262812
#                 MP-TS                                    0.026525   82.821689
#                 OD                                       0.046925   41.560714
#                 OR                                       0.024404   74.753457
#                 OS                                       0.005357  177.410714
# No-5            MP-ADR-Elimination-UCB-ADWIN1; d=0.001   0.010228  469.139632
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    0.010665  469.305047
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     0.010705  469.413220
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  0.011021  469.850886
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  0.010592  469.537136
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       0.011361  466.169804
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true        0.011273  467.511843
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        0.010765  466.554000
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         0.011207  466.800456
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         0.011247  467.522092
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true          0.011301  465.816435
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      0.010779  466.656696
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       0.010889  466.356405
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      0.010091  467.750841
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       0.010822  466.662003
#                 MP-D-TS; g=0.7                           0.011420  467.280108
#                 MP-D-TS; g=0.8                           0.011092  468.277453
#                 MP-D-TS; g=0.9                           0.010042  467.806985
#                 MP-D-TS; g=0.99                          0.011192  467.745961
#                 MP-D-UCB; g=0.7                          0.010534  468.703545
#                 MP-D-UCB; g=0.8                          0.010653  468.459867
#                 MP-D-UCB; g=0.9                          0.010480  469.221119
#                 MP-D-UCB; g=0.99                         0.011826  468.859665
#                 MP-E-G; e=0.7                            0.010414  468.989098
#                 MP-E-G; e=0.8                            0.010073  470.219096
#                 MP-E-G; e=0.9                            0.008890  473.152196
#                 MP-E-G; e=0.99                           0.005485  484.842056
#                 MP-GLR-KL-UCB-G                          0.010409  469.179449
#                 MP-GLR-KL-UCB-G-F                        0.010697  468.263007
#                 MP-GLR-KL-UCB-L                          0.010565  468.661686
#                 MP-GLR-KL-UCB-L-F                        0.010937  468.925828
#                 MP-KLUCB                                 0.000794  496.464286
#                 MP-M-UCB; w=1000; m=10                   0.011606  468.584245
#                 MP-M-UCB; w=1000; m=100                  0.010222  469.790964
#                 MP-M-UCB; w=5000; m=10                   0.011107  468.468124
#                 MP-M-UCB; w=5000; m=100                  0.010288  469.617380
#                 MP-RExp3; b=100.0                        0.008766  470.438186
#                 MP-RExp3; b=1000.0                       0.008351  470.661626
#                 MP-RExp3; b=500.0                        0.009519  470.490494
#                 MP-RExp3; b=5000.0                       0.009509  470.345392
#                 MP-SW-TS; w=100                          0.010735  467.297178
#                 MP-SW-TS; w=1000                         0.010832  467.579758
#                 MP-SW-TS; w=500                          0.009794  466.551363
#                 MP-SW-TS; w=5000                         0.010877  467.345003
#                 MP-SW-UCB#-A; nu=0.1; l=12.3             0.010428  468.607985
#                 MP-SW-UCB#-A; nu=0.2; l=12.3             0.010810  469.142312
#                 MP-SW-UCB#-G; ka=0.1; l=4.3              0.009965  469.850496
#                 MP-SW-UCB#-G; ka=0.2; l=4.3              0.010107  468.639676
#                 MP-SW-UCB; w=100                         0.010863  469.279736
#                 MP-SW-UCB; w=1000                        0.010591  468.830497
#                 MP-SW-UCB; w=500                         0.010686  468.840971
#                 MP-SW-UCB; w=5000                        0.010909  469.391764
#                 MP-TS                                    0.011283  466.911497
#                 OD                                       0.021726  388.575893
#                 OR                                       0.011486  467.284033
#                 OS                                       0.000694  496.660714
#
#                                                          reward/arm   cputime
# scalingstrategy bandit
# No-1            MP-ADR-Elimination-UCB-ADWIN1; d=0.001     0.004856  0.250919
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01      0.004893  0.260450
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1       0.004914  0.309970
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4    0.004950  0.253261
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5    0.004838  0.251586
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false         0.006789  0.210851
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true          0.006587  0.199177
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false          0.006696  0.203367
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true           0.006652  0.198494
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false           0.006463  0.194599
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true            0.006465  0.184536
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false        0.006701  0.208340
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true         0.006597  0.200484
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false        0.006531  0.204728
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true         0.006659  0.200500
#                 MP-D-TS; g=0.7                             0.005214  0.155854
#                 MP-D-TS; g=0.8                             0.005586  0.152678
#                 MP-D-TS; g=0.9                             0.006148  0.159566
#                 MP-D-TS; g=0.99                            0.008161  0.248231
#                 MP-D-UCB; g=0.7                            0.005155  0.292389
#                 MP-D-UCB; g=0.8                            0.005160  0.296015
#                 MP-D-UCB; g=0.9                            0.005225  0.295560
#                 MP-D-UCB; g=0.99                           0.004955  0.299113
#                 MP-E-G; e=0.7                              0.007343  0.105803
#                 MP-E-G; e=0.8                              0.007466  0.122019
#                 MP-E-G; e=0.9                              0.007918  0.144673
#                 MP-E-G; e=0.99                             0.008721  0.232986
#                 MP-GLR-KL-UCB-G                            0.005866  0.456025
#                 MP-GLR-KL-UCB-G-F                          0.005837  0.525542
#                 MP-GLR-KL-UCB-L                            0.006085  0.648034
#                 MP-GLR-KL-UCB-L-F                          0.006043  0.630046
#                 MP-KLUCB                                   0.006944  1.551540
#                 MP-M-UCB; w=1000; m=10                     0.003671  0.977816
#                 MP-M-UCB; w=1000; m=100                    0.003671  0.993318
#                 MP-M-UCB; w=5000; m=10                     0.003671  0.989728
#                 MP-M-UCB; w=5000; m=100                    0.003671  0.989085
#                 MP-RExp3; b=100.0                          0.005758  0.130500
#                 MP-RExp3; b=1000.0                         0.005895  0.129830
#                 MP-RExp3; b=500.0                          0.005786  0.129506
#                 MP-RExp3; b=5000.0                         0.005774  0.129684
#                 MP-SW-TS; w=100                            0.006560  0.149117
#                 MP-SW-TS; w=1000                           0.005938  0.127007
#                 MP-SW-TS; w=500                            0.006818  0.143795
#                 MP-SW-TS; w=5000                           0.006787  0.140386
#                 MP-SW-UCB#-A; nu=0.1; l=12.3               0.004927  0.214705
#                 MP-SW-UCB#-A; nu=0.2; l=12.3               0.004868  0.202714
#                 MP-SW-UCB#-G; ka=0.1; l=4.3                0.004656  0.162445
#                 MP-SW-UCB#-G; ka=0.2; l=4.3                0.004623  0.187768
#                 MP-SW-UCB; w=100                           0.004735  0.197921
#                 MP-SW-UCB; w=1000                          0.005372  0.221554
#                 MP-SW-UCB; w=500                           0.005536  0.206717
#                 MP-SW-UCB; w=5000                          0.005579  0.212249
#                 MP-TS                                      0.006672  0.136120
#                 OD                                         0.047718  0.077125
#                 OR                                         0.004991  0.058473
#                 OS                                         0.011012  0.219695
# No-10           MP-ADR-Elimination-UCB-ADWIN1; d=0.001     0.000000  2.949481
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01      0.000000  2.986435
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1       0.000000  2.995731
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4    0.000000  2.121473
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5    0.000000  1.880543
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false         0.000000  1.360506
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true          0.000000  1.358927
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false          0.000000  1.358432
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true           0.000000  1.356717
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false           0.000000  1.353484
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true            0.000000  1.358284
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false        0.000000  1.355775
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true         0.000000  1.344565
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false        0.000000  1.355066
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true         0.000000  1.347261
#                 MP-D-TS; g=0.7                             0.000000  1.600916
#                 MP-D-TS; g=0.8                             0.000000  1.605115
#                 MP-D-TS; g=0.9                             0.000000  1.596242
#                 MP-D-TS; g=0.99                            0.000000  1.629082
#                 MP-D-UCB; g=0.7                            0.000000  2.019355
#                 MP-D-UCB; g=0.8                            0.000000  2.035878
#                 MP-D-UCB; g=0.9                            0.000000  2.027862
#                 MP-D-UCB; g=0.99                           0.000000  2.056264
#                 MP-E-G; e=0.7                              0.000000  1.072894
#                 MP-E-G; e=0.8                              0.000000  1.034082
#                 MP-E-G; e=0.9                              0.000000  1.009499
#                 MP-E-G; e=0.99                             0.000000  0.966552
#                 MP-GLR-KL-UCB-G                            0.000000  2.483715
#                 MP-GLR-KL-UCB-G-F                          0.000000  2.487695
#                 MP-GLR-KL-UCB-L                            0.000000  2.476921
#                 MP-GLR-KL-UCB-L-F                          0.000000  2.590569
#                 MP-KLUCB                                   0.000000  1.523541
#                 MP-M-UCB; w=1000; m=10                     0.000000  1.554198
#                 MP-M-UCB; w=1000; m=100                    0.000000  1.553742
#                 MP-M-UCB; w=5000; m=10                     0.000000  1.561570
#                 MP-M-UCB; w=5000; m=100                    0.000000  1.577182
#                 MP-RExp3; b=100.0                          0.000000  2.165601
#                 MP-RExp3; b=1000.0                         0.000000  2.061053
#                 MP-RExp3; b=500.0                          0.000000  2.164325
#                 MP-RExp3; b=5000.0                         0.000000  2.066036
#                 MP-SW-TS; w=100                            0.000000  1.369213
#                 MP-SW-TS; w=1000                           0.000000  1.380405
#                 MP-SW-TS; w=500                            0.000000  1.378461
#                 MP-SW-TS; w=5000                           0.000000  1.417047
#                 MP-SW-UCB#-A; nu=0.1; l=12.3               0.000000  1.636476
#                 MP-SW-UCB#-A; nu=0.2; l=12.3               0.000000  1.661916
#                 MP-SW-UCB#-G; ka=0.1; l=4.3                0.000000  1.624747
#                 MP-SW-UCB#-G; ka=0.2; l=4.3                0.000000  1.705379
#                 MP-SW-UCB; w=100                           0.000000  1.525476
#                 MP-SW-UCB; w=1000                          0.000000  1.523359
#                 MP-SW-UCB; w=500                           0.000000  1.513192
#                 MP-SW-UCB; w=5000                          0.000000  1.527599
#                 MP-TS                                      0.000000  1.340822
#                 OD                                         0.000000  1.125496
#                 OR                                         0.000000  0.812387
#                 OS                                         0.000000  0.521201
# No-2            MP-ADR-Elimination-UCB-ADWIN1; d=0.001     0.001715  0.947249
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01      0.001722  0.944162
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1       0.001733  0.963156
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4    0.001766  0.939093
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5    0.001728  0.858441
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false         0.002236  0.477162
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true          0.002250  0.476059
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false          0.002201  0.476720
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true           0.002287  0.474827
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false           0.002302  0.481797
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true            0.002216  0.469059
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false        0.002320  0.488253
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true         0.002299  0.484557
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false        0.002216  0.475254
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true         0.002204  0.477742
#                 MP-D-TS; g=0.7                             0.001986  0.555543
#                 MP-D-TS; g=0.8                             0.002033  0.571572
#                 MP-D-TS; g=0.9                             0.002226  0.610696
#                 MP-D-TS; g=0.99                            0.002530  0.666611
#                 MP-D-UCB; g=0.7                            0.001783  0.793707
#                 MP-D-UCB; g=0.8                            0.001750  0.793000
#                 MP-D-UCB; g=0.9                            0.001760  0.801894
#                 MP-D-UCB; g=0.99                           0.001848  0.801950
#                 MP-E-G; e=0.7                              0.002550  0.379445
#                 MP-E-G; e=0.8                              0.002403  0.382488
#                 MP-E-G; e=0.9                              0.002470  0.403615
#                 MP-E-G; e=0.99                             0.002373  0.459818
#                 MP-GLR-KL-UCB-G                            0.002067  1.096045
#                 MP-GLR-KL-UCB-G-F                          0.001978  1.372231
#                 MP-GLR-KL-UCB-L                            0.002016  1.497628
#                 MP-GLR-KL-UCB-L-F                          0.002088  1.476411
#                 MP-KLUCB                                   0.001935  1.914192
#                 MP-M-UCB; w=1000; m=10                     0.001743  0.629609
#                 MP-M-UCB; w=1000; m=100                    0.001755  0.633086
#                 MP-M-UCB; w=5000; m=10                     0.001763  0.627320
#                 MP-M-UCB; w=5000; m=100                    0.001736  0.637335
#                 MP-RExp3; b=100.0                          0.002082  0.509524
#                 MP-RExp3; b=1000.0                         0.002081  0.505714
#                 MP-RExp3; b=500.0                          0.002110  0.505584
#                 MP-RExp3; b=5000.0                         0.002083  0.507983
#                 MP-SW-TS; w=100                            0.002325  0.563099
#                 MP-SW-TS; w=1000                           0.002209  0.473402
#                 MP-SW-TS; w=500                            0.002027  0.451832
#                 MP-SW-TS; w=5000                           0.002228  0.475851
#                 MP-SW-UCB#-A; nu=0.1; l=12.3               0.001672  0.573084
#                 MP-SW-UCB#-A; nu=0.2; l=12.3               0.001767  0.560136
#                 MP-SW-UCB#-G; ka=0.1; l=4.3                0.001640  0.540279
#                 MP-SW-UCB#-G; ka=0.2; l=4.3                0.001766  0.549565
#                 MP-SW-UCB; w=100                           0.001965  0.591983
#                 MP-SW-UCB; w=1000                          0.001889  0.572219
#                 MP-SW-UCB; w=500                           0.001817  0.566102
#                 MP-SW-UCB; w=5000                          0.001933  0.571014
#                 MP-TS                                      0.002255  0.468802
#                 OD                                         0.023462  0.223962
#                 OR                                         0.001768  0.226728
#                 OS                                         0.002679  0.312605
# No-5            MP-ADR-Elimination-UCB-ADWIN1; d=0.001     0.000116  2.050039
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01      0.000118  2.075179
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1       0.000124  2.150760
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4    0.000121  2.054274
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5    0.000123  2.053978
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false         0.000122  1.045263
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true          0.000128  1.053314
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false          0.000129  1.038380
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true           0.000131  1.050812
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false           0.000120  1.043564
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true            0.000132  1.054850
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false        0.000118  1.047936
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true         0.000123  1.048042
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false        0.000116  1.049002
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true         0.000127  1.049102
#                 MP-D-TS; g=0.7                             0.000133  1.427215
#                 MP-D-TS; g=0.8                             0.000127  1.418438
#                 MP-D-TS; g=0.9                             0.000123  1.369324
#                 MP-D-TS; g=0.99                            0.000119  1.386654
#                 MP-D-UCB; g=0.7                            0.000118  1.760543
#                 MP-D-UCB; g=0.8                            0.000121  1.760164
#                 MP-D-UCB; g=0.9                            0.000122  1.767833
#                 MP-D-UCB; g=0.99                           0.000128  1.767370
#                 MP-E-G; e=0.7                              0.000138  0.863591
#                 MP-E-G; e=0.8                              0.000139  0.856051
#                 MP-E-G; e=0.9                              0.000146  0.840282
#                 MP-E-G; e=0.99                             0.000158  0.848856
#                 MP-GLR-KL-UCB-G                            0.000129  2.506194
#                 MP-GLR-KL-UCB-G-F                          0.000127  2.895861
#                 MP-GLR-KL-UCB-L                            0.000128  2.945988
#                 MP-GLR-KL-UCB-L-F                          0.000121  2.944143
#                 MP-KLUCB                                   0.000159  2.081919
#                 MP-M-UCB; w=1000; m=10                     0.000122  1.324394
#                 MP-M-UCB; w=1000; m=100                    0.000117  1.350766
#                 MP-M-UCB; w=5000; m=10                     0.000115  1.339309
#                 MP-M-UCB; w=5000; m=100                    0.000120  1.348777
#                 MP-RExp3; b=100.0                          0.000149  1.551896
#                 MP-RExp3; b=1000.0                         0.000140  1.555334
#                 MP-RExp3; b=500.0                          0.000149  1.555544
#                 MP-RExp3; b=5000.0                         0.000138  1.512949
#                 MP-SW-TS; w=100                            0.000134  1.097029
#                 MP-SW-TS; w=1000                           0.000119  1.103845
#                 MP-SW-TS; w=500                            0.000121  1.094247
#                 MP-SW-TS; w=5000                           0.000124  1.104792
#                 MP-SW-UCB#-A; nu=0.1; l=12.3               0.000120  1.284956
#                 MP-SW-UCB#-A; nu=0.2; l=12.3               0.000127  1.288409
#                 MP-SW-UCB#-G; ka=0.1; l=4.3                0.000120  1.292099
#                 MP-SW-UCB#-G; ka=0.2; l=4.3                0.000119  1.298999
#                 MP-SW-UCB; w=100                           0.000125  1.288939
#                 MP-SW-UCB; w=1000                          0.000126  1.284021
#                 MP-SW-UCB; w=500                           0.000127  1.284226
#                 MP-SW-UCB; w=5000                          0.000129  1.280444
#                 MP-TS                                      0.000134  1.063435
#                 OD                                         0.004345  0.866032
#                 OR                                         0.000121  0.624852
#                 OS                                         0.000139  0.408135

# %%
from matplotlib.markers import TICKLEFT, TICKRIGHT, TICKUP, TICKDOWN, CARETLEFT, CARETRIGHT, CARETUP, CARETDOWN
markers = [
#    '.',
#    ',',
    'v',
    'o',
    '^',
    '<',
    '>',
#    '1',
#    '2',
#    '3',
#    '4',
#    '8',
    's',
    'p',
    '*',
#    'h',
    'H',
    '+',
    'x',
    'D',
#    'd',
    '|',
    '_',
    TICKLEFT,
    TICKRIGHT,
    TICKUP,
    TICKDOWN,
    CARETLEFT,
    CARETRIGHT,
    CARETUP,
    CARETDOWN,
]

# %%
algs_ours = [    
    # ours
    'MP-ADR-Elimination-UCB-ADWIN1; d=0.001',
    'MP-ADS-TS-ADWIN1; d=0.001; r=true',
#    'MP-ADS-TS-ADWIN1; d=0.001; r=false'
]
algs_pass = [
    # passive
    'MP-D-UCB; g=0.9',
    'MP-RExp3; b=1000.0',
    'MP-SW-TS; w=1000',
#    'MP-SW-UCB; w=1000',
    'MP-SW-UCB#-A; nu=0.1; l=12.3', 
    #'MP-SW-UCB#-A; nu=0.2; l=12.3', 
    'MP-SW-UCB#-G; ka=0.1; l=4.3', 
    #'MP-SW-UCB#-G; ka=0.2; l=4.3'
]
algs_act = [
    # active
    'MP-GLR-KL-UCB-G',
#    'MP-GLR-KL-UCB-L',
#    'MP-GLR-KL-UCB-G-F',
#    'MP-GLR-KL-UCB-L-F',
    'MP-M-UCB; w=1000; m=10',
#    'MP-M-UCB; w=5000; m=100',
]
algs_base = [
    # baselines
    'MP-TS',
    'MP-E-G; e=0.9',
    'OR',
    'OD',
    'OS',
    'CustomOracle'
]

# %%
prettynames = {
    'MP-ADR-Elimination-UCB-ADWIN1; d=0.001' : "ADR-E-UCB",
    'MP-ADS-TS-ADWIN1; d=0.001; r=true': "ADR-TS",
    'MP-ADS-TS-ADWIN1; d=0.001; r=false': "ADS-TS",
    'MP-D-UCB; g=0.9': "D-UCB",
    'MP-RExp3; b=1000.0': "RExp3",
    'MP-SW-TS; w=1000': "SW-TS",
    'MP-SW-UCB; w=1000': "SW-UCB",
    'MP-SW-UCB#-A; nu=0.1; l=12.3': "SW-UCB\#-A",
    'MP-SW-UCB#-G; ka=0.1; l=4.3': "SW-UCB\#-G",
    # active
    'MP-GLR-KL-UCB-G': 'GLR-KL-UCB',
    'MP-GLR-KL-UCB-L': 'GLR-KL-UCB-L',
    'MP-GLR-KL-UCB-G-F': 'GLR-KL-UCB-G-F',
    'MP-GLR-KL-UCB-L-F': 'GLR-KL-UCB-L-F',
    'MP-M-UCB; w=1000; m=10': 'M-UCB; w=1000; m=10',
#    'MP-M-UCB; w=5000; m=100': 'M-UCB; w=5000; m=100',
    'MP-M-UCB; w=1000; m=10': 'M-UCB',
    # baselines
    'MP-TS': 'MP-TS',
    'MP-E-G; e=0.9': 'Espilon-Greedy',
    'OR': "Random Oracle",
    'OD': "Dynamic Oracle",
    'OS': "Static Oracle",
    'CustomOracle': "Custom Oracle"
}

# %%
# compute regret against 'OD', or just the cumulative rewards

# %%
strategy = "No-1"

# %%
fig, axes = plt.subplots(2, 2, sharey=True, sharex=True, figsize=(14,10), constrained_layout=True)

L = 2

plt.sca(axes[0][0])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
for bandit in algs_ours + algs_pass:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)/L
    cumsum.plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                markevery=(i*50,400), marker=markers[i] , markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20) 
plt.legend(ncol=1)
plt.ylabel("$\sum_{i}^{K} X_i^T/L$")
plt.title("Ours vs. passive approaches ($L = %s$)"%L)

plt.sca(axes[1][0])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
for bandit in algs_ours + algs_act:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)/L
    cumsum.plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                markevery=(i*50,400), marker=markers[i] , markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20) 
plt.legend(ncol=1)
plt.ylabel("$\sum_{i}^{K} X_i^T/L$")
plt.title("Ours vs. active approaches ($L = %s$)"%L)
plt.xlabel("$T$")

L = 1

plt.sca(axes[0][1])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
for bandit in algs_ours + algs_pass:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)/L
    cumsum.plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                markevery=(i*50,400), marker=markers[i] , markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20) 
plt.legend(ncol=1)
plt.title("Ours vs. passive approaches ($L = %s$)"%L)

plt.sca(axes[1][1])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
for bandit in algs_ours + algs_act:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)/L
    cumsum.plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                markevery=(i*50,400), marker=markers[i] , markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20) 
plt.legend(ncol=1)
plt.xlabel("$T$")
plt.title("Ours vs. active approaches ($L = %s$)"%L)

plt.suptitle("Cumulative gain over time (Zozo)", fontsize=25)
plt.savefig("plots/Zozo_unif_gain_full.pdf")

# %%
fig, axes = plt.subplots(1, 2, sharey=True, sharex=True, figsize=(14,5), constrained_layout=True)

L = 1

plt.sca(axes[0])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
for bandit in algs_ours + algs_pass:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)/L
    cumsum.plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                markevery=(i*50,400), marker=markers[i] , markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20) 
plt.legend(ncol=1)
plt.xlabel("$T$")
plt.ylabel("$\sum_{i}^{K} X_i^T$")
plt.title("Ours vs. passive approaches")

plt.sca(axes[1])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
for bandit in algs_ours + algs_act:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)/L
    cumsum.plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                markevery=(i*50,400), marker=markers[i] , markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20) 
plt.legend(ncol=1)
plt.xlabel("$T$")
plt.title("Ours vs. active approaches")

plt.suptitle("Cumulative gain over time (Zozo)", fontsize=25)
plt.savefig("plots/Zozo_unif_gain_Fig7b.pdf")
