# %%
import math

import matplotlib as mpl
mpl.rcParams['text.usetex'] = True 
mpl.rcParams['text.latex.preamble'] = [r'\usepackage{libertine}', r'\usepackage{newtxmath}'] 
mpl.rc('font', family='serif')

import numpy as np
import pandas as pd
import seaborn as sns


import matplotlib.pyplot as plt
from matplotlib import rc

from cycler import cycler


mpl.rcParams['ps.usedistiller'] = 'xpdf' 

plt.style.use('seaborn-notebook')
# sns.set_palette("Blues_r")

plt.rcParams['axes.titlesize'] = '25'
plt.rcParams['axes.labelsize'] = '25'
plt.rcParams['legend.fontsize'] = '15'
plt.rcParams['xtick.labelsize'] = '15'
plt.rcParams['ytick.labelsize'] = '15'

monochrome=(cycler('color', sns.color_palette("husl", 8))*2+(cycler('marker', ['v', 's', "o"])*7)[0:16])
plt.rc('axes', prop_cycle=monochrome)

pd.options.display.max_rows = 999
# Out:
# /var/folders/8v/5czrtjp134z_qn6j_jsmrnl80000gn/T/ipykernel_13896/831503919.py:5: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   mpl.rcParams['text.latex.preamble'] = [r'\usepackage{libertine}', r'\usepackage{newtxmath}']
# /var/folders/8v/5czrtjp134z_qn6j_jsmrnl80000gn/T/ipykernel_13896/831503919.py:21: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-notebook')

# %%
# Change if required
folder = "../experiments/2022-11-14-16-33_BanditNonStaticAbrupt_"
dataset = "Abrupt"

# %%
masterdata = pd.read_csv("%s/BanditNonStaticAbrupt.csv"%folder, sep=",")
narms = masterdata.iloc[0]['k']

# %%
sorted(masterdata.bandit.unique())
# Out:
# ['CustomOracle',
#  'ImpCPD',
#  'ImpCPD2',
#  'ImpCPD3',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=0.001',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=0.01',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=0.1',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-12',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-15',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-6',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-7',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-8',
#  'MP-ADS-KL-UCB-ADWIN1; d=0.001; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=0.001; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=0.01; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=0.01; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=0.1; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=0.1; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-15; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-15; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-5; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-5; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-7; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-7; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=true',
#  'MP-ADS-TS-ADWIN1; d=0.001; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.001; r=true',
#  'MP-ADS-TS-ADWIN1; d=0.01; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.01; r=true',
#  'MP-ADS-TS-ADWIN1; d=0.1; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.1; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-12; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-12; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-15; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-15; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-4; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-4; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-5; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-5; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-6; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-6; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-7; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-7; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-8; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-8; r=true',
#  'MP-D-TS; g=0.7',
#  'MP-D-TS; g=0.8',
#  'MP-D-TS; g=0.9',
#  'MP-D-TS; g=0.99',
#  'MP-D-TS; g=0.999',
#  'MP-D-UCB; g=0.7',
#  'MP-D-UCB; g=0.8',
#  'MP-D-UCB; g=0.9',
#  'MP-D-UCB; g=0.99',
#  'MP-D-UCB; g=0.999',
#  'MP-E-G; e=0.7',
#  'MP-E-G; e=0.8',
#  'MP-E-G; e=0.9',
#  'MP-E-G; e=0.99',
#  'MP-GLR-KL-UCB-G',
#  'MP-GLR-KL-UCB-L',
#  'MP-KLUCB',
#  'MP-M-UCB; w=1000; m=10',
#  'MP-M-UCB; w=1000; m=100',
#  'MP-M-UCB; w=5000; m=10',
#  'MP-M-UCB; w=5000; m=100',
#  'MP-RExp3; b=100.0',
#  'MP-RExp3; b=1000.0',
#  'MP-RExp3; b=500.0',
#  'MP-RExp3; b=5000.0',
#  'MP-SW-TS; w=100',
#  'MP-SW-TS; w=1000',
#  'MP-SW-TS; w=500',
#  'MP-SW-TS; w=5000',
#  'MP-SW-UCB#-A; nu=0.1; l=12.3',
#  'MP-SW-UCB#-A; nu=0.2; l=12.3',
#  'MP-SW-UCB#-G; ka=0.1; l=4.3',
#  'MP-SW-UCB#-G; ka=0.2; l=4.3',
#  'MP-SW-UCB; w=100',
#  'MP-SW-UCB; w=1000',
#  'MP-SW-UCB; w=500',
#  'MP-SW-UCB; w=5000',
#  'MP-TS',
#  'OD',
#  'OR',
#  'OS',
#  'UCBL-CPD']

# %%
masterdata.columns
# Out:
# Index(['bandit', 'dataset', 'scalingstrategy', 'k', 'gain', 'cputime',
#        'iteration'],
#       dtype='object')

# %%
masterdata['reward/arm'] = masterdata['gain']/masterdata['k']

# %%
masterdata.shape
# Out:
# (960000, 8)

# %%
masterdata.groupby(["scalingstrategy", "bandit"])[['gain', 'k', 'reward/arm', 'cputime']].mean()
# Out:
#                                                               gain    k  \
# scalingstrategy bandit
# No-1            CustomOracle                              0.966554  1.0
#                 ImpCPD                                    0.846339  1.0
#                 ImpCPD2                                   0.800153  1.0
#                 ImpCPD3                                   0.803882  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001    0.682441  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01     0.665817  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1      0.618635  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-12  0.751892  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-15  0.752084  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4   0.694798  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5   0.725004  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-6   0.743257  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-7   0.751154  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-8   0.752665  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=0.001; r=false    0.902678  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=0.001; r=true     0.903494  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=0.01; r=false     0.903286  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=0.01; r=true      0.905097  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=0.1; r=false      0.911370  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=0.1; r=true       0.902695  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=false  0.901054  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=true   0.902548  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-15; r=false  0.900776  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-15; r=true   0.901909  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=false   0.903383  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=true    0.904922  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-5; r=false   0.901432  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-5; r=true    0.903314  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=false   0.902472  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=true    0.902608  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-7; r=false   0.903735  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-7; r=true    0.902987  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=false   0.900396  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=true    0.900858  1.0
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false        0.886011  1.0
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true         0.892454  1.0
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false         0.886241  1.0
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true          0.893118  1.0
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false          0.890980  1.0
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true           0.872261  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-12; r=false      0.884545  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-12; r=true       0.891338  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-15; r=false      0.882518  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-15; r=true       0.889662  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false       0.885569  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true        0.893525  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false       0.885616  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true        0.892231  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-6; r=false       0.885481  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-6; r=true        0.890309  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-7; r=false       0.883275  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-7; r=true        0.892879  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-8; r=false       0.884846  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-8; r=true        0.890443  1.0
#                 MP-D-TS; g=0.7                            0.844578  1.0
#                 MP-D-TS; g=0.8                            0.864909  1.0
#                 MP-D-TS; g=0.9                            0.900916  1.0
#                 MP-D-TS; g=0.99                           0.862647  1.0
#                 MP-D-TS; g=0.999                          0.838163  1.0
#                 MP-D-UCB; g=0.7                           0.752143  1.0
#                 MP-D-UCB; g=0.8                           0.752862  1.0
#                 MP-D-UCB; g=0.9                           0.752313  1.0
#                 MP-D-UCB; g=0.99                          0.752495  1.0
#                 MP-D-UCB; g=0.999                         0.752792  1.0
#                 MP-E-G; e=0.7                             0.768360  1.0
#                 MP-E-G; e=0.8                             0.808487  1.0
#                 MP-E-G; e=0.9                             0.843777  1.0
#                 MP-E-G; e=0.99                            0.869071  1.0
#                 MP-GLR-KL-UCB-G                           0.541040  1.0
#                 MP-GLR-KL-UCB-L                           0.614568  1.0
#                 MP-KLUCB                                  0.900740  1.0
#                 MP-M-UCB; w=1000; m=10                    0.497698  1.0
#                 MP-M-UCB; w=1000; m=100                   0.497738  1.0
#                 MP-M-UCB; w=5000; m=10                    0.497744  1.0
#                 MP-M-UCB; w=5000; m=100                   0.497741  1.0
#                 MP-RExp3; b=100.0                         0.481553  1.0
#                 MP-RExp3; b=1000.0                        0.480990  1.0
#                 MP-RExp3; b=500.0                         0.481463  1.0
#                 MP-RExp3; b=5000.0                        0.481622  1.0
#                 MP-SW-TS; w=100                           0.390737  1.0
#                 MP-SW-TS; w=1000                          0.814778  1.0
#                 MP-SW-TS; w=500                           0.625034  1.0
#                 MP-SW-TS; w=5000                          0.855205  1.0
#                 MP-SW-UCB#-A; nu=0.1; l=12.3              0.582757  1.0
#                 MP-SW-UCB#-A; nu=0.2; l=12.3              0.564200  1.0
#                 MP-SW-UCB#-G; ka=0.1; l=4.3               0.489459  1.0
#                 MP-SW-UCB#-G; ka=0.2; l=4.3               0.489688  1.0
#                 MP-SW-UCB; w=100                          0.162395  1.0
#                 MP-SW-UCB; w=1000                         0.666281  1.0
#                 MP-SW-UCB; w=500                          0.587678  1.0
#                 MP-SW-UCB; w=5000                         0.801474  1.0
#                 MP-TS                                     0.864350  1.0
#                 OD                                        1.000000  1.0
#                 OR                                        0.489671  1.0
#                 OS                                        0.899988  1.0
#                 UCBL-CPD                                  0.810772  1.0
#
#                                                           reward/arm   cputime
# scalingstrategy bandit
# No-1            CustomOracle                                0.966554  0.024774
#                 ImpCPD                                      0.846339  0.600290
#                 ImpCPD2                                     0.800153  1.393561
#                 ImpCPD3                                     0.803882  0.824074
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001      0.682441  0.279311
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01       0.665817  0.386119
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1        0.618635  0.454772
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-12    0.751892  0.461720
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-15    0.752084  0.764085
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4     0.694798  0.664363
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5     0.725004  0.296377
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-6     0.743257  0.276462
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-7     0.751154  0.758817
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-8     0.752665  0.555528
#                 MP-ADS-KL-UCB-ADWIN1; d=0.001; r=false      0.902678  0.389712
#                 MP-ADS-KL-UCB-ADWIN1; d=0.001; r=true       0.903494  0.383516
#                 MP-ADS-KL-UCB-ADWIN1; d=0.01; r=false       0.903286  0.421066
#                 MP-ADS-KL-UCB-ADWIN1; d=0.01; r=true        0.905097  0.568628
#                 MP-ADS-KL-UCB-ADWIN1; d=0.1; r=false        0.911370  0.514176
#                 MP-ADS-KL-UCB-ADWIN1; d=0.1; r=true         0.902695  0.283702
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=false    0.901054  0.498192
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=true     0.902548  0.587352
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-15; r=false    0.900776  0.627764
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-15; r=true     0.901909  0.301767
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=false     0.903383  0.337693
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=true      0.904922  0.300986
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-5; r=false     0.901432  0.308363
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-5; r=true      0.903314  0.373640
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=false     0.902472  0.479072
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=true      0.902608  0.404679
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-7; r=false     0.903735  0.308956
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-7; r=true      0.902987  0.281269
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=false     0.900396  0.300181
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=true      0.900858  0.578580
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false          0.886011  0.487441
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true           0.892454  0.557509
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false           0.886241  0.236783
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true            0.893118  0.565612
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false            0.890980  0.296946
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true             0.872261  0.212103
#                 MP-ADS-TS-ADWIN1; d=1.0E-12; r=false        0.884545  0.413715
#                 MP-ADS-TS-ADWIN1; d=1.0E-12; r=true         0.891338  0.298525
#                 MP-ADS-TS-ADWIN1; d=1.0E-15; r=false        0.882518  0.337313
#                 MP-ADS-TS-ADWIN1; d=1.0E-15; r=true         0.889662  0.276530
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false         0.885569  0.495119
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true          0.893525  0.313908
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false         0.885616  0.371968
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true          0.892231  0.444925
#                 MP-ADS-TS-ADWIN1; d=1.0E-6; r=false         0.885481  0.392440
#                 MP-ADS-TS-ADWIN1; d=1.0E-6; r=true          0.890309  0.492741
#                 MP-ADS-TS-ADWIN1; d=1.0E-7; r=false         0.883275  0.365701
#                 MP-ADS-TS-ADWIN1; d=1.0E-7; r=true          0.892879  0.323844
#                 MP-ADS-TS-ADWIN1; d=1.0E-8; r=false         0.884846  0.455942
#                 MP-ADS-TS-ADWIN1; d=1.0E-8; r=true          0.890443  0.633871
#                 MP-D-TS; g=0.7                              0.844578  0.220372
#                 MP-D-TS; g=0.8                              0.864909  0.179850
#                 MP-D-TS; g=0.9                              0.900916  0.241014
#                 MP-D-TS; g=0.99                             0.862647  0.323043
#                 MP-D-TS; g=0.999                            0.838163  0.237107
#                 MP-D-UCB; g=0.7                             0.752143  0.830249
#                 MP-D-UCB; g=0.8                             0.752862  0.734836
#                 MP-D-UCB; g=0.9                             0.752313  0.567531
#                 MP-D-UCB; g=0.99                            0.752495  0.701280
#                 MP-D-UCB; g=0.999                           0.752792  0.825506
#                 MP-E-G; e=0.7                               0.768360  0.153548
#                 MP-E-G; e=0.8                               0.808487  0.161123
#                 MP-E-G; e=0.9                               0.843777  0.175444
#                 MP-E-G; e=0.99                              0.869071  0.238489
#                 MP-GLR-KL-UCB-G                             0.541040  0.443168
#                 MP-GLR-KL-UCB-L                             0.614568  0.580757
#                 MP-KLUCB                                    0.900740  0.267969
#                 MP-M-UCB; w=1000; m=10                      0.497698  0.204082
#                 MP-M-UCB; w=1000; m=100                     0.497738  0.255154
#                 MP-M-UCB; w=5000; m=10                      0.497744  0.233057
#                 MP-M-UCB; w=5000; m=100                     0.497741  0.305281
#                 MP-RExp3; b=100.0                           0.481553  0.324079
#                 MP-RExp3; b=1000.0                          0.480990  0.247172
#                 MP-RExp3; b=500.0                           0.481463  0.748138
#                 MP-RExp3; b=5000.0                          0.481622  0.231297
#                 MP-SW-TS; w=100                             0.390737  0.267255
#                 MP-SW-TS; w=1000                            0.814778  0.435505
#                 MP-SW-TS; w=500                             0.625034  0.211398
#                 MP-SW-TS; w=5000                            0.855205  0.209412
#                 MP-SW-UCB#-A; nu=0.1; l=12.3                0.582757  0.271858
#                 MP-SW-UCB#-A; nu=0.2; l=12.3                0.564200  0.197385
#                 MP-SW-UCB#-G; ka=0.1; l=4.3                 0.489459  0.185572
#                 MP-SW-UCB#-G; ka=0.2; l=4.3                 0.489688  0.147684
#                 MP-SW-UCB; w=100                            0.162395  0.284482
#                 MP-SW-UCB; w=1000                           0.666281  0.234372
#                 MP-SW-UCB; w=500                            0.587678  0.257472
#                 MP-SW-UCB; w=5000                           0.801474  0.203787
#                 MP-TS                                       0.864350  0.204128
#                 OD                                          1.000000  0.169802
#                 OR                                          0.489671  0.060997
#                 OS                                          0.899988  0.012192
#                 UCBL-CPD                                    0.810772  0.657175

# %%
masterdata['dataset'].unique()
# Out:
# array(['AbruptGenerator-100'], dtype=object)

# %%
from matplotlib.markers import TICKLEFT, TICKRIGHT, TICKUP, TICKDOWN, CARETLEFT, CARETRIGHT, CARETUP, CARETDOWN
markers = [
#    '.',
#    ',',
    'v',
    'o',
    '^',
    '<',
    '>',
#    '1',
#    '2',
#    '3',
#    '4',
#    '8',
    's',
    'p',
    '*',
#    'h',
    'H',
    '+',
    'x',
    'D',
#    'd',
    '|',
    '_',
    TICKLEFT,
    TICKRIGHT,
    TICKUP,
    TICKDOWN,
    CARETLEFT,
    CARETRIGHT,
    CARETUP,
    CARETDOWN,
]

# %%
algs_ours = [    
    # ours
    'MP-ADR-Elimination-UCB-ADWIN1; d=0.001',
    'MP-ADS-TS-ADWIN1; d=0.001; r=true',
    'MP-ADS-KL-UCB-ADWIN1; d=0.001; r=true',
#    'MP-ADS-TS-ADWIN1; d=0.001; r=false'
]
algs_pass = [
    # passive
    'MP-D-UCB; g=0.9',
    'MP-RExp3; b=1000.0',
    'MP-SW-TS; w=1000',
#    'MP-SW-UCB; w=1000',
    'MP-SW-UCB#-A; nu=0.1; l=12.3', 
    #'MP-SW-UCB#-A; nu=0.2; l=12.3', 
    'MP-SW-UCB#-G; ka=0.1; l=4.3', 
    #'MP-SW-UCB#-G; ka=0.2; l=4.3'
]
algs_act = [
    # active
    'MP-GLR-KL-UCB-G',
#    'MP-GLR-KL-UCB-L',
#    'MP-GLR-KL-UCB-G-F',
#    'MP-GLR-KL-UCB-L-F',
    'MP-M-UCB; w=1000; m=10',
#    'MP-M-UCB; w=5000; m=100',
    #'ImpCPD',
    'ImpCPD2',
    #'ImpCPD3', 
    'UCBL-CPD'
]
algs_base = [
    # baselines
    'MP-TS',
    'MP-E-G; e=0.9',
    'OR',
    'OD',
    'OS',
    'CustomOracle'
]

# %%
prettynames = {
    'MP-ADR-Elimination-UCB-ADWIN1; d=0.001' : "ADR-E-UCB",
    'MP-ADS-TS-ADWIN1; d=0.001; r=true': "ADR-TS",
    'MP-ADS-TS-ADWIN1; d=0.001; r=false': "ADS-TS",
    'MP-ADS-KL-UCB-ADWIN1; d=0.001; r=true':'ADR-KL-UCB',
    'MP-D-UCB; g=0.9': "D-UCB",
    'MP-RExp3; b=1000.0': "RExp3",
    'MP-SW-TS; w=1000': "SW-TS",
    'MP-SW-UCB; w=1000': "SW-UCB",
    'MP-SW-UCB#-A; nu=0.1; l=12.3': "SW-UCB\#-A",
    'MP-SW-UCB#-G; ka=0.1; l=4.3': "SW-UCB\#-G",
    # active
    'MP-GLR-KL-UCB-G': 'GLR-KL-UCB',
    'MP-GLR-KL-UCB-L': 'GLR-KL-UCB-L',
    'MP-GLR-KL-UCB-G-F': 'GLR-KL-UCB-G-F',
    'MP-GLR-KL-UCB-L-F': 'GLR-KL-UCB-L-F',
#    'MP-M-UCB; w=1000; m=10': 'M-UCB; w=1000; m=10',
#    'MP-M-UCB; w=5000; m=100': 'M-UCB; w=5000; m=100',
    'MP-M-UCB; w=1000; m=10': 'M-UCB',
    'ImpCPD': 'ImpCPD1',
    'ImpCPD2': 'ImpCPD',
    'ImpCPD3': 'ImpCPD3', 
    'UCBL-CPD': 'UCBL-CPD',
    # baselines
    'MP-TS': 'MP-TS',
    'MP-E-G; e=0.9': 'Espilon-Greedy',
    'OR': "Random Oracle",
    'OD': "Dynamic Oracle",
    'OS': "Static Oracle",
    'CustomOracle': "Custom Oracle"
}

# %%
# compute regret against 'OD', or just the cumulative rewards

# %%
fig, axes = plt.subplots(1, 2, sharey=True, sharex=True, figsize=(14,5), constrained_layout=True)

L = 1

plt.sca(axes[0])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "CustomOracle"].gain.cumsum().reset_index(drop=True)
for bandit in algs_ours + algs_pass:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                             markevery=(i*500,400),  marker=markers[i] , markersize=10)
    i+=1

plt.ylabel("$R_T$")
plt.legend(ncol=1, loc="upper left")
#plt.ylim([0,2000])
plt.title("Ours vs. passive approaches")

plt.sca(axes[1])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "CustomOracle"].gain.cumsum().reset_index(drop=True)
for bandit in algs_ours + algs_act:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                             markevery=(i*500,400),  marker=markers[i] , markersize=10)
    i+=1

plt.legend(ncol=1, loc="upper left")
plt.title("Ours vs. active approaches")
plt.xlabel("$T$")
#plt.ylim([0,2000])

#plt.tight_layout()

plt.suptitle("Cumulative regret over time (abrupt local)", fontsize=25)
plt.savefig("plots/%s_regret_Fig6.pdf"%dataset)
