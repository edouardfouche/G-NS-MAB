# %%
import math

import matplotlib as mpl
mpl.rcParams['text.usetex'] = True 
mpl.rcParams['text.latex.preamble'] = [r'\usepackage{libertine}', r'\usepackage{newtxmath}'] 
mpl.rc('font', family='serif')

import numpy as np
import pandas as pd
import seaborn as sns


import matplotlib.pyplot as plt
from matplotlib import rc

from cycler import cycler


mpl.rcParams['ps.usedistiller'] = 'xpdf' 

plt.style.use('seaborn-notebook')
# sns.set_palette("Blues_r")

plt.rcParams['axes.titlesize'] = '25'
plt.rcParams['axes.labelsize'] = '25'
plt.rcParams['legend.fontsize'] = '15'
plt.rcParams['xtick.labelsize'] = '15'
plt.rcParams['ytick.labelsize'] = '15'

monochrome=(cycler('color', sns.color_palette("husl", 8))*2+(cycler('marker', ['v', 's', "o"])*7)[0:16])
plt.rc('axes', prop_cycle=monochrome)

pd.options.display.max_rows = 999
# Out:
# <ipython-input-1-56d1c1821bb1>:5: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   mpl.rcParams['text.latex.preamble'] = [r'\usepackage{libertine}', r'\usepackage{newtxmath}']

# %%
# Change if required
folder = "../experiments/2021-06-16-08-20_BanditNonStaticAbrupt_"
dataset = "Abrupt"

# %%
masterdata = pd.read_csv("%s/BanditNonStaticAbrupt.csv"%folder, sep=",")
narms = masterdata.iloc[0]['k']

# %%
sorted(masterdata.bandit.unique())
# Out:
# ['CustomOracle',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=0.001',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=0.01',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=0.1',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5',
#  'MP-ADS-TS-ADWIN1; d=0.001; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.001; r=true',
#  'MP-ADS-TS-ADWIN1; d=0.01; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.01; r=true',
#  'MP-ADS-TS-ADWIN1; d=0.1; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.1; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-4; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-4; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-5; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-5; r=true',
#  'MP-D-TS; g=0.7',
#  'MP-D-TS; g=0.8',
#  'MP-D-TS; g=0.9',
#  'MP-D-TS; g=0.99',
#  'MP-D-UCB; g=0.7',
#  'MP-D-UCB; g=0.8',
#  'MP-D-UCB; g=0.9',
#  'MP-D-UCB; g=0.99',
#  'MP-E-G; e=0.7',
#  'MP-E-G; e=0.8',
#  'MP-E-G; e=0.9',
#  'MP-E-G; e=0.99',
#  'MP-GLR-KL-UCB-G',
#  'MP-GLR-KL-UCB-G-F',
#  'MP-GLR-KL-UCB-L',
#  'MP-GLR-KL-UCB-L-F',
#  'MP-KLUCB',
#  'MP-M-UCB; w=1000; m=10',
#  'MP-M-UCB; w=1000; m=100',
#  'MP-M-UCB; w=5000; m=10',
#  'MP-M-UCB; w=5000; m=100',
#  'MP-RExp3; b=100.0',
#  'MP-RExp3; b=1000.0',
#  'MP-RExp3; b=500.0',
#  'MP-RExp3; b=5000.0',
#  'MP-SW-TS; w=100',
#  'MP-SW-TS; w=1000',
#  'MP-SW-TS; w=500',
#  'MP-SW-TS; w=5000',
#  'MP-SW-UCB#-A; nu=0.1; l=12.3',
#  'MP-SW-UCB#-A; nu=0.2; l=12.3',
#  'MP-SW-UCB#-G; ka=0.1; l=4.3',
#  'MP-SW-UCB#-G; ka=0.2; l=4.3',
#  'MP-SW-UCB; w=100',
#  'MP-SW-UCB; w=1000',
#  'MP-SW-UCB; w=500',
#  'MP-SW-UCB; w=5000',
#  'MP-TS',
#  'OD',
#  'OR',
#  'OS']

# %%
masterdata.columns
# Out:
# Index(['bandit', 'dataset', 'scalingstrategy', 'k', 'gain', 'cputime',
#        'iteration'],
#       dtype='object')

# %%
masterdata['reward/arm'] = masterdata['gain']/masterdata['k']

# %%
masterdata.shape
# Out:
# (1710000, 8)

# %%
masterdata.groupby(["scalingstrategy", "bandit"])[['gain', 'k', 'reward/arm', 'cputime']].mean()
# Out:
#                                                              gain       k  \
# scalingstrategy bandit
# No-1            CustomOracle                             0.905147  1.0099
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001   0.596126  1.0099
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    0.597370  1.0099
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     0.549719  1.0099
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  0.593344  1.0099
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  0.593655  1.0099
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       0.792761  1.0099
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true        0.809416  1.0099
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        0.800336  1.0099
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         0.814092  1.0099
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         0.809943  1.0099
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true          0.791906  1.0099
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      0.797403  1.0099
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       0.809898  1.0099
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      0.795484  1.0099
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       0.805939  1.0099
#                 MP-D-TS; g=0.7                           0.671032  1.0099
#                 MP-D-TS; g=0.8                           0.677210  1.0099
#                 MP-D-TS; g=0.9                           0.759809  1.0099
#                 MP-D-TS; g=0.99                          0.799840  1.0099
#                 MP-D-UCB; g=0.7                          0.683516  1.0099
#                 MP-D-UCB; g=0.8                          0.683455  1.0099
#                 MP-D-UCB; g=0.9                          0.682336  1.0099
#                 MP-D-UCB; g=0.99                         0.683829  1.0099
#                 MP-E-G; e=0.7                            0.638406  1.0099
#                 MP-E-G; e=0.8                            0.667394  1.0099
#                 MP-E-G; e=0.9                            0.690988  1.0099
#                 MP-E-G; e=0.99                           0.707875  1.0099
#                 MP-GLR-KL-UCB-G                          0.470892  1.0099
#                 MP-GLR-KL-UCB-G-F                        0.519330  1.0099
#                 MP-GLR-KL-UCB-L                          0.515571  1.0099
#                 MP-GLR-KL-UCB-L-F                        0.451954  1.0099
#                 MP-KLUCB                                 0.793832  1.0099
#                 MP-M-UCB; w=1000; m=10                   0.431189  1.0099
#                 MP-M-UCB; w=1000; m=100                  0.431217  1.0099
#                 MP-M-UCB; w=5000; m=10                   0.431198  1.0099
#                 MP-M-UCB; w=5000; m=100                  0.431224  1.0099
#                 MP-RExp3; b=100.0                        0.417146  1.0099
#                 MP-RExp3; b=1000.0                       0.418418  1.0099
#                 MP-RExp3; b=500.0                        0.417785  1.0099
#                 MP-RExp3; b=5000.0                       0.417440  1.0099
#                 MP-SW-TS; w=100                          0.345623  1.0099
#                 MP-SW-TS; w=1000                         0.726954  1.0099
#                 MP-SW-TS; w=500                          0.564017  1.0099
#                 MP-SW-TS; w=5000                         0.725125  1.0099
#                 MP-SW-UCB#-A; nu=0.1; l=12.3             0.516877  1.0099
#                 MP-SW-UCB#-A; nu=0.2; l=12.3             0.494088  1.0099
#                 MP-SW-UCB#-G; ka=0.1; l=4.3              0.425015  1.0099
#                 MP-SW-UCB#-G; ka=0.2; l=4.3              0.424183  1.0099
#                 MP-SW-UCB; w=100                         0.173171  1.0099
#                 MP-SW-UCB; w=1000                        0.594364  1.0099
#                 MP-SW-UCB; w=500                         0.494866  1.0099
#                 MP-SW-UCB; w=5000                        0.693939  1.0099
#                 MP-TS                                    0.725964  1.0099
#                 OD                                       1.004978  1.0099
#                 OR                                       0.423757  1.0099
#                 OS                                       0.705445  1.0099
# No-2            CustomOracle                             1.794832  2.0098
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001   1.305439  2.0098
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    1.302130  2.0098
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     1.111151  2.0098
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  1.305567  2.0098
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  1.304726  2.0098
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       1.593401  2.0098
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true        1.638432  2.0098
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        1.625450  2.0098
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         1.658281  2.0098
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         1.642891  2.0098
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true          1.578411  2.0098
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      1.598067  2.0098
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       1.622178  2.0098
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      1.598542  2.0098
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       1.626236  2.0098
#                 MP-D-TS; g=0.7                           1.416849  2.0098
#                 MP-D-TS; g=0.8                           1.515636  2.0098
#                 MP-D-TS; g=0.9                           1.592048  2.0098
#                 MP-D-TS; g=0.99                          1.544722  2.0098
#                 MP-D-UCB; g=0.7                          1.393071  2.0098
#                 MP-D-UCB; g=0.8                          1.398079  2.0098
#                 MP-D-UCB; g=0.9                          1.396682  2.0098
#                 MP-D-UCB; g=0.99                         1.392755  2.0098
#                 MP-E-G; e=0.7                            1.238059  2.0098
#                 MP-E-G; e=0.8                            1.292581  2.0098
#                 MP-E-G; e=0.9                            1.332897  2.0098
#                 MP-E-G; e=0.99                           1.351908  2.0098
#                 MP-GLR-KL-UCB-G                          1.145835  2.0098
#                 MP-GLR-KL-UCB-G-F                        1.242695  2.0098
#                 MP-GLR-KL-UCB-L                          1.349902  2.0098
#                 MP-GLR-KL-UCB-L-F                        1.291061  2.0098
#                 MP-KLUCB                                 1.537082  2.0098
#                 MP-M-UCB; w=1000; m=10                   1.182329  2.0098
#                 MP-M-UCB; w=1000; m=100                  1.180505  2.0098
#                 MP-M-UCB; w=5000; m=10                   1.201923  2.0098
#                 MP-M-UCB; w=5000; m=100                  1.201936  2.0098
#                 MP-RExp3; b=100.0                        0.829189  2.0098
#                 MP-RExp3; b=1000.0                       0.830389  2.0098
#                 MP-RExp3; b=500.0                        0.830421  2.0098
#                 MP-RExp3; b=5000.0                       0.831241  2.0098
#                 MP-SW-TS; w=100                          0.774863  2.0098
#                 MP-SW-TS; w=1000                         1.470871  2.0098
#                 MP-SW-TS; w=500                          1.181478  2.0098
#                 MP-SW-TS; w=5000                         1.407477  2.0098
#                 MP-SW-UCB#-A; nu=0.1; l=12.3             1.118729  2.0098
#                 MP-SW-UCB#-A; nu=0.2; l=12.3             1.065810  2.0098
#                 MP-SW-UCB#-G; ka=0.1; l=4.3              0.843596  2.0098
#                 MP-SW-UCB#-G; ka=0.2; l=4.3              0.843128  2.0098
#                 MP-SW-UCB; w=100                         0.539432  2.0098
#                 MP-SW-UCB; w=1000                        1.304055  2.0098
#                 MP-SW-UCB; w=500                         1.059886  2.0098
#                 MP-SW-UCB; w=5000                        1.378247  2.0098
#                 MP-TS                                    1.417241  2.0098
#                 OD                                       2.004878  2.0098
#                 OR                                       0.844844  2.0098
#                 OS                                       1.394549  2.0098
# No-5            CustomOracle                             4.405407  5.0095
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001   3.646315  5.0095
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    3.532561  5.0095
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     2.796498  5.0095
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  3.651501  5.0095
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  3.649584  5.0095
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       3.966869  5.0095
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true        4.133158  5.0095
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        4.135305  5.0095
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         4.174510  5.0095
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         4.113928  5.0095
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true          3.870096  5.0095
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      3.929499  5.0095
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       4.000039  5.0095
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      3.913441  5.0095
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       3.992020  5.0095
#                 MP-D-TS; g=0.7                           3.894255  5.0095
#                 MP-D-TS; g=0.8                           3.875912  5.0095
#                 MP-D-TS; g=0.9                           3.841083  5.0095
#                 MP-D-TS; g=0.99                          3.710740  5.0095
#                 MP-D-UCB; g=0.7                          3.600714  5.0095
#                 MP-D-UCB; g=0.8                          3.597454  5.0095
#                 MP-D-UCB; g=0.9                          3.594196  5.0095
#                 MP-D-UCB; g=0.99                         3.604477  5.0095
#                 MP-E-G; e=0.7                            3.017158  5.0095
#                 MP-E-G; e=0.8                            3.110132  5.0095
#                 MP-E-G; e=0.9                            3.191995  5.0095
#                 MP-E-G; e=0.99                           3.205345  5.0095
#                 MP-GLR-KL-UCB-G                          3.095602  5.0095
#                 MP-GLR-KL-UCB-G-F                        3.467826  5.0095
#                 MP-GLR-KL-UCB-L                          3.701374  5.0095
#                 MP-GLR-KL-UCB-L-F                        3.708344  5.0095
#                 MP-KLUCB                                 3.698407  5.0095
#                 MP-M-UCB; w=1000; m=10                   3.524216  5.0095
#                 MP-M-UCB; w=1000; m=100                  3.519974  5.0095
#                 MP-M-UCB; w=5000; m=10                   3.414509  5.0095
#                 MP-M-UCB; w=5000; m=100                  3.412835  5.0095
#                 MP-RExp3; b=100.0                        2.071593  5.0095
#                 MP-RExp3; b=1000.0                       2.068402  5.0095
#                 MP-RExp3; b=500.0                        2.069037  5.0095
#                 MP-RExp3; b=5000.0                       2.069095  5.0095
#                 MP-SW-TS; w=100                          2.292463  5.0095
#                 MP-SW-TS; w=1000                         3.675623  5.0095
#                 MP-SW-TS; w=500                          3.033732  5.0095
#                 MP-SW-TS; w=5000                         3.381179  5.0095
#                 MP-SW-UCB#-A; nu=0.1; l=12.3             3.144123  5.0095
#                 MP-SW-UCB#-A; nu=0.2; l=12.3             2.997878  5.0095
#                 MP-SW-UCB#-G; ka=0.1; l=4.3              2.103575  5.0095
#                 MP-SW-UCB#-G; ka=0.2; l=4.3              2.102487  5.0095
#                 MP-SW-UCB; w=100                         1.981461  5.0095
#                 MP-SW-UCB; w=1000                        3.667506  5.0095
#                 MP-SW-UCB; w=500                         3.088902  5.0095
#                 MP-SW-UCB; w=5000                        3.441973  5.0095
#                 MP-TS                                    3.388019  5.0095
#                 OD                                       5.004578  5.0095
#                 OR                                       2.102041  5.0095
#                 OS                                       3.412255  5.0095
#
#                                                          reward/arm   cputime
# scalingstrategy bandit
# No-1            CustomOracle                               0.900120  0.020728
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001     0.591099  0.456039
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01      0.592343  0.670780
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1       0.544692  0.188930
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4    0.588317  0.216354
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5    0.588628  0.243692
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false         0.787734  0.338898
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true          0.804389  0.687484
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false          0.795309  0.606657
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true           0.809065  0.311527
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false           0.804916  0.592028
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true            0.786879  0.229485
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false        0.792376  0.430500
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true         0.804871  0.397810
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false        0.790457  0.327791
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true         0.800912  0.252610
#                 MP-D-TS; g=0.7                             0.666005  0.411673
#                 MP-D-TS; g=0.8                             0.672183  0.222930
#                 MP-D-TS; g=0.9                             0.754782  0.285464
#                 MP-D-TS; g=0.99                            0.794813  0.146847
#                 MP-D-UCB; g=0.7                            0.678489  0.447648
#                 MP-D-UCB; g=0.8                            0.678428  0.443560
#                 MP-D-UCB; g=0.9                            0.677309  0.432289
#                 MP-D-UCB; g=0.99                           0.678802  0.588641
#                 MP-E-G; e=0.7                              0.633379  0.091751
#                 MP-E-G; e=0.8                              0.662367  0.185661
#                 MP-E-G; e=0.9                              0.685961  0.157697
#                 MP-E-G; e=0.99                             0.702848  0.128349
#                 MP-GLR-KL-UCB-G                            0.465865  0.685221
#                 MP-GLR-KL-UCB-G-F                          0.514303  0.396528
#                 MP-GLR-KL-UCB-L                            0.510544  0.516169
#                 MP-GLR-KL-UCB-L-F                          0.446927  0.510661
#                 MP-KLUCB                                   0.788805  0.321920
#                 MP-M-UCB; w=1000; m=10                     0.426162  0.324391
#                 MP-M-UCB; w=1000; m=100                    0.426190  0.187582
#                 MP-M-UCB; w=5000; m=10                     0.426171  0.330161
#                 MP-M-UCB; w=5000; m=100                    0.426197  0.167268
#                 MP-RExp3; b=100.0                          0.412119  0.220565
#                 MP-RExp3; b=1000.0                         0.413391  0.418268
#                 MP-RExp3; b=500.0                          0.412758  0.315540
#                 MP-RExp3; b=5000.0                         0.412413  0.560403
#                 MP-SW-TS; w=100                            0.340596  0.353106
#                 MP-SW-TS; w=1000                           0.721927  0.379728
#                 MP-SW-TS; w=500                            0.558990  0.164064
#                 MP-SW-TS; w=5000                           0.720098  0.338084
#                 MP-SW-UCB#-A; nu=0.1; l=12.3               0.511850  0.358903
#                 MP-SW-UCB#-A; nu=0.2; l=12.3               0.489061  0.244848
#                 MP-SW-UCB#-G; ka=0.1; l=4.3                0.419988  0.262443
#                 MP-SW-UCB#-G; ka=0.2; l=4.3                0.419156  0.174351
#                 MP-SW-UCB; w=100                           0.168144  0.305530
#                 MP-SW-UCB; w=1000                          0.589337  0.277159
#                 MP-SW-UCB; w=500                           0.489839  0.134558
#                 MP-SW-UCB; w=5000                          0.688912  0.253550
#                 MP-TS                                      0.720937  0.334246
#                 OD                                         0.999951  0.150645
#                 OR                                         0.418730  0.057870
#                 OS                                         0.700418  0.016080
# No-2            CustomOracle                               0.894928  0.023014
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001     0.650231  0.459866
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01      0.648577  0.785627
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1       0.553087  0.263515
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4    0.650295  0.547573
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5    0.649875  0.367020
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false         0.794212  0.079924
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true          0.816728  0.633407
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false          0.810237  0.507359
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true           0.826652  0.225609
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false           0.818957  0.672392
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true            0.786717  0.259422
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false        0.796545  0.402714
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true         0.808601  0.521338
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false        0.796783  0.289436
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true         0.810630  0.444126
#                 MP-D-TS; g=0.7                             0.705936  0.261191
#                 MP-D-TS; g=0.8                             0.755330  0.170977
#                 MP-D-TS; g=0.9                             0.793536  0.286284
#                 MP-D-TS; g=0.99                            0.769873  0.256531
#                 MP-D-UCB; g=0.7                            0.694047  0.569202
#                 MP-D-UCB; g=0.8                            0.696551  0.572466
#                 MP-D-UCB; g=0.9                            0.695853  0.363633
#                 MP-D-UCB; g=0.99                           0.693889  0.463040
#                 MP-E-G; e=0.7                              0.616541  0.099819
#                 MP-E-G; e=0.8                              0.643802  0.111995
#                 MP-E-G; e=0.9                              0.663960  0.181324
#                 MP-E-G; e=0.99                             0.673466  0.174094
#                 MP-GLR-KL-UCB-G                            0.570429  0.245464
#                 MP-GLR-KL-UCB-G-F                          0.618859  0.418927
#                 MP-GLR-KL-UCB-L                            0.672463  0.555196
#                 MP-GLR-KL-UCB-L-F                          0.643042  0.170754
#                 MP-KLUCB                                   0.766053  0.254688
#                 MP-M-UCB; w=1000; m=10                     0.588676  0.277830
#                 MP-M-UCB; w=1000; m=100                    0.587764  0.145540
#                 MP-M-UCB; w=5000; m=10                     0.598473  0.155549
#                 MP-M-UCB; w=5000; m=100                    0.598480  0.149439
#                 MP-RExp3; b=100.0                          0.412106  0.279694
#                 MP-RExp3; b=1000.0                         0.412706  0.402765
#                 MP-RExp3; b=500.0                          0.412722  0.532227
#                 MP-RExp3; b=5000.0                         0.413132  0.483199
#                 MP-SW-TS; w=100                            0.384943  0.346919
#                 MP-SW-TS; w=1000                           0.732947  0.144968
#                 MP-SW-TS; w=500                            0.588251  0.165083
#                 MP-SW-TS; w=5000                           0.701250  0.208333
#                 MP-SW-UCB#-A; nu=0.1; l=12.3               0.556876  0.126786
#                 MP-SW-UCB#-A; nu=0.2; l=12.3               0.530417  0.340426
#                 MP-SW-UCB#-G; ka=0.1; l=4.3                0.419310  0.128502
#                 MP-SW-UCB#-G; ka=0.2; l=4.3                0.419076  0.281780
#                 MP-SW-UCB; w=100                           0.267228  0.380174
#                 MP-SW-UCB; w=1000                          0.649539  0.135293
#                 MP-SW-UCB; w=500                           0.527455  0.186164
#                 MP-SW-UCB; w=5000                          0.686635  0.328125
#                 MP-TS                                      0.706132  0.165020
#                 OD                                         0.999951  0.229075
#                 OR                                         0.419934  0.054022
#                 OS                                         0.694786  0.021524
# No-5            CustomOracle                               0.880117  0.014633
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001     0.728298  0.406392
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01      0.705547  0.657958
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1       0.558335  0.180149
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4    0.729335  0.609390
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5    0.728952  0.534033
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false         0.792409  0.648154
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true          0.825667  0.786580
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false          0.826096  0.789752
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true           0.833937  0.257082
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false           0.821821  0.725010
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true            0.773054  0.328798
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false        0.784935  0.948642
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true         0.799043  0.483442
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false        0.781723  0.350274
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true         0.797439  0.310690
#                 MP-D-TS; g=0.7                             0.777886  0.315520
#                 MP-D-TS; g=0.8                             0.774218  0.305036
#                 MP-D-TS; g=0.9                             0.767252  0.187438
#                 MP-D-TS; g=0.99                            0.741183  0.226830
#                 MP-D-UCB; g=0.7                            0.719178  0.725459
#                 MP-D-UCB; g=0.8                            0.718526  0.327836
#                 MP-D-UCB; g=0.9                            0.717874  0.389506
#                 MP-D-UCB; g=0.99                           0.719931  0.817695
#                 MP-E-G; e=0.7                              0.602467  0.184752
#                 MP-E-G; e=0.8                              0.621062  0.153391
#                 MP-E-G; e=0.9                              0.637434  0.202104
#                 MP-E-G; e=0.99                             0.640104  0.091732
#                 MP-GLR-KL-UCB-G                            0.618156  0.466070
#                 MP-GLR-KL-UCB-G-F                          0.692600  0.409639
#                 MP-GLR-KL-UCB-L                            0.739310  0.996637
#                 MP-GLR-KL-UCB-L-F                          0.740704  0.486905
#                 MP-KLUCB                                   0.738717  0.412709
#                 MP-M-UCB; w=1000; m=10                     0.703878  0.257206
#                 MP-M-UCB; w=1000; m=100                    0.703030  0.182935
#                 MP-M-UCB; w=5000; m=10                     0.681937  0.532836
#                 MP-M-UCB; w=5000; m=100                    0.681602  0.062881
#                 MP-RExp3; b=100.0                          0.413354  0.405794
#                 MP-RExp3; b=1000.0                         0.412716  0.380460
#                 MP-RExp3; b=500.0                          0.412843  0.718821
#                 MP-RExp3; b=5000.0                         0.412854  0.457216
#                 MP-SW-TS; w=100                            0.457528  0.241464
#                 MP-SW-TS; w=1000                           0.734160  0.415643
#                 MP-SW-TS; w=500                            0.605782  0.237730
#                 MP-SW-TS; w=5000                           0.675271  0.287415
#                 MP-SW-UCB#-A; nu=0.1; l=12.3               0.627860  0.295405
#                 MP-SW-UCB#-A; nu=0.2; l=12.3               0.598611  0.350324
#                 MP-SW-UCB#-G; ka=0.1; l=4.3                0.419750  0.195345
#                 MP-SW-UCB#-G; ka=0.2; l=4.3                0.419533  0.215333
#                 MP-SW-UCB; w=100                           0.395327  0.211292
#                 MP-SW-UCB; w=1000                          0.732536  0.300044
#                 MP-SW-UCB; w=500                           0.616816  0.341895
#                 MP-SW-UCB; w=5000                          0.687430  0.365048
#                 MP-TS                                      0.676639  0.176372
#                 OD                                         0.999951  0.243890
#                 OR                                         0.419443  0.074458
#                 OS                                         0.681486  0.013735

# %%
masterdata['dataset'].unique()
# Out:
# array(['AbruptGenerator-100'], dtype=object)

# %%
from matplotlib.markers import TICKLEFT, TICKRIGHT, TICKUP, TICKDOWN, CARETLEFT, CARETRIGHT, CARETUP, CARETDOWN
markers = [
#    '.',
#    ',',
    'v',
    'o',
    '^',
    '<',
    '>',
#    '1',
#    '2',
#    '3',
#    '4',
#    '8',
    's',
    'p',
    '*',
#    'h',
    'H',
    '+',
    'x',
    'D',
#    'd',
    '|',
    '_',
    TICKLEFT,
    TICKRIGHT,
    TICKUP,
    TICKDOWN,
    CARETLEFT,
    CARETRIGHT,
    CARETUP,
    CARETDOWN,
]

# %%
algs_ours = [    
    # ours
    'MP-ADR-Elimination-UCB-ADWIN1; d=0.001',
    'MP-ADS-TS-ADWIN1; d=0.001; r=true',
#    'MP-ADS-TS-ADWIN1; d=0.001; r=false'
]
algs_pass = [
    # passive
    'MP-D-UCB; g=0.9',
    'MP-RExp3; b=1000.0',
    'MP-SW-TS; w=1000',
#    'MP-SW-UCB; w=1000',
    'MP-SW-UCB#-A; nu=0.1; l=12.3', 
    #'MP-SW-UCB#-A; nu=0.2; l=12.3', 
    'MP-SW-UCB#-G; ka=0.1; l=4.3', 
    #'MP-SW-UCB#-G; ka=0.2; l=4.3'
]
algs_act = [
    # active
    'MP-GLR-KL-UCB-G',
#    'MP-GLR-KL-UCB-L',
#    'MP-GLR-KL-UCB-G-F',
#    'MP-GLR-KL-UCB-L-F',
    'MP-M-UCB; w=1000; m=10',
#    'MP-M-UCB; w=5000; m=100',
]
algs_base = [
    # baselines
    'MP-TS',
    'MP-E-G; e=0.9',
    'OR',
    'OD',
    'OS',
    'CustomOracle'
]

# %%
prettynames = {
    'MP-ADR-Elimination-UCB-ADWIN1; d=0.001' : "ADR-E-UCB",
    'MP-ADS-TS-ADWIN1; d=0.001; r=true': "ADR-TS",
    'MP-ADS-TS-ADWIN1; d=0.001; r=false': "ADS-TS",
    'MP-D-UCB; g=0.9': "D-UCB",
    'MP-RExp3; b=1000.0': "RExp3",
    'MP-SW-TS; w=1000': "SW-TS",
    'MP-SW-UCB; w=1000': "SW-UCB",
    'MP-SW-UCB#-A; nu=0.1; l=12.3': "SW-UCB\#-A",
    'MP-SW-UCB#-G; ka=0.1; l=4.3': "SW-UCB\#-G",
    # active
    'MP-GLR-KL-UCB-G': 'GLR-KL-UCB',
    'MP-GLR-KL-UCB-L': 'GLR-KL-UCB-L',
    'MP-GLR-KL-UCB-G-F': 'GLR-KL-UCB-G-F',
    'MP-GLR-KL-UCB-L-F': 'GLR-KL-UCB-L-F',
#    'MP-M-UCB; w=1000; m=10': 'M-UCB; w=1000; m=10',
#    'MP-M-UCB; w=5000; m=100': 'M-UCB; w=5000; m=100',
    'MP-M-UCB; w=1000; m=10': 'M-UCB',
    # baselines
    'MP-TS': 'MP-TS',
    'MP-E-G; e=0.9': 'Espilon-Greedy',
    'OR': "Random Oracle",
    'OD': "Dynamic Oracle",
    'OS': "Static Oracle",
    'CustomOracle': "Custom Oracle"
}

# %%
# compute regret against 'OD', or just the cumulative rewards

# %%
fig, axes = plt.subplots(2, 2, sharey=True, sharex=True,  figsize=(14,10), constrained_layout=True)

L = 5

plt.sca(axes[0][0])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "CustomOracle"].gain.cumsum().reset_index(drop=True)
for bandit in algs_ours + algs_pass:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                             markevery=(i*500,400),  marker=markers[i] , markersize=10)
    i+=1

plt.legend(ncol=1, loc="upper left")
plt.ylabel("$R_T / L$")
plt.ylim([0,2000])
plt.title("Ours vs. passive approaches ($L = %s$)"%L)

plt.sca(axes[1][0])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "CustomOracle"].gain.cumsum().reset_index(drop=True)
for bandit in algs_ours + algs_act:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                             markevery=(i*500,400),  marker=markers[i] , markersize=10)
    i+=1

plt.legend(ncol=1, loc="upper left")
plt.ylabel("$R_T / L$")
plt.ylim([0,2000])
plt.title("Ours vs. active approaches ($L = %s$)"%L)

L = 1

plt.sca(axes[0][1])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "CustomOracle"].gain.cumsum().reset_index(drop=True)
for bandit in algs_ours + algs_pass:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                             markevery=(i*500,400),  marker=markers[i] , markersize=10)
    i+=1

plt.legend(ncol=1, loc="upper left")
plt.ylim([0,2000])
plt.title("Ours vs. passive approaches ($L = %s$)"%L)

plt.sca(axes[1][1])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "CustomOracle"].gain.cumsum().reset_index(drop=True)
for bandit in algs_ours + algs_act:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                             markevery=(i*500,400),  marker=markers[i] , markersize=10)
    i+=1

plt.legend(ncol=1, loc="upper left")
plt.title("Ours vs. active approaches ($L = %s$)"%L)
plt.xlabel("$T$")
plt.ylim([0,2000])

#plt.tight_layout()

plt.suptitle("Cumulative regret over time (abrupt local)", fontsize=25)
plt.savefig("plots/%s_regret_full.pdf"%dataset)

# %%
fig, axes = plt.subplots(1, 2, sharey=True, sharex=True, figsize=(14,5), constrained_layout=True)

L = 1

plt.sca(axes[0])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "CustomOracle"].gain.cumsum().reset_index(drop=True)
for bandit in algs_ours + algs_pass:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                             markevery=(i*500,400),  marker=markers[i] , markersize=10)
    i+=1

plt.ylabel("$R_T$")
plt.legend(ncol=1, loc="upper left")
plt.ylim([0,2000])
plt.title("Ours vs. passive approaches")

plt.sca(axes[1])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "CustomOracle"].gain.cumsum().reset_index(drop=True)
for bandit in algs_ours + algs_act:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                             markevery=(i*500,400),  marker=markers[i] , markersize=10)
    i+=1

plt.legend(ncol=1, loc="upper left")
plt.title("Ours vs. active approaches")
plt.xlabel("$T$")
plt.ylim([0,2000])

#plt.tight_layout()

plt.suptitle("Cumulative regret over time (abrupt local)", fontsize=25)
plt.savefig("plots/%s_regret_Fig6.pdf"%dataset)
