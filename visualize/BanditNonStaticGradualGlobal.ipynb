# %%
import math

import matplotlib as mpl
mpl.rcParams['text.usetex'] = True 
mpl.rcParams['text.latex.preamble'] = [r'\usepackage{libertine}', r'\usepackage{newtxmath}'] 
mpl.rc('font', family='serif')

import numpy as np
import pandas as pd
import seaborn as sns


import matplotlib.pyplot as plt
from matplotlib import rc

from cycler import cycler


mpl.rcParams['ps.usedistiller'] = 'xpdf' 

plt.style.use('seaborn-notebook')
# sns.set_palette("Blues_r")

plt.rcParams['axes.titlesize'] = '25'
plt.rcParams['axes.labelsize'] = '25'
plt.rcParams['legend.fontsize'] = '15'
plt.rcParams['xtick.labelsize'] = '15'
plt.rcParams['ytick.labelsize'] = '15'

monochrome=(cycler('color', sns.color_palette("husl", 8))*2+(cycler('marker', ['v', 's', "o"])*7)[0:16])
plt.rc('axes', prop_cycle=monochrome)

pd.options.display.max_rows = 999
# Out:
# <ipython-input-1-56d1c1821bb1>:5: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   mpl.rcParams['text.latex.preamble'] = [r'\usepackage{libertine}', r'\usepackage{newtxmath}']

# %%
# Change if required
folder = "../experiments/2021-06-09-14-50_BanditNonStaticGradualGlobal_"
dataset = "GradualGlobal"

# %%
masterdata = pd.read_csv("%s/BanditNonStaticGradualGlobal.csv"%folder, sep=",")
narms = masterdata.iloc[0]['k']

# %%
sorted(masterdata.bandit.unique())
# Out:
# ['CustomOracle',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=0.001',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=0.01',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=0.1',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5',
#  'MP-ADS-TS-ADWIN1; d=0.001; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.001; r=true',
#  'MP-ADS-TS-ADWIN1; d=0.01; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.01; r=true',
#  'MP-ADS-TS-ADWIN1; d=0.1; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.1; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-4; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-4; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-5; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-5; r=true',
#  'MP-D-TS; g=0.7',
#  'MP-D-TS; g=0.8',
#  'MP-D-TS; g=0.9',
#  'MP-D-TS; g=0.99',
#  'MP-D-UCB; g=0.7',
#  'MP-D-UCB; g=0.8',
#  'MP-D-UCB; g=0.9',
#  'MP-D-UCB; g=0.99',
#  'MP-E-G; e=0.7',
#  'MP-E-G; e=0.8',
#  'MP-E-G; e=0.9',
#  'MP-E-G; e=0.99',
#  'MP-GLR-KL-UCB-G',
#  'MP-GLR-KL-UCB-G-F',
#  'MP-GLR-KL-UCB-L',
#  'MP-GLR-KL-UCB-L-F',
#  'MP-KLUCB',
#  'MP-M-UCB; w=1000; m=10',
#  'MP-M-UCB; w=1000; m=100',
#  'MP-M-UCB; w=5000; m=10',
#  'MP-M-UCB; w=5000; m=100',
#  'MP-RExp3; b=100.0',
#  'MP-RExp3; b=1000.0',
#  'MP-RExp3; b=500.0',
#  'MP-RExp3; b=5000.0',
#  'MP-SW-TS; w=100',
#  'MP-SW-TS; w=1000',
#  'MP-SW-TS; w=500',
#  'MP-SW-TS; w=5000',
#  'MP-SW-UCB#-A; nu=0.1; l=12.3',
#  'MP-SW-UCB#-A; nu=0.2; l=12.3',
#  'MP-SW-UCB#-G; ka=0.1; l=4.3',
#  'MP-SW-UCB#-G; ka=0.2; l=4.3',
#  'MP-SW-UCB; w=100',
#  'MP-SW-UCB; w=1000',
#  'MP-SW-UCB; w=500',
#  'MP-SW-UCB; w=5000',
#  'MP-TS',
#  'OD',
#  'OR',
#  'OS']

# %%
masterdata.columns
# Out:
# Index(['bandit', 'dataset', 'scalingstrategy', 'k', 'gain', 'cputime',
#        'iteration'],
#       dtype='object')

# %%
masterdata['reward/arm'] = masterdata['gain']/masterdata['k']

# %%
masterdata.shape
# Out:
# (1710000, 8)

# %%
masterdata.groupby(["scalingstrategy", "bandit"])[['gain', 'k', 'reward/arm', 'cputime']].mean()
# Out:
#                                                              gain       k  \
# scalingstrategy bandit
# No-1            CustomOracle                             0.752587  1.0099
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001   0.575419  1.0099
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    0.575664  1.0099
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     0.550689  1.0099
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  0.571167  1.0099
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  0.578695  1.0099
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       0.673232  1.0099
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true        0.674204  1.0099
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        0.672906  1.0099
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         0.662068  1.0099
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         0.668346  1.0099
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true          0.617813  1.0099
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      0.675408  1.0099
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       0.679928  1.0099
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      0.677398  1.0099
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       0.681824  1.0099
#                 MP-D-TS; g=0.7                           0.518471  1.0099
#                 MP-D-TS; g=0.8                           0.525143  1.0099
#                 MP-D-TS; g=0.9                           0.538591  1.0099
#                 MP-D-TS; g=0.99                          0.584432  1.0099
#                 MP-D-UCB; g=0.7                          0.612825  1.0099
#                 MP-D-UCB; g=0.8                          0.613878  1.0099
#                 MP-D-UCB; g=0.9                          0.612973  1.0099
#                 MP-D-UCB; g=0.99                         0.613133  1.0099
#                 MP-E-G; e=0.7                            0.594030  1.0099
#                 MP-E-G; e=0.8                            0.618970  1.0099
#                 MP-E-G; e=0.9                            0.644172  1.0099
#                 MP-E-G; e=0.99                           0.660638  1.0099
#                 MP-GLR-KL-UCB-G                          0.537697  1.0099
#                 MP-GLR-KL-UCB-G-F                        0.604493  1.0099
#                 MP-GLR-KL-UCB-L                          0.504145  1.0099
#                 MP-GLR-KL-UCB-L-F                        0.593144  1.0099
#                 MP-KLUCB                                 0.667847  1.0099
#                 MP-M-UCB; w=1000; m=10                   0.508384  1.0099
#                 MP-M-UCB; w=1000; m=100                  0.508378  1.0099
#                 MP-M-UCB; w=5000; m=10                   0.508447  1.0099
#                 MP-M-UCB; w=5000; m=100                  0.508409  1.0099
#                 MP-RExp3; b=100.0                        0.504668  1.0099
#                 MP-RExp3; b=1000.0                       0.505403  1.0099
#                 MP-RExp3; b=500.0                        0.505540  1.0099
#                 MP-RExp3; b=5000.0                       0.505633  1.0099
#                 MP-SW-TS; w=100                          0.573539  1.0099
#                 MP-SW-TS; w=1000                         0.663363  1.0099
#                 MP-SW-TS; w=500                          0.652567  1.0099
#                 MP-SW-TS; w=5000                         0.683186  1.0099
#                 MP-SW-UCB#-A; nu=0.1; l=12.3             0.536078  1.0099
#                 MP-SW-UCB#-A; nu=0.2; l=12.3             0.529968  1.0099
#                 MP-SW-UCB#-G; ka=0.1; l=4.3              0.504275  1.0099
#                 MP-SW-UCB#-G; ka=0.2; l=4.3              0.503988  1.0099
#                 MP-SW-UCB; w=100                         0.547707  1.0099
#                 MP-SW-UCB; w=1000                        0.600976  1.0099
#                 MP-SW-UCB; w=500                         0.621279  1.0099
#                 MP-SW-UCB; w=5000                        0.643122  1.0099
#                 MP-TS                                    0.668811  1.0099
#                 OD                                       1.004994  1.0099
#                 OR                                       0.505171  1.0099
#                 OS                                       0.516934  1.0099
# No-2            CustomOracle                             1.495155  2.0098
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001   1.190237  2.0098
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    1.174597  2.0098
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     1.101239  2.0098
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  1.214504  2.0098
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  1.204377  2.0098
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       1.375466  2.0098
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true        1.357412  2.0098
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        1.371088  2.0098
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         1.342127  2.0098
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         1.360112  2.0098
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true          1.236501  2.0098
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      1.378784  2.0098
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       1.360543  2.0098
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      1.381818  2.0098
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       1.369666  2.0098
#                 MP-D-TS; g=0.7                           1.056267  2.0098
#                 MP-D-TS; g=0.8                           1.073910  2.0098
#                 MP-D-TS; g=0.9                           1.115471  2.0098
#                 MP-D-TS; g=0.99                          1.180562  2.0098
#                 MP-D-UCB; g=0.7                          1.264506  2.0098
#                 MP-D-UCB; g=0.8                          1.266352  2.0098
#                 MP-D-UCB; g=0.9                          1.265196  2.0098
#                 MP-D-UCB; g=0.99                         1.266696  2.0098
#                 MP-E-G; e=0.7                            1.147770  2.0098
#                 MP-E-G; e=0.8                            1.185687  2.0098
#                 MP-E-G; e=0.9                            1.231597  2.0098
#                 MP-E-G; e=0.99                           1.292179  2.0098
#                 MP-GLR-KL-UCB-G                          1.155013  2.0098
#                 MP-GLR-KL-UCB-G-F                        1.265873  2.0098
#                 MP-GLR-KL-UCB-L                          1.197428  2.0098
#                 MP-GLR-KL-UCB-L-F                        1.261969  2.0098
#                 MP-KLUCB                                 1.355491  2.0098
#                 MP-M-UCB; w=1000; m=10                   1.167000  2.0098
#                 MP-M-UCB; w=1000; m=100                  1.168246  2.0098
#                 MP-M-UCB; w=5000; m=10                   1.167889  2.0098
#                 MP-M-UCB; w=5000; m=100                  1.168307  2.0098
#                 MP-RExp3; b=100.0                        1.004367  2.0098
#                 MP-RExp3; b=1000.0                       1.004581  2.0098
#                 MP-RExp3; b=500.0                        1.005165  2.0098
#                 MP-RExp3; b=5000.0                       1.004874  2.0098
#                 MP-SW-TS; w=100                          1.156551  2.0098
#                 MP-SW-TS; w=1000                         1.359531  2.0098
#                 MP-SW-TS; w=500                          1.328952  2.0098
#                 MP-SW-TS; w=5000                         1.391190  2.0098
#                 MP-SW-UCB#-A; nu=0.1; l=12.3             1.101795  2.0098
#                 MP-SW-UCB#-A; nu=0.2; l=12.3             1.086347  2.0098
#                 MP-SW-UCB#-G; ka=0.1; l=4.3              1.005191  2.0098
#                 MP-SW-UCB#-G; ka=0.2; l=4.3              1.005244  2.0098
#                 MP-SW-UCB; w=100                         1.076637  2.0098
#                 MP-SW-UCB; w=1000                        1.258931  2.0098
#                 MP-SW-UCB; w=500                         1.271227  2.0098
#                 MP-SW-UCB; w=5000                        1.340021  2.0098
#                 MP-TS                                    1.355955  2.0098
#                 OD                                       2.004894  2.0098
#                 OR                                       1.005249  2.0098
#                 OS                                       1.027096  2.0098
# No-5            CustomOracle                             3.692494  5.0095
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001   3.092743  5.0095
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    3.017584  5.0095
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     2.752307  5.0095
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  3.132764  5.0095
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  3.139510  5.0095
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       3.461816  5.0095
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true        3.455141  5.0095
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        3.446675  5.0095
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         3.404297  5.0095
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         3.400026  5.0095
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true          3.094320  5.0095
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      3.469323  5.0095
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       3.470742  5.0095
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      3.479489  5.0095
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       3.467724  5.0095
#                 MP-D-TS; g=0.7                           2.756043  5.0095
#                 MP-D-TS; g=0.8                           2.824710  5.0095
#                 MP-D-TS; g=0.9                           2.890295  5.0095
#                 MP-D-TS; g=0.99                          3.049681  5.0095
#                 MP-D-UCB; g=0.7                          3.272673  5.0095
#                 MP-D-UCB; g=0.8                          3.273917  5.0095
#                 MP-D-UCB; g=0.9                          3.268598  5.0095
#                 MP-D-UCB; g=0.99                         3.270654  5.0095
#                 MP-E-G; e=0.7                            2.703039  5.0095
#                 MP-E-G; e=0.8                            2.768656  5.0095
#                 MP-E-G; e=0.9                            2.879847  5.0095
#                 MP-E-G; e=0.99                           3.103260  5.0095
#                 MP-GLR-KL-UCB-G                          3.132916  5.0095
#                 MP-GLR-KL-UCB-G-F                        3.296751  5.0095
#                 MP-GLR-KL-UCB-L                          3.289954  5.0095
#                 MP-GLR-KL-UCB-L-F                        3.299380  5.0095
#                 MP-KLUCB                                 3.437551  5.0095
#                 MP-M-UCB; w=1000; m=10                   3.202437  5.0095
#                 MP-M-UCB; w=1000; m=100                  3.200788  5.0095
#                 MP-M-UCB; w=5000; m=10                   3.196659  5.0095
#                 MP-M-UCB; w=5000; m=100                  3.197458  5.0095
#                 MP-RExp3; b=100.0                        2.506258  5.0095
#                 MP-RExp3; b=1000.0                       2.506420  5.0095
#                 MP-RExp3; b=500.0                        2.503301  5.0095
#                 MP-RExp3; b=5000.0                       2.503719  5.0095
#                 MP-SW-TS; w=100                          2.920921  5.0095
#                 MP-SW-TS; w=1000                         3.483255  5.0095
#                 MP-SW-TS; w=500                          3.391687  5.0095
#                 MP-SW-TS; w=5000                         3.511478  5.0095
#                 MP-SW-UCB#-A; nu=0.1; l=12.3             2.888233  5.0095
#                 MP-SW-UCB#-A; nu=0.2; l=12.3             2.829852  5.0095
#                 MP-SW-UCB#-G; ka=0.1; l=4.3              2.504806  5.0095
#                 MP-SW-UCB#-G; ka=0.2; l=4.3              2.505240  5.0095
#                 MP-SW-UCB; w=100                         2.722060  5.0095
#                 MP-SW-UCB; w=1000                        3.303780  5.0095
#                 MP-SW-UCB; w=500                         3.253350  5.0095
#                 MP-SW-UCB; w=5000                        3.456637  5.0095
#                 MP-TS                                    3.391493  5.0095
#                 OD                                       5.004594  5.0095
#                 OR                                       2.505028  5.0095
#                 OS                                       2.552327  5.0095
#
#                                                          reward/arm   cputime
# scalingstrategy bandit
# No-1            CustomOracle                               0.747544  0.025825
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001     0.570376  0.375979
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01      0.570621  0.426116
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1       0.545646  0.257734
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4    0.566124  0.398138
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5    0.573652  0.404526
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false         0.668189  0.343217
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true          0.669161  0.394599
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false          0.667863  0.398412
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true           0.657025  0.195995
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false           0.663303  0.394301
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true            0.612770  0.174176
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false        0.670365  0.516092
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true         0.674885  0.431889
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false        0.672355  0.241019
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true         0.676781  0.295938
#                 MP-D-TS; g=0.7                             0.513428  0.172295
#                 MP-D-TS; g=0.8                             0.520100  0.235475
#                 MP-D-TS; g=0.9                             0.533548  0.208980
#                 MP-D-TS; g=0.99                            0.579389  0.203109
#                 MP-D-UCB; g=0.7                            0.607782  0.512893
#                 MP-D-UCB; g=0.8                            0.608835  0.400674
#                 MP-D-UCB; g=0.9                            0.607930  0.174513
#                 MP-D-UCB; g=0.99                           0.608090  0.374471
#                 MP-E-G; e=0.7                              0.588987  0.116963
#                 MP-E-G; e=0.8                              0.613927  0.158920
#                 MP-E-G; e=0.9                              0.639129  0.165555
#                 MP-E-G; e=0.99                             0.655595  0.154716
#                 MP-GLR-KL-UCB-G                            0.532654  0.218757
#                 MP-GLR-KL-UCB-G-F                          0.599450  0.256441
#                 MP-GLR-KL-UCB-L                            0.499102  0.478193
#                 MP-GLR-KL-UCB-L-F                          0.588101  0.290290
#                 MP-KLUCB                                   0.662804  0.168955
#                 MP-M-UCB; w=1000; m=10                     0.503341  0.145101
#                 MP-M-UCB; w=1000; m=100                    0.503335  0.141500
#                 MP-M-UCB; w=5000; m=10                     0.503404  0.148114
#                 MP-M-UCB; w=5000; m=100                    0.503366  0.122044
#                 MP-RExp3; b=100.0                          0.499625  0.345512
#                 MP-RExp3; b=1000.0                         0.500360  0.145153
#                 MP-RExp3; b=500.0                          0.500497  0.326564
#                 MP-RExp3; b=5000.0                         0.500590  0.175704
#                 MP-SW-TS; w=100                            0.568496  0.136322
#                 MP-SW-TS; w=1000                           0.658320  0.335174
#                 MP-SW-TS; w=500                            0.647524  0.212320
#                 MP-SW-TS; w=5000                           0.678143  0.228281
#                 MP-SW-UCB#-A; nu=0.1; l=12.3               0.531035  0.151356
#                 MP-SW-UCB#-A; nu=0.2; l=12.3               0.524925  0.261674
#                 MP-SW-UCB#-G; ka=0.1; l=4.3                0.499232  0.157544
#                 MP-SW-UCB#-G; ka=0.2; l=4.3                0.498945  0.243171
#                 MP-SW-UCB; w=100                           0.542664  0.162515
#                 MP-SW-UCB; w=1000                          0.595933  0.139097
#                 MP-SW-UCB; w=500                           0.616236  0.252680
#                 MP-SW-UCB; w=5000                          0.638079  0.194704
#                 MP-TS                                      0.663768  0.204273
#                 OD                                         0.999951  0.197615
#                 OR                                         0.500128  0.048142
#                 OS                                         0.511891  0.019451
# No-2            CustomOracle                               0.745081  0.023151
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001     0.592622  0.506512
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01      0.584802  0.693983
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1       0.548123  0.418161
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4    0.604756  0.620893
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5    0.599692  0.441693
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false         0.685237  0.114757
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true          0.676210  0.545206
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false          0.683048  0.356600
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true           0.668567  0.256857
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false           0.677560  0.680154
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true            0.615754  0.182990
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false        0.686896  0.672478
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true         0.677775  0.666163
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false        0.688413  0.288056
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true         0.682337  0.537435
#                 MP-D-TS; g=0.7                             0.525637  0.250839
#                 MP-D-TS; g=0.8                             0.534459  0.197334
#                 MP-D-TS; g=0.9                             0.555239  0.302814
#                 MP-D-TS; g=0.99                            0.587785  0.220826
#                 MP-D-UCB; g=0.7                            0.629757  0.527575
#                 MP-D-UCB; g=0.8                            0.630680  0.436135
#                 MP-D-UCB; g=0.9                            0.630102  0.558641
#                 MP-D-UCB; g=0.99                           0.630852  0.662471
#                 MP-E-G; e=0.7                              0.571389  0.098379
#                 MP-E-G; e=0.8                              0.590347  0.179642
#                 MP-E-G; e=0.9                              0.613302  0.243287
#                 MP-E-G; e=0.99                             0.643593  0.198239
#                 MP-GLR-KL-UCB-G                            0.575010  0.361512
#                 MP-GLR-KL-UCB-G-F                          0.630440  0.314108
#                 MP-GLR-KL-UCB-L                            0.596218  0.423587
#                 MP-GLR-KL-UCB-L-F                          0.628488  0.368800
#                 MP-KLUCB                                   0.675249  0.188386
#                 MP-M-UCB; w=1000; m=10                     0.581004  0.204940
#                 MP-M-UCB; w=1000; m=100                    0.581627  0.246559
#                 MP-M-UCB; w=5000; m=10                     0.581448  0.181638
#                 MP-M-UCB; w=5000; m=100                    0.581657  0.255898
#                 MP-RExp3; b=100.0                          0.499687  0.336967
#                 MP-RExp3; b=1000.0                         0.499794  0.285177
#                 MP-RExp3; b=500.0                          0.500086  0.298234
#                 MP-RExp3; b=5000.0                         0.499941  0.290599
#                 MP-SW-TS; w=100                            0.575779  0.274386
#                 MP-SW-TS; w=1000                           0.677269  0.410213
#                 MP-SW-TS; w=500                            0.661980  0.206974
#                 MP-SW-TS; w=5000                           0.693099  0.227227
#                 MP-SW-UCB#-A; nu=0.1; l=12.3               0.548401  0.336621
#                 MP-SW-UCB#-A; nu=0.2; l=12.3               0.540677  0.217508
#                 MP-SW-UCB#-G; ka=0.1; l=4.3                0.500099  0.153200
#                 MP-SW-UCB#-G; ka=0.2; l=4.3                0.500126  0.166765
#                 MP-SW-UCB; w=100                           0.535822  0.192201
#                 MP-SW-UCB; w=1000                          0.626969  0.281494
#                 MP-SW-UCB; w=500                           0.633117  0.300684
#                 MP-SW-UCB; w=5000                          0.667514  0.178797
#                 MP-TS                                      0.675481  0.206434
#                 OD                                         0.999951  0.280477
#                 OR                                         0.500128  0.065609
#                 OS                                         0.511052  0.019452
# No-5            CustomOracle                               0.737531  0.016953
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001     0.617581  0.332147
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01      0.602549  0.517358
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1       0.549494  0.228911
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4    0.625585  0.489173
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5    0.626934  0.437172
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false         0.691395  0.439612
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true          0.690060  0.549243
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false          0.688367  0.409950
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true           0.679892  0.341471
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false           0.679037  0.509279
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true            0.617896  0.268407
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false        0.692897  0.744607
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true         0.693181  0.567480
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false        0.694930  0.416875
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true         0.692577  0.313909
#                 MP-D-TS; g=0.7                             0.550241  0.283575
#                 MP-D-TS; g=0.8                             0.563974  0.152922
#                 MP-D-TS; g=0.9                             0.577091  0.378862
#                 MP-D-TS; g=0.99                            0.608968  0.312643
#                 MP-D-UCB; g=0.7                            0.653567  0.416528
#                 MP-D-UCB; g=0.8                            0.653816  0.543427
#                 MP-D-UCB; g=0.9                            0.652752  0.374127
#                 MP-D-UCB; g=0.99                           0.653163  0.504013
#                 MP-E-G; e=0.7                              0.539640  0.101674
#                 MP-E-G; e=0.8                              0.552763  0.107766
#                 MP-E-G; e=0.9                              0.575002  0.188637
#                 MP-E-G; e=0.99                             0.619684  0.187773
#                 MP-GLR-KL-UCB-G                            0.625615  0.829940
#                 MP-GLR-KL-UCB-G-F                          0.658382  0.672450
#                 MP-GLR-KL-UCB-L                            0.657023  0.867739
#                 MP-GLR-KL-UCB-L-F                          0.658908  0.874320
#                 MP-KLUCB                                   0.686542  0.188574
#                 MP-M-UCB; w=1000; m=10                     0.639520  0.249512
#                 MP-M-UCB; w=1000; m=100                    0.639190  0.269067
#                 MP-M-UCB; w=5000; m=10                     0.638364  0.314722
#                 MP-M-UCB; w=5000; m=100                    0.638524  0.222953
#                 MP-RExp3; b=100.0                          0.500284  0.332449
#                 MP-RExp3; b=1000.0                         0.500316  0.366361
#                 MP-RExp3; b=500.0                          0.499692  0.443932
#                 MP-RExp3; b=5000.0                         0.499776  0.577391
#                 MP-SW-TS; w=100                            0.583216  0.214044
#                 MP-SW-TS; w=1000                           0.695683  0.228113
#                 MP-SW-TS; w=500                            0.677370  0.161141
#                 MP-SW-TS; w=5000                           0.701328  0.229584
#                 MP-SW-UCB#-A; nu=0.1; l=12.3               0.576679  0.238762
#                 MP-SW-UCB#-A; nu=0.2; l=12.3               0.565003  0.370031
#                 MP-SW-UCB#-G; ka=0.1; l=4.3                0.499993  0.198006
#                 MP-SW-UCB#-G; ka=0.2; l=4.3                0.500080  0.279778
#                 MP-SW-UCB; w=100                           0.543444  0.261542
#                 MP-SW-UCB; w=1000                          0.659788  0.178775
#                 MP-SW-UCB; w=500                           0.649702  0.205692
#                 MP-SW-UCB; w=5000                          0.690360  0.261817
#                 MP-TS                                      0.677331  0.185319
#                 OD                                         0.999951  0.207082
#                 OR                                         0.500038  0.089180
#                 OS                                         0.509498  0.018571

# %%
masterdata['dataset'].unique()
# Out:
# array(['GradualGlobalGenerator-100'], dtype=object)

# %%
from matplotlib.markers import TICKLEFT, TICKRIGHT, TICKUP, TICKDOWN, CARETLEFT, CARETRIGHT, CARETUP, CARETDOWN
markers = [
#    '.',
#    ',',
    'v',
    'o',
    '^',
    '<',
    '>',
#    '1',
#    '2',
#    '3',
#    '4',
#    '8',
    's',
    'p',
    '*',
#    'h',
    'H',
    '+',
    'x',
    'D',
#    'd',
    '|',
    '_',
    TICKLEFT,
    TICKRIGHT,
    TICKUP,
    TICKDOWN,
    CARETLEFT,
    CARETRIGHT,
    CARETUP,
    CARETDOWN,
]

# %%
algs_ours = [    
    # ours
    'MP-ADR-Elimination-UCB-ADWIN1; d=0.001',
    'MP-ADS-TS-ADWIN1; d=0.001; r=true',
#    'MP-ADS-TS-ADWIN1; d=0.001; r=false'
]
algs_pass = [
    # passive
    'MP-D-UCB; g=0.9',
    'MP-RExp3; b=1000.0',
    'MP-SW-TS; w=1000',
#    'MP-SW-UCB; w=1000',
    'MP-SW-UCB#-A; nu=0.1; l=12.3', 
    'MP-SW-UCB#-G; ka=0.1; l=4.3', 
    
    #'MP-SW-UCB#-A; nu=0.2; l=12.3', 
    #'MP-SW-UCB#-G; ka=0.2; l=4.3'
]
algs_act = [
    # active
    'MP-GLR-KL-UCB-G',
#    'MP-GLR-KL-UCB-L',
#    'MP-GLR-KL-UCB-G-F',
#    'MP-GLR-KL-UCB-L-F',
    'MP-M-UCB; w=1000; m=10',
#    'MP-M-UCB; w=5000; m=100',
]
algs_base = [
    # baselines
    'MP-TS',
    'MP-E-G; e=0.9',
    'OR',
    'OD',
    'OS',
    'CustomOracle'
]

# %%
prettynames = {
    'MP-ADR-Elimination-UCB-ADWIN1; d=0.001' : "ADR-E-UCB",
    'MP-ADS-TS-ADWIN1; d=0.001; r=true': "ADR-TS",
    'MP-ADS-TS-ADWIN1; d=0.001; r=false': "ADS-TS",
    'MP-D-UCB; g=0.9': "D-UCB",
    'MP-RExp3; b=1000.0': "RExp3",
    'MP-SW-TS; w=1000': "SW-TS",
    'MP-SW-UCB; w=1000': "SW-UCB",
    'MP-SW-UCB#-A; nu=0.1; l=12.3': "SW-UCB\#-A",
    'MP-SW-UCB#-G; ka=0.1; l=4.3': "SW-UCB\#-G",
    # active
    'MP-GLR-KL-UCB-G': 'GLR-KL-UCB',
    'MP-GLR-KL-UCB-L': 'GLR-KL-UCB-L',
    'MP-GLR-KL-UCB-G-F': 'GLR-KL-UCB-G-F',
    'MP-GLR-KL-UCB-L-F': 'GLR-KL-UCB-L-F',
#    'MP-M-UCB; w=1000; m=10': 'M-UCB; w=1000; m=10',
#    'MP-M-UCB; w=5000; m=100': 'M-UCB; w=5000; m=100',
    'MP-M-UCB; w=1000; m=10': 'M-UCB',
    # baselines
    'MP-TS': 'MP-TS',
    'MP-E-G; e=0.9': 'Espilon-Greedy',
    'OR': "Random Oracle",
    'OD': "Dynamic Oracle",
    'OS': "Static Oracle",
    'CustomOracle': "Custom Oracle"
}

# %%
# compute regret against 'OD', or just the cumulative rewards

# %%
fig, axes = plt.subplots(2, 2, sharey=True, sharex=True, figsize=(14,10), constrained_layout=True)

L = 5

plt.sca(axes[0][0])

subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]

for bandit in algs_ours + algs_pass:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "CustomOracle"].gain.cumsum().reset_index(drop=True)
for bandit in algs_ours + algs_pass:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                             markevery=(i*500,400), marker=markers[i] , markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)    
plt.legend(ncol=1, loc="upper left")
plt.ylabel("$R_T / L$")
plt.title("Ours vs. passive approaches ($L = %s$)"%L)

plt.sca(axes[1][0])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "CustomOracle"].gain.cumsum().reset_index(drop=True)
for bandit in algs_ours + algs_act:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                             markevery=(i*500,400), marker=markers[i] , markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)    
plt.legend(ncol=1, loc="upper left")
plt.ylabel("$R_T / L$")
plt.title("Ours vs. active approaches ($L = %s$)"%L)
plt.xlabel("$T$")


L = 1

plt.sca(axes[0][1])

subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]

for bandit in algs_ours + algs_pass:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "CustomOracle"].gain.cumsum().reset_index(drop=True)
for bandit in algs_ours + algs_pass:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                             markevery=(i*500,400), marker=markers[i] , markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)    
plt.legend(ncol=1, loc="upper left")
plt.title("Ours vs. passive approaches ($L = %s$)"%L)

plt.sca(axes[1][1])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "CustomOracle"].gain.cumsum().reset_index(drop=True)
for bandit in algs_ours + algs_act:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                             markevery=(i*500,400), marker=markers[i] , markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)    
plt.legend(ncol=1, loc="upper left")
plt.title("Ours vs. active approaches ($L = %s$)"%L)
plt.xlabel("$T$")

#plt.tight_layout()

plt.suptitle("Cumulative regret over time (gradual)", fontsize=25)
plt.savefig("plots/%s_regret_full_Fig11.pdf"%dataset)

# %%
fig, axes = plt.subplots(1, 2, sharey=True, sharex=True, figsize=(14,5), constrained_layout=True)


L = 1

plt.sca(axes[0])

subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]

for bandit in algs_ours + algs_pass:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "CustomOracle"].gain.cumsum().reset_index(drop=True)
for bandit in algs_ours + algs_pass:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                             markevery=(i*500,400), marker=markers[i] , markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)    
plt.legend(ncol=1, loc="upper left")
plt.title("Ours vs. passive approaches")
#plt.title("Ours vs. passive approaches ($L = %s$)"%L)
plt.xlabel("$T$")
plt.ylabel("$R_T$")

plt.sca(axes[1])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "CustomOracle"].gain.cumsum().reset_index(drop=True)
for bandit in algs_ours + algs_act:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                             markevery=(i*500,400), marker=markers[i] , markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)    
plt.legend(ncol=1, loc="upper left")
plt.title("Ours vs. active approaches")
#plt.title("Ours vs. active approaches ($L = %s$)"%L)
plt.xlabel("$T$")

#plt.tight_layout()

plt.suptitle("Cumulative regret over time (gradual)", fontsize=25)
plt.savefig("plots/%s_regret_Fig5c.pdf"%dataset)
