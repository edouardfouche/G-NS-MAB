# %%
import math

import matplotlib as mpl
mpl.rcParams['text.usetex'] = True 
mpl.rcParams['text.latex.preamble'] = [r'\usepackage{libertine}', r'\usepackage{newtxmath}'] 
mpl.rc('font', family='serif')

import numpy as np
import pandas as pd
import seaborn as sns


import matplotlib.pyplot as plt
from matplotlib import rc

from cycler import cycler


mpl.rcParams['ps.usedistiller'] = 'xpdf' 

plt.style.use('seaborn-notebook')
# sns.set_palette("Blues_r")

plt.rcParams['axes.titlesize'] = '25'
plt.rcParams['axes.labelsize'] = '25'
plt.rcParams['legend.fontsize'] = '15'
plt.rcParams['xtick.labelsize'] = '15'
plt.rcParams['ytick.labelsize'] = '15'

monochrome=(cycler('color', sns.color_palette("husl", 8))*2+(cycler('marker', ['v', 's', "o"])*7)[0:16])
plt.rc('axes', prop_cycle=monochrome)

pd.options.display.max_rows = 999
# Out:
# /var/folders/8v/5czrtjp134z_qn6j_jsmrnl80000gn/T/ipykernel_14109/831503919.py:5: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   mpl.rcParams['text.latex.preamble'] = [r'\usepackage{libertine}', r'\usepackage{newtxmath}']
# /var/folders/8v/5czrtjp134z_qn6j_jsmrnl80000gn/T/ipykernel_14109/831503919.py:21: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-notebook')

# %%
# Change if required
folder = "../experiments/2022-11-14-16-05_BanditNonStaticGradualGlobal_"
dataset = "GradualGlobal"

# %%
masterdata = pd.read_csv("%s/BanditNonStaticGradualGlobal.csv"%folder, sep=",")
narms = masterdata.iloc[0]['k']

# %%
sorted(masterdata.bandit.unique())
# Out:
# ['CustomOracle',
#  'ImpCPD',
#  'ImpCPD2',
#  'ImpCPD3',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=0.001',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=0.01',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=0.1',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-12',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-15',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-6',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-7',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-8',
#  'MP-ADS-KL-UCB-ADWIN1; d=0.001; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=0.001; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=0.01; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=0.01; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=0.1; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=0.1; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-15; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-15; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-5; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-5; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-7; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-7; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=true',
#  'MP-ADS-TS-ADWIN1; d=0.001; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.001; r=true',
#  'MP-ADS-TS-ADWIN1; d=0.01; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.01; r=true',
#  'MP-ADS-TS-ADWIN1; d=0.1; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.1; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-12; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-12; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-15; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-15; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-4; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-4; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-5; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-5; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-6; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-6; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-7; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-7; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-8; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-8; r=true',
#  'MP-D-TS; g=0.7',
#  'MP-D-TS; g=0.8',
#  'MP-D-TS; g=0.9',
#  'MP-D-TS; g=0.99',
#  'MP-D-TS; g=0.999',
#  'MP-D-UCB; g=0.7',
#  'MP-D-UCB; g=0.8',
#  'MP-D-UCB; g=0.9',
#  'MP-D-UCB; g=0.99',
#  'MP-D-UCB; g=0.999',
#  'MP-E-G; e=0.7',
#  'MP-E-G; e=0.8',
#  'MP-E-G; e=0.9',
#  'MP-E-G; e=0.99',
#  'MP-GLR-KL-UCB-G',
#  'MP-GLR-KL-UCB-L',
#  'MP-KLUCB',
#  'MP-M-UCB; w=1000; m=10',
#  'MP-M-UCB; w=1000; m=100',
#  'MP-M-UCB; w=5000; m=10',
#  'MP-M-UCB; w=5000; m=100',
#  'MP-RExp3; b=100.0',
#  'MP-RExp3; b=1000.0',
#  'MP-RExp3; b=500.0',
#  'MP-RExp3; b=5000.0',
#  'MP-SW-TS; w=100',
#  'MP-SW-TS; w=1000',
#  'MP-SW-TS; w=500',
#  'MP-SW-TS; w=5000',
#  'MP-SW-UCB#-A; nu=0.1; l=12.3',
#  'MP-SW-UCB#-A; nu=0.2; l=12.3',
#  'MP-SW-UCB#-G; ka=0.1; l=4.3',
#  'MP-SW-UCB#-G; ka=0.2; l=4.3',
#  'MP-SW-UCB; w=100',
#  'MP-SW-UCB; w=1000',
#  'MP-SW-UCB; w=500',
#  'MP-SW-UCB; w=5000',
#  'MP-TS',
#  'OD',
#  'OR',
#  'OS',
#  'UCBL-CPD']

# %%
masterdata.columns
# Out:
# Index(['bandit', 'dataset', 'scalingstrategy', 'k', 'gain', 'cputime',
#        'iteration'],
#       dtype='object')

# %%
masterdata['reward/arm'] = masterdata['gain']/masterdata['k']

# %%
masterdata.shape
# Out:
# (960000, 8)

# %%
masterdata.groupby(["scalingstrategy", "bandit"])[['gain', 'k', 'reward/arm', 'cputime']].mean()
# Out:
#                                                               gain    k  \
# scalingstrategy bandit
# No-1            CustomOracle                              0.747593  1.0
#                 ImpCPD                                    0.652636  1.0
#                 ImpCPD2                                   0.625070  1.0
#                 ImpCPD3                                   0.619926  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001    0.568543  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01     0.567944  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1      0.544231  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-12  0.602703  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-15  0.603929  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4   0.565689  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5   0.572970  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-6   0.583808  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-7   0.596224  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-8   0.599749  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=0.001; r=false    0.687604  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=0.001; r=true     0.692461  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=0.01; r=false     0.690697  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=0.01; r=true      0.687183  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=0.1; r=false      0.688395  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=0.1; r=true       0.649492  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=false  0.694244  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=true   0.689361  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-15; r=false  0.688657  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-15; r=true   0.691267  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=false   0.683774  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=true    0.685492  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-5; r=false   0.691141  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-5; r=true    0.679993  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=false   0.687820  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=true    0.675585  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-7; r=false   0.687318  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-7; r=true    0.677385  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=false   0.689309  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=true    0.679688  1.0
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false        0.664674  1.0
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true         0.664362  1.0
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false         0.661896  1.0
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true          0.653378  1.0
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false          0.661247  1.0
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true           0.610942  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-12; r=false      0.666495  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-12; r=true       0.660053  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-15; r=false      0.663373  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-15; r=true       0.658299  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false       0.665168  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true        0.671244  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false       0.666153  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true        0.672407  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-6; r=false       0.667463  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-6; r=true        0.672611  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-7; r=false       0.667400  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-7; r=true        0.669514  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-8; r=false       0.669773  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-8; r=true        0.668141  1.0
#                 MP-D-TS; g=0.7                            0.513662  1.0
#                 MP-D-TS; g=0.8                            0.519757  1.0
#                 MP-D-TS; g=0.9                            0.533185  1.0
#                 MP-D-TS; g=0.99                           0.577188  1.0
#                 MP-D-TS; g=0.999                          0.611648  1.0
#                 MP-D-UCB; g=0.7                           0.605159  1.0
#                 MP-D-UCB; g=0.8                           0.605585  1.0
#                 MP-D-UCB; g=0.9                           0.605850  1.0
#                 MP-D-UCB; g=0.99                          0.606093  1.0
#                 MP-D-UCB; g=0.999                         0.604852  1.0
#                 MP-E-G; e=0.7                             0.595150  1.0
#                 MP-E-G; e=0.8                             0.619667  1.0
#                 MP-E-G; e=0.9                             0.642677  1.0
#                 MP-E-G; e=0.99                            0.655886  1.0
#                 MP-GLR-KL-UCB-G                           0.535638  1.0
#                 MP-GLR-KL-UCB-L                           0.505214  1.0
#                 MP-KLUCB                                  0.658401  1.0
#                 MP-M-UCB; w=1000; m=10                    0.503255  1.0
#                 MP-M-UCB; w=1000; m=100                   0.503289  1.0
#                 MP-M-UCB; w=5000; m=10                    0.503293  1.0
#                 MP-M-UCB; w=5000; m=100                   0.503311  1.0
#                 MP-RExp3; b=100.0                         0.500034  1.0
#                 MP-RExp3; b=1000.0                        0.500533  1.0
#                 MP-RExp3; b=500.0                         0.499340  1.0
#                 MP-RExp3; b=5000.0                        0.500024  1.0
#                 MP-SW-TS; w=100                           0.569719  1.0
#                 MP-SW-TS; w=1000                          0.653832  1.0
#                 MP-SW-TS; w=500                           0.644646  1.0
#                 MP-SW-TS; w=5000                          0.672790  1.0
#                 MP-SW-UCB#-A; nu=0.1; l=12.3              0.531299  1.0
#                 MP-SW-UCB#-A; nu=0.2; l=12.3              0.525007  1.0
#                 MP-SW-UCB#-G; ka=0.1; l=4.3               0.500348  1.0
#                 MP-SW-UCB#-G; ka=0.2; l=4.3               0.499675  1.0
#                 MP-SW-UCB; w=100                          0.551244  1.0
#                 MP-SW-UCB; w=1000                         0.592742  1.0
#                 MP-SW-UCB; w=500                          0.616950  1.0
#                 MP-SW-UCB; w=5000                         0.635801  1.0
#                 MP-TS                                     0.659259  1.0
#                 OD                                        1.000000  1.0
#                 OR                                        0.499852  1.0
#                 OS                                        0.511895  1.0
#                 UCBL-CPD                                  0.635491  1.0
#
#                                                           reward/arm   cputime
# scalingstrategy bandit
# No-1            CustomOracle                                0.747593  0.026364
#                 ImpCPD                                      0.652636  0.411193
#                 ImpCPD2                                     0.625070  1.565697
#                 ImpCPD3                                     0.619926  0.768619
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001      0.568543  0.301433
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01       0.567944  0.301349
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1        0.544231  0.498559
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-12    0.602703  0.433301
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-15    0.603929  0.828064
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4     0.565689  0.634870
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5     0.572970  0.739424
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-6     0.583808  0.792347
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-7     0.596224  0.809856
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-8     0.599749  0.747038
#                 MP-ADS-KL-UCB-ADWIN1; d=0.001; r=false      0.687604  0.308679
#                 MP-ADS-KL-UCB-ADWIN1; d=0.001; r=true       0.692461  0.195715
#                 MP-ADS-KL-UCB-ADWIN1; d=0.01; r=false       0.690697  0.340653
#                 MP-ADS-KL-UCB-ADWIN1; d=0.01; r=true        0.687183  0.495099
#                 MP-ADS-KL-UCB-ADWIN1; d=0.1; r=false        0.688395  0.331168
#                 MP-ADS-KL-UCB-ADWIN1; d=0.1; r=true         0.649492  0.240187
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=false    0.694244  0.694587
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=true     0.689361  0.471749
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-15; r=false    0.688657  0.515291
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-15; r=true     0.691267  0.354660
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=false     0.683774  0.485304
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=true      0.685492  0.219497
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-5; r=false     0.691141  0.425571
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-5; r=true      0.679993  0.353571
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=false     0.687820  0.492242
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=true      0.675585  0.513575
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-7; r=false     0.687318  0.284708
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-7; r=true      0.677385  0.284186
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=false     0.689309  0.263499
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=true      0.679688  0.342183
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false          0.664674  0.511802
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true           0.664362  0.329858
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false           0.661896  0.509043
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true            0.653378  0.628425
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false            0.661247  0.740095
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true             0.610942  0.328641
#                 MP-ADS-TS-ADWIN1; d=1.0E-12; r=false        0.666495  0.649672
#                 MP-ADS-TS-ADWIN1; d=1.0E-12; r=true         0.660053  0.552930
#                 MP-ADS-TS-ADWIN1; d=1.0E-15; r=false        0.663373  0.659718
#                 MP-ADS-TS-ADWIN1; d=1.0E-15; r=true         0.658299  0.395473
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false         0.665168  0.674856
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true          0.671244  0.443157
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false         0.666153  0.377794
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true          0.672407  0.616112
#                 MP-ADS-TS-ADWIN1; d=1.0E-6; r=false         0.667463  0.515472
#                 MP-ADS-TS-ADWIN1; d=1.0E-6; r=true          0.672611  0.249587
#                 MP-ADS-TS-ADWIN1; d=1.0E-7; r=false         0.667400  0.404313
#                 MP-ADS-TS-ADWIN1; d=1.0E-7; r=true          0.669514  0.191922
#                 MP-ADS-TS-ADWIN1; d=1.0E-8; r=false         0.669773  0.598679
#                 MP-ADS-TS-ADWIN1; d=1.0E-8; r=true          0.668141  0.470441
#                 MP-D-TS; g=0.7                              0.513662  0.165025
#                 MP-D-TS; g=0.8                              0.519757  0.155224
#                 MP-D-TS; g=0.9                              0.533185  0.283693
#                 MP-D-TS; g=0.99                             0.577188  0.308651
#                 MP-D-TS; g=0.999                            0.611648  0.264615
#                 MP-D-UCB; g=0.7                             0.605159  0.723062
#                 MP-D-UCB; g=0.8                             0.605585  0.822302
#                 MP-D-UCB; g=0.9                             0.605850  0.772128
#                 MP-D-UCB; g=0.99                            0.606093  0.579236
#                 MP-D-UCB; g=0.999                           0.604852  0.700518
#                 MP-E-G; e=0.7                               0.595150  0.243592
#                 MP-E-G; e=0.8                               0.619667  0.191974
#                 MP-E-G; e=0.9                               0.642677  0.185418
#                 MP-E-G; e=0.99                              0.655886  0.187736
#                 MP-GLR-KL-UCB-G                             0.535638  0.616195
#                 MP-GLR-KL-UCB-L                             0.505214  0.602933
#                 MP-KLUCB                                    0.658401  0.315066
#                 MP-M-UCB; w=1000; m=10                      0.503255  0.128808
#                 MP-M-UCB; w=1000; m=100                     0.503289  0.347424
#                 MP-M-UCB; w=5000; m=10                      0.503293  0.192862
#                 MP-M-UCB; w=5000; m=100                     0.503311  0.187083
#                 MP-RExp3; b=100.0                           0.500034  0.402475
#                 MP-RExp3; b=1000.0                          0.500533  0.612913
#                 MP-RExp3; b=500.0                           0.499340  0.791159
#                 MP-RExp3; b=5000.0                          0.500024  0.232609
#                 MP-SW-TS; w=100                             0.569719  0.302548
#                 MP-SW-TS; w=1000                            0.653832  0.145498
#                 MP-SW-TS; w=500                             0.644646  0.401081
#                 MP-SW-TS; w=5000                            0.672790  0.278279
#                 MP-SW-UCB#-A; nu=0.1; l=12.3                0.531299  0.277197
#                 MP-SW-UCB#-A; nu=0.2; l=12.3                0.525007  0.320897
#                 MP-SW-UCB#-G; ka=0.1; l=4.3                 0.500348  0.261666
#                 MP-SW-UCB#-G; ka=0.2; l=4.3                 0.499675  0.190480
#                 MP-SW-UCB; w=100                            0.551244  0.215891
#                 MP-SW-UCB; w=1000                           0.592742  0.169948
#                 MP-SW-UCB; w=500                            0.616950  0.269038
#                 MP-SW-UCB; w=5000                           0.635801  0.121239
#                 MP-TS                                       0.659259  0.171851
#                 OD                                          1.000000  0.154582
#                 OR                                          0.499852  0.091842
#                 OS                                          0.511895  0.012919
#                 UCBL-CPD                                    0.635491  0.889403

# %%
masterdata['dataset'].unique()
# Out:
# array(['GradualGlobalGenerator-100'], dtype=object)

# %%
from matplotlib.markers import TICKLEFT, TICKRIGHT, TICKUP, TICKDOWN, CARETLEFT, CARETRIGHT, CARETUP, CARETDOWN
markers = [
#    '.',
#    ',',
    'v',
    'o',
    '^',
    '<',
    '>',
#    '1',
#    '2',
#    '3',
#    '4',
#    '8',
    's',
    'p',
    '*',
#    'h',
    'H',
    '+',
    'x',
    'D',
#    'd',
    '|',
    '_',
    TICKLEFT,
    TICKRIGHT,
    TICKUP,
    TICKDOWN,
    CARETLEFT,
    CARETRIGHT,
    CARETUP,
    CARETDOWN,
]

# %%
algs_ours = [    
    # ours
    'MP-ADR-Elimination-UCB-ADWIN1; d=0.001',
    'MP-ADS-TS-ADWIN1; d=0.001; r=true',
    'MP-ADS-KL-UCB-ADWIN1; d=0.001; r=true',
#    'MP-ADS-TS-ADWIN1; d=0.001; r=false'
]
algs_pass = [
    # passive
    'MP-D-UCB; g=0.9',
    'MP-RExp3; b=1000.0',
    'MP-SW-TS; w=1000',
#    'MP-SW-UCB; w=1000',
    'MP-SW-UCB#-A; nu=0.1; l=12.3', 
    #'MP-SW-UCB#-A; nu=0.2; l=12.3', 
    'MP-SW-UCB#-G; ka=0.1; l=4.3', 
    #'MP-SW-UCB#-G; ka=0.2; l=4.3'
]
algs_act = [
    # active
    'MP-GLR-KL-UCB-G',
#    'MP-GLR-KL-UCB-L',
#    'MP-GLR-KL-UCB-G-F',
#    'MP-GLR-KL-UCB-L-F',
    'MP-M-UCB; w=1000; m=10',
#    'MP-M-UCB; w=5000; m=100',
    #'ImpCPD',
    'ImpCPD2',
    #'ImpCPD3', 
    'UCBL-CPD'
]
algs_base = [
    # baselines
    'MP-TS',
    'MP-E-G; e=0.9',
    'OR',
    'OD',
    'OS',
    'CustomOracle'
]

# %%
prettynames = {
    'MP-ADR-Elimination-UCB-ADWIN1; d=0.001' : "ADR-E-UCB",
    'MP-ADS-TS-ADWIN1; d=0.001; r=true': "ADR-TS",
    'MP-ADS-TS-ADWIN1; d=0.001; r=false': "ADS-TS",
    'MP-ADS-KL-UCB-ADWIN1; d=0.001; r=true':'ADR-KL-UCB',
    'MP-D-UCB; g=0.9': "D-UCB",
    'MP-RExp3; b=1000.0': "RExp3",
    'MP-SW-TS; w=1000': "SW-TS",
    'MP-SW-UCB; w=1000': "SW-UCB",
    'MP-SW-UCB#-A; nu=0.1; l=12.3': "SW-UCB\#-A",
    'MP-SW-UCB#-G; ka=0.1; l=4.3': "SW-UCB\#-G",
    # active
    'MP-GLR-KL-UCB-G': 'GLR-KL-UCB',
    'MP-GLR-KL-UCB-L': 'GLR-KL-UCB-L',
    'MP-GLR-KL-UCB-G-F': 'GLR-KL-UCB-G-F',
    'MP-GLR-KL-UCB-L-F': 'GLR-KL-UCB-L-F',
#    'MP-M-UCB; w=1000; m=10': 'M-UCB; w=1000; m=10',
#    'MP-M-UCB; w=5000; m=100': 'M-UCB; w=5000; m=100',
    'MP-M-UCB; w=1000; m=10': 'M-UCB',
    'ImpCPD': 'ImpCPD1',
    'ImpCPD2': 'ImpCPD',
    'ImpCPD3': 'ImpCPD3', 
    'UCBL-CPD': 'UCBL-CPD',
    # baselines
    'MP-TS': 'MP-TS',
    'MP-E-G; e=0.9': 'Espilon-Greedy',
    'OR': "Random Oracle",
    'OD': "Dynamic Oracle",
    'OS': "Static Oracle",
    'CustomOracle': "Custom Oracle"
}

# %%
# compute regret against 'OD', or just the cumulative rewards

# %%
fig, axes = plt.subplots(1, 2, sharey=True, sharex=True, figsize=(14,5), constrained_layout=True)


L = 1

plt.sca(axes[0])

subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]

for bandit in algs_ours + algs_pass:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "CustomOracle"].gain.cumsum().reset_index(drop=True)
for bandit in algs_ours + algs_pass:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                             markevery=(i*500,400), marker=markers[i] , markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)    
plt.legend(ncol=1, loc="upper left")
plt.title("Ours vs. passive approaches")
#plt.title("Ours vs. passive approaches ($L = %s$)"%L)
plt.xlabel("$T$")
plt.ylabel("$R_T$")

plt.sca(axes[1])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "CustomOracle"].gain.cumsum().reset_index(drop=True)
for bandit in algs_ours + algs_act:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                             markevery=(i*500,400), marker=markers[i] , markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)    
plt.legend(ncol=1, loc="upper left")
plt.title("Ours vs. active approaches")
#plt.title("Ours vs. active approaches ($L = %s$)"%L)
plt.xlabel("$T$")

#plt.tight_layout()

plt.suptitle("Cumulative regret over time (gradual)", fontsize=25)
plt.savefig("plots/%s_regret_Fig5c.pdf"%dataset)
