# %%
import math

import matplotlib as mpl
mpl.rcParams['text.usetex'] = True 
mpl.rcParams['text.latex.preamble'] = [r'\usepackage{libertine}', r'\usepackage{newtxmath}'] 
mpl.rc('font', family='serif')

import numpy as np
import pandas as pd
import seaborn as sns


import matplotlib.pyplot as plt
from matplotlib import rc

from cycler import cycler


mpl.rcParams['ps.usedistiller'] = 'xpdf' 

plt.style.use('seaborn-notebook')
# sns.set_palette("Blues_r")

plt.rcParams['axes.titlesize'] = '25'
plt.rcParams['axes.labelsize'] = '25'
plt.rcParams['legend.fontsize'] = '15'
plt.rcParams['xtick.labelsize'] = '15'
plt.rcParams['ytick.labelsize'] = '15'

monochrome=(cycler('color', sns.color_palette("husl", 8))*2+(cycler('marker', ['v', 's', "o"])*7)[0:16])
plt.rc('axes', prop_cycle=monochrome)

pd.options.display.max_rows = 999
# Out:
# <ipython-input-1-56d1c1821bb1>:5: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   mpl.rcParams['text.latex.preamble'] = [r'\usepackage{libertine}', r'\usepackage{newtxmath}']

# %%
# Change if required
folder = "../experiments/2021-06-16-20-28_BanditNonStaticAbrupt_long"
dataset = "Abrupt-long"

# %%
masterdata = pd.read_csv("%s/BanditNonStaticAbrupt.csv"%folder, sep=",")
narms = masterdata.iloc[0]['k']

# %%
sorted(masterdata.bandit.unique())
# Out:
# ['CustomOracle',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=0.001',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=0.01',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=0.1',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5',
#  'MP-ADS-TS-ADWIN1; d=0.001; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.001; r=true',
#  'MP-ADS-TS-ADWIN1; d=0.01; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.01; r=true',
#  'MP-ADS-TS-ADWIN1; d=0.1; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.1; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-4; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-4; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-5; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-5; r=true',
#  'MP-D-TS; g=0.7',
#  'MP-D-TS; g=0.8',
#  'MP-D-TS; g=0.9',
#  'MP-D-TS; g=0.99',
#  'MP-D-UCB; g=0.7',
#  'MP-D-UCB; g=0.8',
#  'MP-D-UCB; g=0.9',
#  'MP-D-UCB; g=0.99',
#  'MP-E-G; e=0.7',
#  'MP-E-G; e=0.8',
#  'MP-E-G; e=0.9',
#  'MP-E-G; e=0.99',
#  'MP-GLR-KL-UCB-G',
#  'MP-GLR-KL-UCB-G-F',
#  'MP-GLR-KL-UCB-L',
#  'MP-GLR-KL-UCB-L-F',
#  'MP-KLUCB',
#  'MP-M-UCB; w=1000; m=10',
#  'MP-M-UCB; w=1000; m=100',
#  'MP-M-UCB; w=5000; m=10',
#  'MP-M-UCB; w=5000; m=100',
#  'MP-RExp3; b=100.0',
#  'MP-RExp3; b=1000.0',
#  'MP-RExp3; b=500.0',
#  'MP-RExp3; b=5000.0',
#  'MP-SW-TS; w=100',
#  'MP-SW-TS; w=1000',
#  'MP-SW-TS; w=500',
#  'MP-SW-TS; w=5000',
#  'MP-SW-UCB#-A; nu=0.1; l=12.3',
#  'MP-SW-UCB#-A; nu=0.2; l=12.3',
#  'MP-SW-UCB#-G; ka=0.1; l=4.3',
#  'MP-SW-UCB#-G; ka=0.2; l=4.3',
#  'MP-SW-UCB; w=100',
#  'MP-SW-UCB; w=1000',
#  'MP-SW-UCB; w=500',
#  'MP-SW-UCB; w=5000',
#  'MP-TS',
#  'OD',
#  'OR',
#  'OS']

# %%
masterdata.columns
# Out:
# Index(['bandit', 'dataset', 'scalingstrategy', 'k', 'gain', 'cputime',
#        'iteration'],
#       dtype='object')

# %%
masterdata['reward/arm'] = masterdata['gain']/masterdata['k']

# %%
masterdata.shape
# Out:
# (17100000, 8)

# %%
masterdata.groupby(["scalingstrategy", "bandit"])[['gain', 'k', 'reward/arm', 'cputime']].mean()
# Out:
#                                                              gain        k  \
# scalingstrategy bandit
# No-1            CustomOracle                             0.967152  1.00099
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001   0.837428  1.00099
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    0.790059  1.00099
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     0.616212  1.00099
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  0.839231  1.00099
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  0.839147  1.00099
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       0.934307  1.00099
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true        0.937045  1.00099
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        0.943166  1.00099
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         0.942117  1.00099
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         0.944453  1.00099
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true          0.898364  1.00099
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      0.934489  1.00099
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       0.935543  1.00099
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      0.934204  1.00099
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       0.936706  1.00099
#                 MP-D-TS; g=0.7                           0.845388  1.00099
#                 MP-D-TS; g=0.8                           0.866167  1.00099
#                 MP-D-TS; g=0.9                           0.902917  1.00099
#                 MP-D-TS; g=0.99                          0.874927  1.00099
#                 MP-D-UCB; g=0.7                          0.879712  1.00099
#                 MP-D-UCB; g=0.8                          0.878292  1.00099
#                 MP-D-UCB; g=0.9                          0.877904  1.00099
#                 MP-D-UCB; g=0.99                         0.879326  1.00099
#                 MP-E-G; e=0.7                            0.774473  1.00099
#                 MP-E-G; e=0.8                            0.811623  1.00099
#                 MP-E-G; e=0.9                            0.848497  1.00099
#                 MP-E-G; e=0.99                           0.881443  1.00099
#                 MP-GLR-KL-UCB-G                          0.552560  1.00099
#                 MP-GLR-KL-UCB-G-F                        0.594985  1.00099
#                 MP-GLR-KL-UCB-L                          0.540275  1.00099
#                 MP-GLR-KL-UCB-L-F                        0.511198  1.00099
#                 MP-KLUCB                                 0.922193  1.00099
#                 MP-M-UCB; w=1000; m=10                   0.498920  1.00099
#                 MP-M-UCB; w=1000; m=100                  0.498911  1.00099
#                 MP-M-UCB; w=5000; m=10                   0.498929  1.00099
#                 MP-M-UCB; w=5000; m=100                  0.498926  1.00099
#                 MP-RExp3; b=100.0                        0.482163  1.00099
#                 MP-RExp3; b=1000.0                       0.482072  1.00099
#                 MP-RExp3; b=500.0                        0.482104  1.00099
#                 MP-RExp3; b=5000.0                       0.481948  1.00099
#                 MP-SW-TS; w=100                          0.382522  1.00099
#                 MP-SW-TS; w=1000                         0.595599  1.00099
#                 MP-SW-TS; w=500                          0.530971  1.00099
#                 MP-SW-TS; w=5000                         0.807168  1.00099
#                 MP-SW-UCB#-A; nu=0.1; l=12.3             0.639522  1.00099
#                 MP-SW-UCB#-A; nu=0.2; l=12.3             0.606747  1.00099
#                 MP-SW-UCB#-G; ka=0.1; l=4.3              0.490221  1.00099
#                 MP-SW-UCB#-G; ka=0.2; l=4.3              0.490288  1.00099
#                 MP-SW-UCB; w=100                         0.088624  1.00099
#                 MP-SW-UCB; w=1000                        0.595568  1.00099
#                 MP-SW-UCB; w=500                         0.528704  1.00099
#                 MP-SW-UCB; w=5000                        0.797571  1.00099
#                 MP-TS                                    0.893388  1.00099
#                 OD                                       1.000493  1.00099
#                 OR                                       0.490367  1.00099
#                 OS                                       0.900423  1.00099
# No-2            CustomOracle                             1.923796  2.00098
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001   1.755444  2.00098
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    1.620303  2.00098
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     1.235358  2.00098
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  1.766707  2.00098
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  1.766477  2.00098
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       1.861548  2.00098
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true        1.864643  2.00098
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        1.888255  2.00098
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         1.887767  2.00098
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         1.882206  2.00098
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true          1.788203  2.00098
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      1.856064  2.00098
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       1.862252  2.00098
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      1.855992  2.00098
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       1.861509  2.00098
#                 MP-D-TS; g=0.7                           1.766106  2.00098
#                 MP-D-TS; g=0.8                           1.804053  2.00098
#                 MP-D-TS; g=0.9                           1.835340  2.00098
#                 MP-D-TS; g=0.99                          1.678950  2.00098
#                 MP-D-UCB; g=0.7                          1.789563  2.00098
#                 MP-D-UCB; g=0.8                          1.791043  2.00098
#                 MP-D-UCB; g=0.9                          1.787785  2.00098
#                 MP-D-UCB; g=0.99                         1.792391  2.00098
#                 MP-E-G; e=0.7                            1.538070  2.00098
#                 MP-E-G; e=0.8                            1.615245  2.00098
#                 MP-E-G; e=0.9                            1.686399  2.00098
#                 MP-E-G; e=0.99                           1.735041  2.00098
#                 MP-GLR-KL-UCB-G                          1.447328  2.00098
#                 MP-GLR-KL-UCB-G-F                        1.425133  2.00098
#                 MP-GLR-KL-UCB-L                          1.734417  2.00098
#                 MP-GLR-KL-UCB-L-F                        1.706115  2.00098
#                 MP-KLUCB                                 1.811933  2.00098
#                 MP-M-UCB; w=1000; m=10                   1.394364  2.00098
#                 MP-M-UCB; w=1000; m=100                  1.394569  2.00098
#                 MP-M-UCB; w=5000; m=10                   1.398425  2.00098
#                 MP-M-UCB; w=5000; m=100                  1.398439  2.00098
#                 MP-RExp3; b=100.0                        0.963188  2.00098
#                 MP-RExp3; b=1000.0                       0.963916  2.00098
#                 MP-RExp3; b=500.0                        0.963829  2.00098
#                 MP-RExp3; b=5000.0                       0.963556  2.00098
#                 MP-SW-TS; w=100                          0.858398  2.00098
#                 MP-SW-TS; w=1000                         1.219378  2.00098
#                 MP-SW-TS; w=500                          1.127081  2.00098
#                 MP-SW-TS; w=5000                         1.587315  2.00098
#                 MP-SW-UCB#-A; nu=0.1; l=12.3             1.388912  2.00098
#                 MP-SW-UCB#-A; nu=0.2; l=12.3             1.316207  2.00098
#                 MP-SW-UCB#-G; ka=0.1; l=4.3              0.979978  2.00098
#                 MP-SW-UCB#-G; ka=0.2; l=4.3              0.980154  2.00098
#                 MP-SW-UCB; w=100                         0.453843  2.00098
#                 MP-SW-UCB; w=1000                        1.222545  2.00098
#                 MP-SW-UCB; w=500                         1.131828  2.00098
#                 MP-SW-UCB; w=5000                        1.704720  2.00098
#                 MP-TS                                    1.772425  2.00098
#                 OD                                       2.000483  2.00098
#                 OR                                       0.980195  2.00098
#                 OS                                       1.790449  2.00098
# No-5            CustomOracle                             4.733830  5.00095
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001   4.524308  5.00095
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    4.093367  5.00095
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     3.093606  5.00095
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  4.561024  5.00095
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  4.561916  5.00095
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       4.609490  5.00095
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true        4.627822  5.00095
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        4.677669  5.00095
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         4.670013  5.00095
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         4.603945  5.00095
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true          4.324763  5.00095
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      4.566721  5.00095
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       4.581926  5.00095
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      4.564679  5.00095
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       4.580298  5.00095
#                 MP-D-TS; g=0.7                           4.514116  5.00095
#                 MP-D-TS; g=0.8                           4.500492  5.00095
#                 MP-D-TS; g=0.9                           4.291209  5.00095
#                 MP-D-TS; g=0.99                          4.017004  5.00095
#                 MP-D-UCB; g=0.7                          4.444847  5.00095
#                 MP-D-UCB; g=0.8                          4.444325  5.00095
#                 MP-D-UCB; g=0.9                          4.444759  5.00095
#                 MP-D-UCB; g=0.99                         4.445312  5.00095
#                 MP-E-G; e=0.7                            3.795779  5.00095
#                 MP-E-G; e=0.8                            3.977304  5.00095
#                 MP-E-G; e=0.9                            4.151102  5.00095
#                 MP-E-G; e=0.99                           4.251338  5.00095
#                 MP-GLR-KL-UCB-G                          3.955137  5.00095
#                 MP-GLR-KL-UCB-G-F                        4.072927  5.00095
#                 MP-GLR-KL-UCB-L                          4.408322  5.00095
#                 MP-GLR-KL-UCB-L-F                        4.389304  5.00095
#                 MP-KLUCB                                 4.417059  5.00095
#                 MP-M-UCB; w=1000; m=10                   4.129262  5.00095
#                 MP-M-UCB; w=1000; m=100                  4.129245  5.00095
#                 MP-M-UCB; w=5000; m=10                   4.128237  5.00095
#                 MP-M-UCB; w=5000; m=100                  4.128193  5.00095
#                 MP-RExp3; b=100.0                        2.408297  5.00095
#                 MP-RExp3; b=1000.0                       2.408607  5.00095
#                 MP-RExp3; b=500.0                        2.408146  5.00095
#                 MP-RExp3; b=5000.0                       2.408928  5.00095
#                 MP-SW-TS; w=100                          2.529313  5.00095
#                 MP-SW-TS; w=1000                         3.139907  5.00095
#                 MP-SW-TS; w=500                          2.968703  5.00095
#                 MP-SW-TS; w=5000                         3.898797  5.00095
#                 MP-SW-UCB#-A; nu=0.1; l=12.3             3.869724  5.00095
#                 MP-SW-UCB#-A; nu=0.2; l=12.3             3.679858  5.00095
#                 MP-SW-UCB#-G; ka=0.1; l=4.3              2.449543  5.00095
#                 MP-SW-UCB#-G; ka=0.2; l=4.3              2.518611  5.00095
#                 MP-SW-UCB; w=100                         2.172784  5.00095
#                 MP-SW-UCB; w=1000                        3.686448  5.00095
#                 MP-SW-UCB; w=500                         3.143284  5.00095
#                 MP-SW-UCB; w=5000                        4.448029  5.00095
#                 MP-TS                                    4.350246  5.00095
#                 OD                                       5.000453  5.00095
#                 OR                                       2.449813  5.00095
#                 OS                                       4.400200  5.00095
#
#                                                          reward/arm    cputime
# scalingstrategy bandit
# No-1            CustomOracle                               0.966655   0.152538
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001     0.836930   3.592784
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01      0.789562   2.954669
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1       0.615714   1.089680
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4    0.838733   3.730549
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5    0.838649   3.222349
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false         0.933809   1.940189
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true          0.936548   6.880763
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false          0.942668   4.081972
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true           0.941619   2.211705
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false           0.943955   4.635819
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true            0.897867   2.425577
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false        0.933991   4.497779
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true         0.935045   4.420959
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false        0.933707   2.905501
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true         0.936208   4.794191
#                 MP-D-TS; g=0.7                             0.844890   0.759554
#                 MP-D-TS; g=0.8                             0.865669   0.908317
#                 MP-D-TS; g=0.9                             0.902419   0.957194
#                 MP-D-TS; g=0.99                            0.874430   0.887726
#                 MP-D-UCB; g=0.7                            0.879214   1.487607
#                 MP-D-UCB; g=0.8                            0.877795   1.400673
#                 MP-D-UCB; g=0.9                            0.877406   1.256101
#                 MP-D-UCB; g=0.99                           0.878828   1.435401
#                 MP-E-G; e=0.7                              0.773975   0.600684
#                 MP-E-G; e=0.8                              0.811126   0.630546
#                 MP-E-G; e=0.9                              0.847999   0.647458
#                 MP-E-G; e=0.99                             0.880945   0.580391
#                 MP-GLR-KL-UCB-G                            0.552062   1.097718
#                 MP-GLR-KL-UCB-G-F                          0.594487   1.348184
#                 MP-GLR-KL-UCB-L                            0.539777   4.903958
#                 MP-GLR-KL-UCB-L-F                          0.510700   0.843076
#                 MP-KLUCB                                   0.921696   0.752868
#                 MP-M-UCB; w=1000; m=10                     0.498423   0.857961
#                 MP-M-UCB; w=1000; m=100                    0.498414   1.004895
#                 MP-M-UCB; w=5000; m=10                     0.498431   0.879583
#                 MP-M-UCB; w=5000; m=100                    0.498428   0.851974
#                 MP-RExp3; b=100.0                          0.481665   0.824426
#                 MP-RExp3; b=1000.0                         0.481574   1.139393
#                 MP-RExp3; b=500.0                          0.481606   0.924230
#                 MP-RExp3; b=5000.0                         0.481450   0.951371
#                 MP-SW-TS; w=100                            0.382024   1.170957
#                 MP-SW-TS; w=1000                           0.595101   1.174163
#                 MP-SW-TS; w=500                            0.530473   1.103932
#                 MP-SW-TS; w=5000                           0.806671   1.078172
#                 MP-SW-UCB#-A; nu=0.1; l=12.3               0.639025   1.237029
#                 MP-SW-UCB#-A; nu=0.2; l=12.3               0.606249   1.024784
#                 MP-SW-UCB#-G; ka=0.1; l=4.3                0.489723   0.689880
#                 MP-SW-UCB#-G; ka=0.2; l=4.3                0.489790   0.691614
#                 MP-SW-UCB; w=100                           0.088126   0.823297
#                 MP-SW-UCB; w=1000                          0.595070   0.740063
#                 MP-SW-UCB; w=500                           0.528206   0.994011
#                 MP-SW-UCB; w=5000                          0.797074   0.981315
#                 MP-TS                                      0.892890   0.897667
#                 OD                                         0.999995   0.666502
#                 OR                                         0.489869   0.292379
#                 OS                                         0.899926   0.142849
# No-2            CustomOracle                               0.961652   0.156413
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001     0.877476   4.214963
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01      0.809905   2.535401
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1       0.617432   1.012251
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4    0.883107   3.655843
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5    0.882992   4.181943
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false         0.930528   0.916556
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true          0.932075   7.697313
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false          0.943881   5.040763
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true           0.943637   3.822343
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false           0.940857   4.656006
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true            0.893855   2.970109
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false        0.927786   5.518723
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true         0.930880   5.204057
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false        0.927750   5.229079
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true         0.930508   5.260582
#                 MP-D-TS; g=0.7                             0.882807   0.938272
#                 MP-D-TS; g=0.8                             0.901780   0.780659
#                 MP-D-TS; g=0.9                             0.917424   0.675704
#                 MP-D-TS; g=0.99                            0.839229   0.785324
#                 MP-D-UCB; g=0.7                            0.894535   1.496799
#                 MP-D-UCB; g=0.8                            0.895275   1.445038
#                 MP-D-UCB; g=0.9                            0.893646   1.145814
#                 MP-D-UCB; g=0.99                           0.895949   1.603714
#                 MP-E-G; e=0.7                              0.768789   0.458995
#                 MP-E-G; e=0.8                              0.807376   0.592879
#                 MP-E-G; e=0.9                              0.842953   0.659827
#                 MP-E-G; e=0.99                             0.867274   0.589135
#                 MP-GLR-KL-UCB-G                            0.723418   3.898907
#                 MP-GLR-KL-UCB-G-F                          0.712320   2.553839
#                 MP-GLR-KL-UCB-L                            0.866962   5.887905
#                 MP-GLR-KL-UCB-L-F                          0.852811   2.069757
#                 MP-KLUCB                                   0.905720   0.706501
#                 MP-M-UCB; w=1000; m=10                     0.696936   1.767804
#                 MP-M-UCB; w=1000; m=100                    0.697038   1.267029
#                 MP-M-UCB; w=5000; m=10                     0.698966   1.150665
#                 MP-M-UCB; w=5000; m=100                    0.698973   1.316487
#                 MP-RExp3; b=100.0                          0.481348   1.175331
#                 MP-RExp3; b=1000.0                         0.481712   0.920701
#                 MP-RExp3; b=500.0                          0.481668   1.249755
#                 MP-RExp3; b=5000.0                         0.481532   0.910102
#                 MP-SW-TS; w=100                            0.428953   0.904905
#                 MP-SW-TS; w=1000                           0.609443   1.302036
#                 MP-SW-TS; w=500                            0.563294   0.948635
#                 MP-SW-TS; w=5000                           0.793411   1.339496
#                 MP-SW-UCB#-A; nu=0.1; l=12.3               0.694210   0.883585
#                 MP-SW-UCB#-A; nu=0.2; l=12.3               0.657857   1.023148
#                 MP-SW-UCB#-G; ka=0.1; l=4.3                0.489743   0.723277
#                 MP-SW-UCB#-G; ka=0.2; l=4.3                0.489831   0.813639
#                 MP-SW-UCB; w=100                           0.226675   0.633619
#                 MP-SW-UCB; w=1000                          0.611026   0.653508
#                 MP-SW-UCB; w=500                           0.565668   0.734426
#                 MP-SW-UCB; w=5000                          0.852114   0.997728
#                 MP-TS                                      0.885966   0.708033
#                 OD                                         0.999995   0.633977
#                 OR                                         0.489851   0.237670
#                 OS                                         0.894978   0.158980
# No-5            CustomOracle                               0.946670   0.165943
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001     0.904766   2.914193
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01      0.818578   2.147922
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1       0.618626   0.601748
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4    0.912109   2.951067
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5    0.912288   2.988629
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false         0.921802   2.200718
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true          0.925469  10.912122
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false          0.935438   4.915601
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true           0.933907   2.868159
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false           0.920694   3.067387
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true            0.864857   1.153001
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false        0.913249  12.382396
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true         0.916290   4.667857
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false        0.912840   4.781568
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true         0.915964   5.538652
#                 MP-D-TS; g=0.7                             0.902728   0.999045
#                 MP-D-TS; g=0.8                             0.900003   0.781322
#                 MP-D-TS; g=0.9                             0.858146   0.940560
#                 MP-D-TS; g=0.99                            0.803305   1.176608
#                 MP-D-UCB; g=0.7                            0.888874   1.441994
#                 MP-D-UCB; g=0.8                            0.888769   1.421697
#                 MP-D-UCB; g=0.9                            0.888856   1.198815
#                 MP-D-UCB; g=0.99                           0.888967   1.475425
#                 MP-E-G; e=0.7                              0.759060   0.551634
#                 MP-E-G; e=0.8                              0.795365   0.613929
#                 MP-E-G; e=0.9                              0.830125   0.606382
#                 MP-E-G; e=0.99                             0.850172   0.634910
#                 MP-GLR-KL-UCB-G                            0.790932   5.052625
#                 MP-GLR-KL-UCB-G-F                          0.814490   4.579680
#                 MP-GLR-KL-UCB-L                            0.881569  12.449127
#                 MP-GLR-KL-UCB-L-F                          0.877765   3.536802
#                 MP-KLUCB                                   0.883316   0.829874
#                 MP-M-UCB; w=1000; m=10                     0.825757   3.466744
#                 MP-M-UCB; w=1000; m=100                    0.825754   2.783800
#                 MP-M-UCB; w=5000; m=10                     0.825552   3.220866
#                 MP-M-UCB; w=5000; m=100                    0.825543   2.475872
#                 MP-RExp3; b=100.0                          0.481564   0.852934
#                 MP-RExp3; b=1000.0                         0.481626   1.081189
#                 MP-RExp3; b=500.0                          0.481534   1.292352
#                 MP-RExp3; b=5000.0                         0.481690   0.953127
#                 MP-SW-TS; w=100                            0.505767   1.159805
#                 MP-SW-TS; w=1000                           0.627886   1.315086
#                 MP-SW-TS; w=500                            0.593645   1.036890
#                 MP-SW-TS; w=5000                           0.779664   1.096077
#                 MP-SW-UCB#-A; nu=0.1; l=12.3               0.773849   0.990543
#                 MP-SW-UCB#-A; nu=0.2; l=12.3               0.735876   1.352073
#                 MP-SW-UCB#-G; ka=0.1; l=4.3                0.489813   0.616626
#                 MP-SW-UCB#-G; ka=0.2; l=4.3                0.503627   0.695782
#                 MP-SW-UCB; w=100                           0.434461   0.686366
#                 MP-SW-UCB; w=1000                          0.737194   0.738874
#                 MP-SW-UCB; w=500                           0.628561   0.680875
#                 MP-SW-UCB; w=5000                          0.889510   0.947613
#                 MP-TS                                      0.869954   0.909603
#                 OD                                         0.999995   0.658064
#                 OR                                         0.489867   0.349713
#                 OS                                         0.879944   0.161641

# %%
masterdata['dataset'].unique()
# Out:
# array(['AbruptGenerator-100'], dtype=object)

# %%
from matplotlib.markers import TICKLEFT, TICKRIGHT, TICKUP, TICKDOWN, CARETLEFT, CARETRIGHT, CARETUP, CARETDOWN
markers = [
#    '.',
#    ',',
    'v',
    'o',
    '^',
    '<',
    '>',
#    '1',
#    '2',
#    '3',
#    '4',
#    '8',
    's',
    'p',
    '*',
#    'h',
    'H',
    '+',
    'x',
    'D',
#    'd',
    '|',
    '_',
    TICKLEFT,
    TICKRIGHT,
    TICKUP,
    TICKDOWN,
    CARETLEFT,
    CARETRIGHT,
    CARETUP,
    CARETDOWN,
]

# %%
algs_ours = [    
    # ours
    'MP-ADR-Elimination-UCB-ADWIN1; d=0.001',
    'MP-ADS-TS-ADWIN1; d=0.001; r=true',
#    'MP-ADS-TS-ADWIN1; d=0.001; r=false'
]
algs_pass = [
    # passive
    'MP-D-UCB; g=0.9',
    'MP-RExp3; b=1000.0',
    'MP-SW-TS; w=1000',
#    'MP-SW-UCB; w=1000',
    'MP-SW-UCB#-A; nu=0.1; l=12.3', 
    #'MP-SW-UCB#-A; nu=0.2; l=12.3', 
    'MP-SW-UCB#-G; ka=0.1; l=4.3', 
    #'MP-SW-UCB#-G; ka=0.2; l=4.3'
]
algs_act = [
    # active
    'MP-GLR-KL-UCB-G',
#    'MP-GLR-KL-UCB-L',
#    'MP-GLR-KL-UCB-G-F',
#    'MP-GLR-KL-UCB-L-F',
    'MP-M-UCB; w=1000; m=10',
#    'MP-M-UCB; w=5000; m=100',
]
algs_base = [
    # baselines
    'MP-TS',
    'MP-E-G; e=0.9',
    'OR',
    'OD',
    'OS',
    'CustomOracle'
]

# %%
prettynames = {
    'MP-ADR-Elimination-UCB-ADWIN1; d=0.001' : "ADR-E-UCB",
    'MP-ADS-TS-ADWIN1; d=0.001; r=true': "ADR-TS",
    'MP-ADS-TS-ADWIN1; d=0.001; r=false': "ADS-TS",
    'MP-D-UCB; g=0.9': "D-UCB",
    'MP-RExp3; b=1000.0': "RExp3",
    'MP-SW-TS; w=1000': "SW-TS",
    'MP-SW-UCB; w=1000': "SW-UCB",
    'MP-SW-UCB#-A; nu=0.1; l=12.3': "SW-UCB\#-A",
    'MP-SW-UCB#-G; ka=0.1; l=4.3': "SW-UCB\#-G",
    # active
    'MP-GLR-KL-UCB-G': 'GLR-KL-UCB',
    'MP-GLR-KL-UCB-L': 'GLR-KL-UCB-L',
    'MP-GLR-KL-UCB-G-F': 'GLR-KL-UCB-G-F',
    'MP-GLR-KL-UCB-L-F': 'GLR-KL-UCB-L-F',
#    'MP-M-UCB; w=1000; m=10': 'M-UCB; w=1000; m=10',
#    'MP-M-UCB; w=5000; m=100': 'M-UCB; w=5000; m=100',
    'MP-M-UCB; w=1000; m=10': 'M-UCB',
    # baselines
    'MP-TS': 'MP-TS',
    'MP-E-G; e=0.9': 'Espilon-Greedy',
    'OR': "Random Oracle",
    'OD': "Dynamic Oracle",
    'OS': "Static Oracle",
    'CustomOracle': "Custom Oracle"
}

# %%
# compute regret against 'OD', or just the cumulative rewards

# %%
fig, axes = plt.subplots(2, 2, sharey=True, sharex=True,  figsize=(14,10), constrained_layout=True)

L = 5

plt.sca(axes[0][0])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "CustomOracle"].gain.cumsum().reset_index(drop=True)
for bandit in algs_ours + algs_pass:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                             markevery=(i*5000,4000),  marker=markers[i] , markersize=10)
    i+=1

plt.legend(ncol=1, loc="lower right")
plt.ylabel("$R_T / L$")
plt.ylim([0,2000])
plt.title("Ours vs. passive approaches ($L = %s$)"%L)

plt.sca(axes[1][0])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "CustomOracle"].gain.cumsum().reset_index(drop=True)
for bandit in algs_ours + algs_act:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                             markevery=(i*5000,4000),  marker=markers[i] , markersize=10)
    i+=1

plt.legend(ncol=1, loc="lower right")
plt.ylabel("$R_T / L$")
plt.ylim([0,2000])
plt.title("Ours vs. active approaches ($L = %s$)"%L)

L = 1

plt.sca(axes[0][1])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "CustomOracle"].gain.cumsum().reset_index(drop=True)
for bandit in algs_ours + algs_pass:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                             markevery=(i*5000,4000),  marker=markers[i] , markersize=10)
    i+=1

plt.legend(ncol=1, loc="lower right")
plt.ylim([0,2000])
plt.title("Ours vs. passive approaches ($L = %s$)"%L)

plt.sca(axes[1][1])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "CustomOracle"].gain.cumsum().reset_index(drop=True)
for bandit in algs_ours + algs_act:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                             markevery=(i*5000,4000),  marker=markers[i] , markersize=10)
    i+=1

plt.legend(ncol=1, loc="lower right")
plt.title("Ours vs. active approaches ($L = %s$)"%L)
plt.xlabel("$T$")
plt.ylim([0,2000])

#plt.tight_layout()

plt.suptitle("Cumulative regret over time (abrupt local)", fontsize=25)
plt.savefig("plots/%s_regret_full.pdf"%dataset)

# %%
fig, axes = plt.subplots(1, 2, sharey=True, sharex=True,  figsize=(14,6.5), constrained_layout=True)

L = 1

plt.sca(axes[0])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "CustomOracle"].gain.cumsum().reset_index(drop=True)
for bandit in algs_ours + algs_pass:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                             markevery=(i*5000,4000),  marker=markers[i] , markersize=10)
    i+=1

plt.ylabel("$R_T$")
plt.legend(ncol=1, loc="lower right")
plt.ylim([0,2000])
plt.title("Ours vs. passive approaches ($L = %s$)"%L)

plt.sca(axes[1])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
oracle = subdata[subdata["bandit"] == "CustomOracle"].gain.cumsum().reset_index(drop=True)
for bandit in algs_ours + algs_act:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)
    ((oracle-cumsum)/L).plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                             markevery=(i*5000,4000),  marker=markers[i] , markersize=10)
    i+=1

plt.legend(ncol=1, loc="lower right")
plt.title("Ours vs. active approaches ($L = %s$)"%L)
plt.xlabel("$T$")
plt.ylim([0,2000])

#plt.tight_layout()

plt.suptitle("Cumulative regret over time (abrupt local)", fontsize=25)
plt.savefig("plots/%s_regret.pdf"%dataset)
