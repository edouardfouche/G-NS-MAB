# %%
import math

import matplotlib as mpl
mpl.rcParams['text.usetex'] = True 
mpl.rcParams['text.latex.preamble'] = [r'\usepackage{libertine}', r'\usepackage{newtxmath}'] 
mpl.rc('font', family='serif')

import numpy as np
import pandas as pd
import seaborn as sns


import matplotlib.pyplot as plt
from matplotlib import rc

from cycler import cycler


mpl.rcParams['ps.usedistiller'] = 'xpdf' 

plt.style.use('seaborn-notebook')
# sns.set_palette("Blues_r")

plt.rcParams['axes.titlesize'] = '25'
plt.rcParams['axes.labelsize'] = '25'
plt.rcParams['legend.fontsize'] = '15'
plt.rcParams['xtick.labelsize'] = '15'
plt.rcParams['ytick.labelsize'] = '15'

monochrome=(cycler('color', sns.color_palette("husl", 8))*2+(cycler('marker', ['v', 's', "o"])*7)[0:16])
plt.rc('axes', prop_cycle=monochrome)

pd.options.display.max_rows = 999
# Out:
# <ipython-input-1-56d1c1821bb1>:5: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   mpl.rcParams['text.latex.preamble'] = [r'\usepackage{libertine}', r'\usepackage{newtxmath}']

# %%
# Change if required
folder = "../experiments/2021-06-09-15-50_BanditRealWorld_Bioliq_"
dataset = "BanditRealWorld-Bioliq"

# %%
masterdata = pd.read_csv("%s/BanditRealWorld_Bioliq.csv"%folder, sep=",")
narms = masterdata.iloc[0]['k']

# %%
sorted(masterdata.bandit.unique())
# Out:
# ['MP-ADR-Elimination-UCB-ADWIN1; d=0.001',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=0.01',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=0.1',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5',
#  'MP-ADS-TS-ADWIN1; d=0.001; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.001; r=true',
#  'MP-ADS-TS-ADWIN1; d=0.01; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.01; r=true',
#  'MP-ADS-TS-ADWIN1; d=0.1; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.1; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-4; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-4; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-5; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-5; r=true',
#  'MP-D-TS; g=0.7',
#  'MP-D-TS; g=0.8',
#  'MP-D-TS; g=0.9',
#  'MP-D-TS; g=0.99',
#  'MP-D-UCB; g=0.7',
#  'MP-D-UCB; g=0.8',
#  'MP-D-UCB; g=0.9',
#  'MP-D-UCB; g=0.99',
#  'MP-E-G; e=0.7',
#  'MP-E-G; e=0.8',
#  'MP-E-G; e=0.9',
#  'MP-E-G; e=0.99',
#  'MP-GLR-KL-UCB-G',
#  'MP-GLR-KL-UCB-G-F',
#  'MP-GLR-KL-UCB-L',
#  'MP-GLR-KL-UCB-L-F',
#  'MP-KLUCB',
#  'MP-M-UCB; w=1000; m=10',
#  'MP-M-UCB; w=1000; m=100',
#  'MP-M-UCB; w=5000; m=10',
#  'MP-M-UCB; w=5000; m=100',
#  'MP-RExp3; b=100.0',
#  'MP-RExp3; b=1000.0',
#  'MP-RExp3; b=500.0',
#  'MP-RExp3; b=5000.0',
#  'MP-SW-TS; w=100',
#  'MP-SW-TS; w=1000',
#  'MP-SW-TS; w=500',
#  'MP-SW-TS; w=5000',
#  'MP-SW-UCB#-A; nu=0.1; l=12.3',
#  'MP-SW-UCB#-A; nu=0.2; l=12.3',
#  'MP-SW-UCB#-G; ka=0.1; l=4.3',
#  'MP-SW-UCB#-G; ka=0.2; l=4.3',
#  'MP-SW-UCB; w=100',
#  'MP-SW-UCB; w=1000',
#  'MP-SW-UCB; w=500',
#  'MP-SW-UCB; w=5000',
#  'MP-TS',
#  'OD',
#  'OR',
#  'OS']

# %%
masterdata.columns
# Out:
# Index(['bandit', 'dataset', 'scalingstrategy', 'k', 'gain', 'cputime',
#        'iteration'],
#       dtype='object')

# %%
masterdata['reward/arm'] = masterdata['gain']/masterdata['k']

# %%
masterdata.shape
# Out:
# (1352736, 8)

# %%
masterdata.groupby(["scalingstrategy", "bandit"])[['gain', 'k', 'reward/arm', 'cputime']].mean()
# Out:
#                                                              gain     k  \
# scalingstrategy bandit
# No-1            MP-ADR-Elimination-UCB-ADWIN1; d=0.001   0.465811   1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    0.410724   1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     0.363203   1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  0.533308   1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  0.559467   1.0
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       0.765522   1.0
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true        0.758121   1.0
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        0.762126   1.0
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         0.749121   1.0
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         0.754382   1.0
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true          0.710404   1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      0.775521   1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       0.759960   1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      0.771707   1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       0.758823   1.0
#                 MP-D-TS; g=0.7                           0.567221   1.0
#                 MP-D-TS; g=0.8                           0.577299   1.0
#                 MP-D-TS; g=0.9                           0.657317   1.0
#                 MP-D-TS; g=0.99                          0.789078   1.0
#                 MP-D-UCB; g=0.7                          0.562176   1.0
#                 MP-D-UCB; g=0.8                          0.562737   1.0
#                 MP-D-UCB; g=0.9                          0.562525   1.0
#                 MP-D-UCB; g=0.99                         0.562464   1.0
#                 MP-E-G; e=0.7                            0.540965   1.0
#                 MP-E-G; e=0.8                            0.561060   1.0
#                 MP-E-G; e=0.9                            0.581108   1.0
#                 MP-E-G; e=0.99                           0.639084   1.0
#                 MP-GLR-KL-UCB-G                          0.455724   1.0
#                 MP-GLR-KL-UCB-G-F                        0.494804   1.0
#                 MP-GLR-KL-UCB-L                          0.471571   1.0
#                 MP-GLR-KL-UCB-L-F                        0.494670   1.0
#                 MP-KLUCB                                 0.730585   1.0
#                 MP-M-UCB; w=1000; m=10                   0.249467   1.0
#                 MP-M-UCB; w=1000; m=100                  0.249463   1.0
#                 MP-M-UCB; w=5000; m=10                   0.249459   1.0
#                 MP-M-UCB; w=5000; m=100                  0.249455   1.0
#                 MP-RExp3; b=100.0                        0.249576   1.0
#                 MP-RExp3; b=1000.0                       0.250310   1.0
#                 MP-RExp3; b=500.0                        0.250692   1.0
#                 MP-RExp3; b=5000.0                       0.250182   1.0
#                 MP-SW-TS; w=100                          0.169164   1.0
#                 MP-SW-TS; w=1000                         0.709338   1.0
#                 MP-SW-TS; w=500                          0.529285   1.0
#                 MP-SW-TS; w=5000                         0.671368   1.0
#                 MP-SW-UCB#-A; nu=0.1; l=12.3             0.330555   1.0
#                 MP-SW-UCB#-A; nu=0.2; l=12.3             0.341356   1.0
#                 MP-SW-UCB#-G; ka=0.1; l=4.3              0.253646   1.0
#                 MP-SW-UCB#-G; ka=0.2; l=4.3              0.252664   1.0
#                 MP-SW-UCB; w=100                         0.033029   1.0
#                 MP-SW-UCB; w=1000                        0.519305   1.0
#                 MP-SW-UCB; w=500                         0.373251   1.0
#                 MP-SW-UCB; w=5000                        0.687084   1.0
#                 MP-TS                                    0.620295   1.0
#                 OD                                       0.949826   1.0
#                 OR                                       0.253232   1.0
#                 OS                                       0.699950   1.0
# No-10           MP-ADR-Elimination-UCB-ADWIN1; d=0.001   5.327036  10.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    4.871444  10.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     4.237341  10.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  5.653648  10.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  6.009929  10.0
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       7.109998  10.0
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true        6.798164  10.0
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        7.098038  10.0
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         6.650970  10.0
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         7.089104  10.0
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true          6.184386  10.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      7.115971  10.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       6.892789  10.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      7.119367  10.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       6.952285  10.0
#                 MP-D-TS; g=0.7                           6.038561  10.0
#                 MP-D-TS; g=0.8                           6.399844  10.0
#                 MP-D-TS; g=0.9                           6.871080  10.0
#                 MP-D-TS; g=0.99                          7.226973  10.0
#                 MP-D-UCB; g=0.7                          5.624486  10.0
#                 MP-D-UCB; g=0.8                          5.610924  10.0
#                 MP-D-UCB; g=0.9                          5.628722  10.0
#                 MP-D-UCB; g=0.99                         5.632613  10.0
#                 MP-E-G; e=0.7                            4.759876  10.0
#                 MP-E-G; e=0.8                            5.056316  10.0
#                 MP-E-G; e=0.9                            5.167314  10.0
#                 MP-E-G; e=0.99                           4.558927  10.0
#                 MP-GLR-KL-UCB-G                          5.399763  10.0
#                 MP-GLR-KL-UCB-G-F                        5.464569  10.0
#                 MP-GLR-KL-UCB-L                          5.380210  10.0
#                 MP-GLR-KL-UCB-L-F                        5.372706  10.0
#                 MP-KLUCB                                 5.348071  10.0
#                 MP-M-UCB; w=1000; m=10                   6.578730  10.0
#                 MP-M-UCB; w=1000; m=100                  6.579656  10.0
#                 MP-M-UCB; w=5000; m=10                   5.383621  10.0
#                 MP-M-UCB; w=5000; m=100                  5.381767  10.0
#                 MP-RExp3; b=100.0                        2.504138  10.0
#                 MP-RExp3; b=1000.0                       2.499763  10.0
#                 MP-RExp3; b=500.0                        2.503706  10.0
#                 MP-RExp3; b=5000.0                       2.502260  10.0
#                 MP-SW-TS; w=100                          4.229463  10.0
#                 MP-SW-TS; w=1000                         6.350316  10.0
#                 MP-SW-TS; w=500                          5.269314  10.0
#                 MP-SW-TS; w=5000                         5.419813  10.0
#                 MP-SW-UCB#-A; nu=0.1; l=12.3             6.209856  10.0
#                 MP-SW-UCB#-A; nu=0.2; l=12.3             5.885496  10.0
#                 MP-SW-UCB#-G; ka=0.1; l=4.3              2.532785  10.0
#                 MP-SW-UCB#-G; ka=0.2; l=4.3              2.531720  10.0
#                 MP-SW-UCB; w=100                         1.320002  10.0
#                 MP-SW-UCB; w=1000                        6.359508  10.0
#                 MP-SW-UCB; w=500                         5.980421  10.0
#                 MP-SW-UCB; w=5000                        5.631353  10.0
#                 MP-TS                                    5.313895  10.0
#                 OD                                       8.041232  10.0
#                 OR                                       2.530176  10.0
#                 OS                                       6.084120  10.0
# No-2            MP-ADR-Elimination-UCB-ADWIN1; d=0.001   0.953181   2.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    0.907117   2.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     0.781162   2.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  1.004006   2.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  1.020071   2.0
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       1.589896   2.0
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true        1.542388   2.0
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        1.586976   2.0
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         1.499495   2.0
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         1.573469   2.0
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true          1.387505   2.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      1.595264   2.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       1.573441   2.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      1.601234   2.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       1.590349   2.0
#                 MP-D-TS; g=0.7                           1.138106   2.0
#                 MP-D-TS; g=0.8                           1.224325   2.0
#                 MP-D-TS; g=0.9                           1.341295   2.0
#                 MP-D-TS; g=0.99                          1.544671   2.0
#                 MP-D-UCB; g=0.7                          1.382830   2.0
#                 MP-D-UCB; g=0.8                          1.383413   2.0
#                 MP-D-UCB; g=0.9                          1.384135   2.0
#                 MP-D-UCB; g=0.99                         1.382742   2.0
#                 MP-E-G; e=0.7                            0.991908   2.0
#                 MP-E-G; e=0.8                            1.058092   2.0
#                 MP-E-G; e=0.9                            1.171076   2.0
#                 MP-E-G; e=0.99                           1.277534   2.0
#                 MP-GLR-KL-UCB-G                          0.926261   2.0
#                 MP-GLR-KL-UCB-G-F                        1.125701   2.0
#                 MP-GLR-KL-UCB-L                          1.049626   2.0
#                 MP-GLR-KL-UCB-L-F                        1.136436   2.0
#                 MP-KLUCB                                 1.389634   2.0
#                 MP-M-UCB; w=1000; m=10                   1.053060   2.0
#                 MP-M-UCB; w=1000; m=100                  1.053640   2.0
#                 MP-M-UCB; w=5000; m=10                   1.053406   2.0
#                 MP-M-UCB; w=5000; m=100                  1.053300   2.0
#                 MP-RExp3; b=100.0                        0.501172   2.0
#                 MP-RExp3; b=1000.0                       0.500883   2.0
#                 MP-RExp3; b=500.0                        0.501035   2.0
#                 MP-RExp3; b=5000.0                       0.500722   2.0
#                 MP-SW-TS; w=100                          0.505031   2.0
#                 MP-SW-TS; w=1000                         1.522608   2.0
#                 MP-SW-TS; w=500                          1.182913   2.0
#                 MP-SW-TS; w=5000                         1.300116   2.0
#                 MP-SW-UCB#-A; nu=0.1; l=12.3             0.816940   2.0
#                 MP-SW-UCB#-A; nu=0.2; l=12.3             0.735713   2.0
#                 MP-SW-UCB#-G; ka=0.1; l=4.3              0.506024   2.0
#                 MP-SW-UCB#-G; ka=0.2; l=4.3              0.506485   2.0
#                 MP-SW-UCB; w=100                         0.278005   2.0
#                 MP-SW-UCB; w=1000                        1.234042   2.0
#                 MP-SW-UCB; w=500                         0.998298   2.0
#                 MP-SW-UCB; w=5000                        1.301881   2.0
#                 MP-TS                                    1.178581   2.0
#                 OD                                       1.843848   2.0
#                 OR                                       0.505181   2.0
#                 OS                                       1.350720   2.0
# No-5            MP-ADR-Elimination-UCB-ADWIN1; d=0.001   2.726788   5.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    2.382037   5.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     2.023779   5.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  2.863603   5.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  3.033363   5.0
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       3.839215   5.0
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true        3.667831   5.0
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        3.831894   5.0
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         3.545590   5.0
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         3.824133   5.0
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true          3.252863   5.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      3.851162   5.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       3.760295   5.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      3.850348   5.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       3.804491   5.0
#                 MP-D-TS; g=0.7                           2.967899   5.0
#                 MP-D-TS; g=0.8                           3.120257   5.0
#                 MP-D-TS; g=0.9                           3.360654   5.0
#                 MP-D-TS; g=0.99                          3.869220   5.0
#                 MP-D-UCB; g=0.7                          3.478126   5.0
#                 MP-D-UCB; g=0.8                          3.469208   5.0
#                 MP-D-UCB; g=0.9                          3.477778   5.0
#                 MP-D-UCB; g=0.99                         3.478169   5.0
#                 MP-E-G; e=0.7                            2.431465   5.0
#                 MP-E-G; e=0.8                            2.644822   5.0
#                 MP-E-G; e=0.9                            2.794966   5.0
#                 MP-E-G; e=0.99                           2.623254   5.0
#                 MP-GLR-KL-UCB-G                          2.876211   5.0
#                 MP-GLR-KL-UCB-G-F                        2.745445   5.0
#                 MP-GLR-KL-UCB-L                          2.707418   5.0
#                 MP-GLR-KL-UCB-L-F                        2.726347   5.0
#                 MP-KLUCB                                 2.949992   5.0
#                 MP-M-UCB; w=1000; m=10                   3.205213   5.0
#                 MP-M-UCB; w=1000; m=100                  3.207536   5.0
#                 MP-M-UCB; w=5000; m=10                   3.102078   5.0
#                 MP-M-UCB; w=5000; m=100                  3.099518   5.0
#                 MP-RExp3; b=100.0                        1.250354   5.0
#                 MP-RExp3; b=1000.0                       1.251542   5.0
#                 MP-RExp3; b=500.0                        1.253075   5.0
#                 MP-RExp3; b=5000.0                       1.252577   5.0
#                 MP-SW-TS; w=100                          1.882472   5.0
#                 MP-SW-TS; w=1000                         3.584218   5.0
#                 MP-SW-TS; w=500                          2.934670   5.0
#                 MP-SW-TS; w=5000                         3.012878   5.0
#                 MP-SW-UCB#-A; nu=0.1; l=12.3             2.751593   5.0
#                 MP-SW-UCB#-A; nu=0.2; l=12.3             2.482279   5.0
#                 MP-SW-UCB#-G; ka=0.1; l=4.3              1.264671   5.0
#                 MP-SW-UCB#-G; ka=0.2; l=4.3              1.266599   5.0
#                 MP-SW-UCB; w=100                         1.384787   5.0
#                 MP-SW-UCB; w=1000                        3.486335   5.0
#                 MP-SW-UCB; w=500                         3.101323   5.0
#                 MP-SW-UCB; w=5000                        3.059437   5.0
#                 MP-TS                                    2.981297   5.0
#                 OD                                       4.369101   5.0
#                 OR                                       1.264731   5.0
#                 OS                                       3.185461   5.0
#
#                                                          reward/arm   cputime
# scalingstrategy bandit
# No-1            MP-ADR-Elimination-UCB-ADWIN1; d=0.001     0.465811  0.244365
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01      0.410724  0.328660
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1       0.363203  0.250762
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4    0.533308  0.298910
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5    0.559467  0.312692
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false         0.765522  0.733760
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true          0.758121  0.316962
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false          0.762126  0.738983
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true           0.749121  0.322999
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false           0.754382  0.628118
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true            0.710404  0.287206
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false        0.775521  0.537262
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true         0.759960  0.545395
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false        0.771707  0.638269
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true         0.758823  0.264127
#                 MP-D-TS; g=0.7                             0.567221  0.466256
#                 MP-D-TS; g=0.8                             0.577299  0.504895
#                 MP-D-TS; g=0.9                             0.657317  0.501770
#                 MP-D-TS; g=0.99                            0.789078  0.349774
#                 MP-D-UCB; g=0.7                            0.562176  0.874980
#                 MP-D-UCB; g=0.8                            0.562737  1.686113
#                 MP-D-UCB; g=0.9                            0.562525  1.302638
#                 MP-D-UCB; g=0.99                           0.562464  1.083164
#                 MP-E-G; e=0.7                              0.540965  0.232969
#                 MP-E-G; e=0.8                              0.561060  0.253892
#                 MP-E-G; e=0.9                              0.581108  0.206187
#                 MP-E-G; e=0.99                             0.639084  0.182413
#                 MP-GLR-KL-UCB-G                            0.455724  0.831244
#                 MP-GLR-KL-UCB-G-F                          0.494804  0.850493
#                 MP-GLR-KL-UCB-L                            0.471571  0.962975
#                 MP-GLR-KL-UCB-L-F                          0.494670  0.564363
#                 MP-KLUCB                                   0.730585  0.535418
#                 MP-M-UCB; w=1000; m=10                     0.249467  0.537673
#                 MP-M-UCB; w=1000; m=100                    0.249463  0.397450
#                 MP-M-UCB; w=5000; m=10                     0.249459  0.470359
#                 MP-M-UCB; w=5000; m=100                    0.249455  0.607085
#                 MP-RExp3; b=100.0                          0.249576  0.962780
#                 MP-RExp3; b=1000.0                         0.250310  1.405203
#                 MP-RExp3; b=500.0                          0.250692  0.905608
#                 MP-RExp3; b=5000.0                         0.250182  1.015347
#                 MP-SW-TS; w=100                            0.169164  0.648731
#                 MP-SW-TS; w=1000                           0.709338  0.416048
#                 MP-SW-TS; w=500                            0.529285  0.422799
#                 MP-SW-TS; w=5000                           0.671368  0.465470
#                 MP-SW-UCB#-A; nu=0.1; l=12.3               0.330555  0.306471
#                 MP-SW-UCB#-A; nu=0.2; l=12.3               0.341356  0.237288
#                 MP-SW-UCB#-G; ka=0.1; l=4.3                0.253646  0.371130
#                 MP-SW-UCB#-G; ka=0.2; l=4.3                0.252664  0.424854
#                 MP-SW-UCB; w=100                           0.033029  0.436282
#                 MP-SW-UCB; w=1000                          0.519305  0.449585
#                 MP-SW-UCB; w=500                           0.373251  0.509490
#                 MP-SW-UCB; w=5000                          0.687084  0.469090
#                 MP-TS                                      0.620295  0.365557
#                 OD                                         0.949826  0.395572
#                 OR                                         0.253232  0.071145
#                 OS                                         0.699950  0.024162
# No-10           MP-ADR-Elimination-UCB-ADWIN1; d=0.001     0.532704  0.482191
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01      0.487144  0.731942
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1       0.423734  0.799088
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4    0.565365  0.596194
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5    0.600993  0.486394
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false         0.711000  0.706968
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true          0.679816  0.260669
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false          0.709804  0.727428
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true           0.665097  0.393792
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false           0.708910  0.687254
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true            0.618439  0.581027
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false        0.711597  0.526085
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true         0.689279  0.898621
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false        0.711937  1.065117
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true         0.695229  0.685796
#                 MP-D-TS; g=0.7                             0.603856  0.531162
#                 MP-D-TS; g=0.8                             0.639984  0.313698
#                 MP-D-TS; g=0.9                             0.687108  0.365997
#                 MP-D-TS; g=0.99                            0.722697  0.458353
#                 MP-D-UCB; g=0.7                            0.562449  1.192553
#                 MP-D-UCB; g=0.8                            0.561092  1.443991
#                 MP-D-UCB; g=0.9                            0.562872  1.345788
#                 MP-D-UCB; g=0.99                           0.563261  0.437984
#                 MP-E-G; e=0.7                              0.475988  0.285642
#                 MP-E-G; e=0.8                              0.505632  0.256656
#                 MP-E-G; e=0.9                              0.516731  0.258379
#                 MP-E-G; e=0.99                             0.455893  0.209261
#                 MP-GLR-KL-UCB-G                            0.539976  1.078935
#                 MP-GLR-KL-UCB-G-F                          0.546457  0.921779
#                 MP-GLR-KL-UCB-L                            0.538021  0.717631
#                 MP-GLR-KL-UCB-L-F                          0.537271  1.256986
#                 MP-KLUCB                                   0.534807  0.423675
#                 MP-M-UCB; w=1000; m=10                     0.657873  0.534266
#                 MP-M-UCB; w=1000; m=100                    0.657966  0.492680
#                 MP-M-UCB; w=5000; m=10                     0.538362  0.779302
#                 MP-M-UCB; w=5000; m=100                    0.538177  0.756799
#                 MP-RExp3; b=100.0                          0.250414  1.155460
#                 MP-RExp3; b=1000.0                         0.249976  1.638856
#                 MP-RExp3; b=500.0                          0.250371  0.966100
#                 MP-RExp3; b=5000.0                         0.250226  1.420546
#                 MP-SW-TS; w=100                            0.422946  0.673878
#                 MP-SW-TS; w=1000                           0.635032  0.447774
#                 MP-SW-TS; w=500                            0.526931  0.490599
#                 MP-SW-TS; w=5000                           0.541981  0.572037
#                 MP-SW-UCB#-A; nu=0.1; l=12.3               0.620986  0.386273
#                 MP-SW-UCB#-A; nu=0.2; l=12.3               0.588550  0.162552
#                 MP-SW-UCB#-G; ka=0.1; l=4.3                0.253279  0.215758
#                 MP-SW-UCB#-G; ka=0.2; l=4.3                0.253172  0.395594
#                 MP-SW-UCB; w=100                           0.132000  0.212621
#                 MP-SW-UCB; w=1000                          0.635951  0.225755
#                 MP-SW-UCB; w=500                           0.598042  0.233684
#                 MP-SW-UCB; w=5000                          0.563135  0.198027
#                 MP-TS                                      0.531389  0.467546
#                 OD                                         0.804123  0.259607
#                 OR                                         0.253018  0.092442
#                 OS                                         0.608412  0.027973
# No-2            MP-ADR-Elimination-UCB-ADWIN1; d=0.001     0.476590  0.810677
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01      0.453559  0.819972
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1       0.390581  0.665578
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4    0.502003  0.804974
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5    0.510036  0.814183
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false         0.794948  0.763384
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true          0.771194  0.493397
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false          0.793488  0.608900
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true           0.749747  0.422802
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false           0.786735  0.396830
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true            0.693752  0.500580
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false        0.797632  0.705510
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true         0.786720  0.596442
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false        0.800617  0.440045
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true         0.795175  0.785844
#                 MP-D-TS; g=0.7                             0.569053  0.430663
#                 MP-D-TS; g=0.8                             0.612163  0.517370
#                 MP-D-TS; g=0.9                             0.670647  0.536406
#                 MP-D-TS; g=0.99                            0.772336  0.437153
#                 MP-D-UCB; g=0.7                            0.691415  1.358412
#                 MP-D-UCB; g=0.8                            0.691706  1.609300
#                 MP-D-UCB; g=0.9                            0.692067  1.213363
#                 MP-D-UCB; g=0.99                           0.691371  1.351311
#                 MP-E-G; e=0.7                              0.495954  0.248767
#                 MP-E-G; e=0.8                              0.529046  0.238379
#                 MP-E-G; e=0.9                              0.585538  0.212821
#                 MP-E-G; e=0.99                             0.638767  0.160789
#                 MP-GLR-KL-UCB-G                            0.463130  0.660871
#                 MP-GLR-KL-UCB-G-F                          0.562851  0.856859
#                 MP-GLR-KL-UCB-L                            0.524813  0.738375
#                 MP-GLR-KL-UCB-L-F                          0.568218  0.723094
#                 MP-KLUCB                                   0.694817  0.526985
#                 MP-M-UCB; w=1000; m=10                     0.526530  0.495958
#                 MP-M-UCB; w=1000; m=100                    0.526820  0.376906
#                 MP-M-UCB; w=5000; m=10                     0.526703  0.589435
#                 MP-M-UCB; w=5000; m=100                    0.526650  0.403082
#                 MP-RExp3; b=100.0                          0.250586  0.974875
#                 MP-RExp3; b=1000.0                         0.250441  1.620592
#                 MP-RExp3; b=500.0                          0.250517  0.937454
#                 MP-RExp3; b=5000.0                         0.250361  1.058584
#                 MP-SW-TS; w=100                            0.252515  0.479864
#                 MP-SW-TS; w=1000                           0.761304  0.468675
#                 MP-SW-TS; w=500                            0.591456  0.346941
#                 MP-SW-TS; w=5000                           0.650058  0.715108
#                 MP-SW-UCB#-A; nu=0.1; l=12.3               0.408470  0.331246
#                 MP-SW-UCB#-A; nu=0.2; l=12.3               0.367856  0.455269
#                 MP-SW-UCB#-G; ka=0.1; l=4.3                0.253012  0.371047
#                 MP-SW-UCB#-G; ka=0.2; l=4.3                0.253242  0.378274
#                 MP-SW-UCB; w=100                           0.139002  0.439308
#                 MP-SW-UCB; w=1000                          0.617021  0.412704
#                 MP-SW-UCB; w=500                           0.499149  0.555592
#                 MP-SW-UCB; w=5000                          0.650941  0.458282
#                 MP-TS                                      0.589290  0.506398
#                 OD                                         0.921924  0.359290
#                 OR                                         0.252591  0.086712
#                 OS                                         0.675360  0.017978
# No-5            MP-ADR-Elimination-UCB-ADWIN1; d=0.001     0.545358  0.774955
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01      0.476407  0.795257
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1       0.404756  0.440188
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4    0.572721  0.808919
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5    0.606673  0.611053
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false         0.767843  0.639214
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true          0.733566  0.074231
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false          0.766379  0.768544
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true           0.709118  0.072478
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false           0.764827  0.588341
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true            0.650573  0.093229
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false        0.770232  0.559639
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true         0.752059  0.772446
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false        0.770070  0.346298
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true         0.760898  0.697121
#                 MP-D-TS; g=0.7                             0.593580  0.453698
#                 MP-D-TS; g=0.8                             0.624051  0.385667
#                 MP-D-TS; g=0.9                             0.672131  0.264321
#                 MP-D-TS; g=0.99                            0.773844  0.126086
#                 MP-D-UCB; g=0.7                            0.695625  0.182542
#                 MP-D-UCB; g=0.8                            0.693842  1.609982
#                 MP-D-UCB; g=0.9                            0.695556  1.133479
#                 MP-D-UCB; g=0.99                           0.695634  0.462854
#                 MP-E-G; e=0.7                              0.486293  0.273211
#                 MP-E-G; e=0.8                              0.528964  0.195651
#                 MP-E-G; e=0.9                              0.558993  0.295465
#                 MP-E-G; e=0.99                             0.524651  0.202976
#                 MP-GLR-KL-UCB-G                            0.575242  1.257300
#                 MP-GLR-KL-UCB-G-F                          0.549089  0.635102
#                 MP-GLR-KL-UCB-L                            0.541484  1.193090
#                 MP-GLR-KL-UCB-L-F                          0.545269  0.684579
#                 MP-KLUCB                                   0.589998  0.555076
#                 MP-M-UCB; w=1000; m=10                     0.641043  0.492487
#                 MP-M-UCB; w=1000; m=100                    0.641507  0.520109
#                 MP-M-UCB; w=5000; m=10                     0.620416  0.464381
#                 MP-M-UCB; w=5000; m=100                    0.619904  0.451743
#                 MP-RExp3; b=100.0                          0.250071  1.446328
#                 MP-RExp3; b=1000.0                         0.250308  1.518830
#                 MP-RExp3; b=500.0                          0.250615  1.079035
#                 MP-RExp3; b=5000.0                         0.250515  1.384308
#                 MP-SW-TS; w=100                            0.376494  0.428966
#                 MP-SW-TS; w=1000                           0.716844  0.429701
#                 MP-SW-TS; w=500                            0.586934  0.416167
#                 MP-SW-TS; w=5000                           0.602576  0.566724
#                 MP-SW-UCB#-A; nu=0.1; l=12.3               0.550319  0.535149
#                 MP-SW-UCB#-A; nu=0.2; l=12.3               0.496456  0.384564
#                 MP-SW-UCB#-G; ka=0.1; l=4.3                0.252934  0.399903
#                 MP-SW-UCB#-G; ka=0.2; l=4.3                0.253320  0.436033
#                 MP-SW-UCB; w=100                           0.276957  0.363718
#                 MP-SW-UCB; w=1000                          0.697267  0.440084
#                 MP-SW-UCB; w=500                           0.620265  0.462088
#                 MP-SW-UCB; w=5000                          0.611887  0.428063
#                 MP-TS                                      0.596259  0.284162
#                 OD                                         0.873820  0.359682
#                 OR                                         0.252946  0.073450
#                 OS                                         0.637092  0.014791

# %%
from matplotlib.markers import TICKLEFT, TICKRIGHT, TICKUP, TICKDOWN, CARETLEFT, CARETRIGHT, CARETUP, CARETDOWN
markers = [
#    '.',
#    ',',
    'v',
    'o',
    '^',
    '<',
    '>',
#    '1',
#    '2',
#    '3',
#    '4',
#    '8',
    's',
    'p',
    '*',
#    'h',
    'H',
    '+',
    'x',
    'D',
#    'd',
    '|',
    '_',
    TICKLEFT,
    TICKRIGHT,
    TICKUP,
    TICKDOWN,
    CARETLEFT,
    CARETRIGHT,
    CARETUP,
    CARETDOWN,
]

# %%
algs_ours = [    
    # ours
    'MP-ADR-Elimination-UCB-ADWIN1; d=0.001',
    'MP-ADS-TS-ADWIN1; d=0.001; r=true',
#    'MP-ADS-TS-ADWIN1; d=0.001; r=false'
]
algs_pass = [
    # passive
    'MP-D-UCB; g=0.9',
    'MP-RExp3; b=1000.0',
    'MP-SW-TS; w=1000',
#    'MP-SW-UCB; w=1000',
    'MP-SW-UCB#-A; nu=0.1; l=12.3', 
    #'MP-SW-UCB#-A; nu=0.2; l=12.3', 
    'MP-SW-UCB#-G; ka=0.1; l=4.3', 
    #'MP-SW-UCB#-G; ka=0.2; l=4.3'
]
algs_act = [
    # active
    'MP-GLR-KL-UCB-G',
#    'MP-GLR-KL-UCB-L',
#    'MP-GLR-KL-UCB-G-F',
#    'MP-GLR-KL-UCB-L-F',
    'MP-M-UCB; w=1000; m=10',
#    'MP-M-UCB; w=5000; m=100',
]
algs_base = [
    # baselines
    'MP-TS',
    'MP-E-G; e=0.9',
    'OR',
    'OD',
    'OS',
    'CustomOracle'
]

# %%
prettynames = {
    'MP-ADR-Elimination-UCB-ADWIN1; d=0.001' : "ADR-E-UCB",
    'MP-ADS-TS-ADWIN1; d=0.001; r=true': "ADR-TS",
    'MP-ADS-TS-ADWIN1; d=0.001; r=false': "ADS-TS",
    'MP-D-UCB; g=0.9': "D-UCB",
    'MP-RExp3; b=1000.0': "RExp3",
    'MP-SW-TS; w=1000': "SW-TS",
    'MP-SW-UCB; w=1000': "SW-UCB",
    'MP-SW-UCB#-A; nu=0.1; l=12.3': "SW-UCB\#-A",
    'MP-SW-UCB#-G; ka=0.1; l=4.3': "SW-UCB\#-G",
    # active
    'MP-GLR-KL-UCB-G': 'GLR-KL-UCB',
    'MP-GLR-KL-UCB-L': 'GLR-KL-UCB-L',
    'MP-GLR-KL-UCB-G-F': 'GLR-KL-UCB-G-F',
    'MP-GLR-KL-UCB-L-F': 'GLR-KL-UCB-L-F',
#    'MP-M-UCB; w=1000; m=10': 'M-UCB; w=1000; m=10',
#    'MP-M-UCB; w=5000; m=100': 'M-UCB; w=5000; m=100',
    'MP-M-UCB; w=1000; m=10': 'M-UCB',
    # baselines
    'MP-TS': 'MP-TS',
    'MP-E-G; e=0.9': 'Espilon-Greedy',
    'OR': "Random Oracle",
    'OD': "Dynamic Oracle",
    'OS': "Static Oracle",
    'CustomOracle': "Custom Oracle"
}

# %%
# compute regret against 'OD', or just the cumulative rewards

# %%
fig, axes = plt.subplots(2, 2, sharey=True, sharex=True, figsize=(14,10), constrained_layout=True)

L = 5

plt.sca(axes[0][0])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
for bandit in algs_ours + algs_pass:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)/L
    cumsum.plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                markevery=(i*50,400), marker=markers[i] , markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)    
plt.legend(ncol=1)
plt.ylabel("$\sum_{i}^{K} X_i^T/L$")
plt.title("Ours vs. passive approaches ($L = %s$)"%L)

plt.sca(axes[1][0])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
for bandit in algs_ours + algs_act:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)/L
    cumsum.plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                markevery=(i*50,400), marker=markers[i] , markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)    
plt.legend(ncol=1)
plt.ylabel("$\sum_{i}^{K} X_i^T/L$")
plt.title("Ours vs. active approaches ($L = %s$)"%L)
plt.xlabel("$T$")

L = 1

plt.sca(axes[0][1])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
for bandit in algs_ours + algs_pass:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)/L
    cumsum.plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                markevery=(i*50,400), marker=markers[i] , markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)    
plt.legend(ncol=1)
plt.title("Ours vs. passive approaches ($L = %s$)"%L)

plt.sca(axes[1][1])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
for bandit in algs_ours + algs_act:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)/L
    cumsum.plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                markevery=(i*50,400), marker=markers[i] , markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)    
plt.legend(ncol=1)
plt.title("Ours vs. active approaches ($L = %s$)"%L)
plt.xlabel("$T$")

#plt.tight_layout()

plt.suptitle("Cumulative gain over time (Bioliq)", fontsize=25)
plt.savefig("plots/Bioliq_gain_full.pdf")

# %%
fig, axes = plt.subplots(1, 2, sharey=True, sharex=True, figsize=(14,5), constrained_layout=True)


L = 1

plt.sca(axes[0])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
for bandit in algs_ours + algs_pass:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)/L
    cumsum.plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                markevery=(i*50,400), marker=markers[i] , markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)    
plt.legend(ncol=1)
plt.title("Ours vs. passive approaches")
plt.xlabel("$T$")
plt.ylabel("$\sum_{i}^{K} X_i^T$")

plt.sca(axes[1])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
for bandit in algs_ours + algs_act:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)/L
    cumsum.plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                markevery=(i*50,400), marker=markers[i] , markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)    
plt.legend(ncol=1)
plt.title("Ours vs. active approaches")
plt.xlabel("$T$")

#plt.tight_layout()

plt.suptitle("Cumulative gain over time (Bioliq)", fontsize=25)
plt.savefig("plots/Bioliq_gain_Fig7a.pdf")
