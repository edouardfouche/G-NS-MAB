# %%
import math

import matplotlib as mpl
mpl.rcParams['text.usetex'] = True 
mpl.rcParams['text.latex.preamble'] = [r'\usepackage{libertine}', r'\usepackage{newtxmath}'] 
mpl.rc('font', family='serif')

import numpy as np
import pandas as pd
import seaborn as sns


import matplotlib.pyplot as plt
from matplotlib import rc

from cycler import cycler


mpl.rcParams['ps.usedistiller'] = 'xpdf' 

plt.style.use('seaborn-notebook')
# sns.set_palette("Blues_r")

plt.rcParams['axes.titlesize'] = '25'
plt.rcParams['axes.labelsize'] = '25'
plt.rcParams['legend.fontsize'] = '15'
plt.rcParams['xtick.labelsize'] = '15'
plt.rcParams['ytick.labelsize'] = '15'

monochrome=(cycler('color', sns.color_palette("husl", 8))*2+(cycler('marker', ['v', 's', "o"])*7)[0:16])
plt.rc('axes', prop_cycle=monochrome)

pd.options.display.max_rows = 999
# Out:
# /var/folders/8v/5czrtjp134z_qn6j_jsmrnl80000gn/T/ipykernel_14160/831503919.py:5: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   mpl.rcParams['text.latex.preamble'] = [r'\usepackage{libertine}', r'\usepackage{newtxmath}']
# /var/folders/8v/5czrtjp134z_qn6j_jsmrnl80000gn/T/ipykernel_14160/831503919.py:21: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-notebook')

# %%
# Change if required
folder = "../experiments/2022-11-14-17-50_BanditRealWorld_Bioliq_"
dataset = "BanditRealWorld-Bioliq"

# %%
masterdata = pd.read_csv("%s/BanditRealWorld_Bioliq.csv"%folder, sep=",")
narms = masterdata.iloc[0]['k']

# %%
sorted(masterdata.bandit.unique())
# Out:
# ['ImpCPD',
#  'ImpCPD2',
#  'ImpCPD3',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=0.001',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=0.01',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=0.1',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-12',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-15',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-6',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-7',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-8',
#  'MP-ADS-KL-UCB-ADWIN1; d=0.001; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=0.001; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=0.01; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=0.01; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=0.1; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=0.1; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-15; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-15; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-5; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-5; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-7; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-7; r=true',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=false',
#  'MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=true',
#  'MP-ADS-TS-ADWIN1; d=0.001; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.001; r=true',
#  'MP-ADS-TS-ADWIN1; d=0.01; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.01; r=true',
#  'MP-ADS-TS-ADWIN1; d=0.1; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.1; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-12; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-12; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-15; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-15; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-4; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-4; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-5; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-5; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-6; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-6; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-7; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-7; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-8; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-8; r=true',
#  'MP-D-TS; g=0.7',
#  'MP-D-TS; g=0.8',
#  'MP-D-TS; g=0.9',
#  'MP-D-TS; g=0.99',
#  'MP-D-TS; g=0.999',
#  'MP-D-UCB; g=0.7',
#  'MP-D-UCB; g=0.8',
#  'MP-D-UCB; g=0.9',
#  'MP-D-UCB; g=0.99',
#  'MP-D-UCB; g=0.999',
#  'MP-E-G; e=0.7',
#  'MP-E-G; e=0.8',
#  'MP-E-G; e=0.9',
#  'MP-E-G; e=0.99',
#  'MP-GLR-KL-UCB-G',
#  'MP-GLR-KL-UCB-L',
#  'MP-KLUCB',
#  'MP-M-UCB; w=1000; m=10',
#  'MP-M-UCB; w=1000; m=100',
#  'MP-M-UCB; w=5000; m=10',
#  'MP-M-UCB; w=5000; m=100',
#  'MP-RExp3; b=100.0',
#  'MP-RExp3; b=1000.0',
#  'MP-RExp3; b=500.0',
#  'MP-RExp3; b=5000.0',
#  'MP-SW-TS; w=100',
#  'MP-SW-TS; w=1000',
#  'MP-SW-TS; w=500',
#  'MP-SW-TS; w=5000',
#  'MP-SW-UCB#-A; nu=0.1; l=12.3',
#  'MP-SW-UCB#-A; nu=0.2; l=12.3',
#  'MP-SW-UCB#-G; ka=0.1; l=4.3',
#  'MP-SW-UCB#-G; ka=0.2; l=4.3',
#  'MP-SW-UCB; w=100',
#  'MP-SW-UCB; w=1000',
#  'MP-SW-UCB; w=500',
#  'MP-SW-UCB; w=5000',
#  'MP-TS',
#  'OD',
#  'OR',
#  'OS',
#  'UCBL-CPD']

# %%
masterdata.columns
# Out:
# Index(['bandit', 'dataset', 'scalingstrategy', 'k', 'gain', 'cputime',
#        'iteration'],
#       dtype='object')

# %%
masterdata['reward/arm'] = masterdata['gain']/masterdata['k']

# %%
masterdata.shape
# Out:
# (573705, 8)

# %%
masterdata.groupby(["scalingstrategy", "bandit"])[['gain', 'k', 'reward/arm', 'cputime']].mean()
# Out:
#                                                               gain    k  \
# scalingstrategy bandit
# No-1            ImpCPD                                    0.645802  1.0
#                 ImpCPD2                                   0.694983  1.0
#                 ImpCPD3                                   0.598940  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001    0.464610  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01     0.411116  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1      0.362931  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-12  0.558897  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-15  0.559613  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4   0.533756  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5   0.558889  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-6   0.559551  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-7   0.559242  1.0
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-8   0.559154  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=0.001; r=false    0.803015  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=0.001; r=true     0.778735  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=0.01; r=false     0.803193  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=0.01; r=true      0.776902  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=0.1; r=false      0.794211  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=0.1; r=true       0.773782  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=false  0.805698  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=true   0.787705  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-15; r=false  0.798493  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-15; r=true   0.788438  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=false   0.803156  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=true    0.786102  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-5; r=false   0.812547  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-5; r=true    0.796392  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=false   0.799061  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=true    0.792537  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-7; r=false   0.784453  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-7; r=true    0.792394  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=false   0.800075  1.0
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=true    0.792474  1.0
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false        0.770970  1.0
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true         0.757902  1.0
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false         0.757299  1.0
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true          0.748121  1.0
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false          0.760497  1.0
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true           0.703827  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-12; r=false      0.774074  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-12; r=true       0.754676  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-15; r=false      0.773285  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-15; r=true       0.750190  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false       0.768137  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true        0.756556  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false       0.770195  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true        0.758183  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-6; r=false       0.772216  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-6; r=true        0.759755  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-7; r=false       0.779985  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-7; r=true        0.761971  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-8; r=false       0.779545  1.0
#                 MP-ADS-TS-ADWIN1; d=1.0E-8; r=true        0.759574  1.0
#                 MP-D-TS; g=0.7                            0.567177  1.0
#                 MP-D-TS; g=0.8                            0.577332  1.0
#                 MP-D-TS; g=0.9                            0.657519  1.0
#                 MP-D-TS; g=0.99                           0.789354  1.0
#                 MP-D-TS; g=0.999                          0.756183  1.0
#                 MP-D-UCB; g=0.7                           0.563015  1.0
#                 MP-D-UCB; g=0.8                           0.562600  1.0
#                 MP-D-UCB; g=0.9                           0.562593  1.0
#                 MP-D-UCB; g=0.99                          0.562191  1.0
#                 MP-D-UCB; g=0.999                         0.562679  1.0
#                 MP-E-G; e=0.7                             0.536152  1.0
#                 MP-E-G; e=0.8                             0.567505  1.0
#                 MP-E-G; e=0.9                             0.575173  1.0
#                 MP-E-G; e=0.99                            0.638978  1.0
#                 MP-GLR-KL-UCB-G                           0.459261  1.0
#                 MP-GLR-KL-UCB-L                           0.477844  1.0
#                 MP-KLUCB                                  0.730585  1.0
#                 MP-M-UCB; w=1000; m=10                    0.249465  1.0
#                 MP-M-UCB; w=1000; m=100                   0.249470  1.0
#                 MP-M-UCB; w=5000; m=10                    0.249462  1.0
#                 MP-M-UCB; w=5000; m=100                   0.249465  1.0
#                 MP-RExp3; b=100.0                         0.250161  1.0
#                 MP-RExp3; b=1000.0                        0.250205  1.0
#                 MP-RExp3; b=500.0                         0.250359  1.0
#                 MP-RExp3; b=5000.0                        0.250498  1.0
#                 MP-SW-TS; w=100                           0.168288  1.0
#                 MP-SW-TS; w=1000                          0.709601  1.0
#                 MP-SW-TS; w=500                           0.523279  1.0
#                 MP-SW-TS; w=5000                          0.670601  1.0
#                 MP-SW-UCB#-A; nu=0.1; l=12.3              0.330737  1.0
#                 MP-SW-UCB#-A; nu=0.2; l=12.3              0.340522  1.0
#                 MP-SW-UCB#-G; ka=0.1; l=4.3               0.253848  1.0
#                 MP-SW-UCB#-G; ka=0.2; l=4.3               0.253405  1.0
#                 MP-SW-UCB; w=100                          0.031527  1.0
#                 MP-SW-UCB; w=1000                         0.520005  1.0
#                 MP-SW-UCB; w=500                          0.371762  1.0
#                 MP-SW-UCB; w=5000                         0.688993  1.0
#                 MP-TS                                     0.617571  1.0
#                 OD                                        0.949826  1.0
#                 OR                                        0.252943  1.0
#                 OS                                        0.699950  1.0
#                 UCBL-CPD                                  0.598112  1.0
#
#                                                           reward/arm   cputime
# scalingstrategy bandit
# No-1            ImpCPD                                      0.645802  0.313327
#                 ImpCPD2                                     0.694983  1.577524
#                 ImpCPD3                                     0.598940  0.497554
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.001      0.464610  0.396087
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01       0.411116  0.452357
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1        0.362931  0.823915
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-12    0.558897  0.544185
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-15    0.559613  1.010293
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4     0.533756  0.899060
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5     0.558889  0.614592
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-6     0.559551  0.571784
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-7     0.559242  0.981232
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-8     0.559154  1.051009
#                 MP-ADS-KL-UCB-ADWIN1; d=0.001; r=false      0.803015  0.593007
#                 MP-ADS-KL-UCB-ADWIN1; d=0.001; r=true       0.778735  0.356649
#                 MP-ADS-KL-UCB-ADWIN1; d=0.01; r=false       0.803193  0.383830
#                 MP-ADS-KL-UCB-ADWIN1; d=0.01; r=true        0.776902  0.368989
#                 MP-ADS-KL-UCB-ADWIN1; d=0.1; r=false        0.794211  0.386292
#                 MP-ADS-KL-UCB-ADWIN1; d=0.1; r=true         0.773782  0.567910
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=false    0.805698  0.635532
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-12; r=true     0.787705  0.297315
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-15; r=false    0.798493  0.618296
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-15; r=true     0.788438  0.239848
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=false     0.803156  0.327578
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-4; r=true      0.786102  0.355569
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-5; r=false     0.812547  0.116516
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-5; r=true      0.796392  0.692927
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=false     0.799061  0.380536
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-6; r=true      0.792537  0.253292
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-7; r=false     0.784453  0.301806
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-7; r=true      0.792394  0.296607
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=false     0.800075  0.266180
#                 MP-ADS-KL-UCB-ADWIN1; d=1.0E-8; r=true      0.792474  0.325269
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false          0.770970  0.550257
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true           0.757902  0.302693
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false           0.757299  0.338894
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true            0.748121  0.559889
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false            0.760497  0.386244
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true             0.703827  0.609377
#                 MP-ADS-TS-ADWIN1; d=1.0E-12; r=false        0.774074  0.502199
#                 MP-ADS-TS-ADWIN1; d=1.0E-12; r=true         0.754676  0.347972
#                 MP-ADS-TS-ADWIN1; d=1.0E-15; r=false        0.773285  0.583869
#                 MP-ADS-TS-ADWIN1; d=1.0E-15; r=true         0.750190  0.323637
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false         0.768137  0.562876
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true          0.756556  0.320846
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false         0.770195  0.633546
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true          0.758183  0.471777
#                 MP-ADS-TS-ADWIN1; d=1.0E-6; r=false         0.772216  0.732260
#                 MP-ADS-TS-ADWIN1; d=1.0E-6; r=true          0.759755  0.586660
#                 MP-ADS-TS-ADWIN1; d=1.0E-7; r=false         0.779985  0.611042
#                 MP-ADS-TS-ADWIN1; d=1.0E-7; r=true          0.761971  0.564770
#                 MP-ADS-TS-ADWIN1; d=1.0E-8; r=false         0.779545  0.513516
#                 MP-ADS-TS-ADWIN1; d=1.0E-8; r=true          0.759574  0.683547
#                 MP-D-TS; g=0.7                              0.567177  0.417631
#                 MP-D-TS; g=0.8                              0.577332  0.425799
#                 MP-D-TS; g=0.9                              0.657519  0.426743
#                 MP-D-TS; g=0.99                             0.789354  0.510092
#                 MP-D-TS; g=0.999                            0.756183  0.661773
#                 MP-D-UCB; g=0.7                             0.563015  1.682475
#                 MP-D-UCB; g=0.8                             0.562600  1.610246
#                 MP-D-UCB; g=0.9                             0.562593  1.669872
#                 MP-D-UCB; g=0.99                            0.562191  1.407551
#                 MP-D-UCB; g=0.999                           0.562679  1.623041
#                 MP-E-G; e=0.7                               0.536152  0.250784
#                 MP-E-G; e=0.8                               0.567505  0.316514
#                 MP-E-G; e=0.9                               0.575173  0.177101
#                 MP-E-G; e=0.99                              0.638978  0.207405
#                 MP-GLR-KL-UCB-G                             0.459261  0.929310
#                 MP-GLR-KL-UCB-L                             0.477844  0.790899
#                 MP-KLUCB                                    0.730585  0.505448
#                 MP-M-UCB; w=1000; m=10                      0.249465  0.608225
#                 MP-M-UCB; w=1000; m=100                     0.249470  0.353799
#                 MP-M-UCB; w=5000; m=10                      0.249462  0.532254
#                 MP-M-UCB; w=5000; m=100                     0.249465  0.253087
#                 MP-RExp3; b=100.0                           0.250161  1.354868
#                 MP-RExp3; b=1000.0                          0.250205  1.304656
#                 MP-RExp3; b=500.0                           0.250359  1.520774
#                 MP-RExp3; b=5000.0                          0.250498  0.946866
#                 MP-SW-TS; w=100                             0.168288  0.513795
#                 MP-SW-TS; w=1000                            0.709601  0.523661
#                 MP-SW-TS; w=500                             0.523279  0.514773
#                 MP-SW-TS; w=5000                            0.670601  0.339608
#                 MP-SW-UCB#-A; nu=0.1; l=12.3                0.330737  0.385684
#                 MP-SW-UCB#-A; nu=0.2; l=12.3                0.340522  0.454527
#                 MP-SW-UCB#-G; ka=0.1; l=4.3                 0.253848  0.316896
#                 MP-SW-UCB#-G; ka=0.2; l=4.3                 0.253405  0.360934
#                 MP-SW-UCB; w=100                            0.031527  0.595223
#                 MP-SW-UCB; w=1000                           0.520005  0.514640
#                 MP-SW-UCB; w=500                            0.371762  0.475230
#                 MP-SW-UCB; w=5000                           0.688993  0.347670
#                 MP-TS                                       0.617571  0.317275
#                 OD                                          0.949826  0.239675
#                 OR                                          0.252943  0.066047
#                 OS                                          0.699950  0.016359
#                 UCBL-CPD                                    0.598112  0.353124

# %%
from matplotlib.markers import TICKLEFT, TICKRIGHT, TICKUP, TICKDOWN, CARETLEFT, CARETRIGHT, CARETUP, CARETDOWN
markers = [
#    '.',
#    ',',
    'v',
    'o',
    '^',
    '<',
    '>',
#    '1',
#    '2',
#    '3',
#    '4',
#    '8',
    's',
    'p',
    '*',
#    'h',
    'H',
    '+',
    'x',
    'D',
#    'd',
    '|',
    '_',
    TICKLEFT,
    TICKRIGHT,
    TICKUP,
    TICKDOWN,
    CARETLEFT,
    CARETRIGHT,
    CARETUP,
    CARETDOWN,
]

# %%
algs_ours = [    
    # ours
    'MP-ADR-Elimination-UCB-ADWIN1; d=0.001',
    'MP-ADS-TS-ADWIN1; d=0.001; r=true',
    'MP-ADS-KL-UCB-ADWIN1; d=0.001; r=true',
#    'MP-ADS-TS-ADWIN1; d=0.001; r=false'
]
algs_pass = [
    # passive
    'MP-D-UCB; g=0.9',
    'MP-RExp3; b=1000.0',
    'MP-SW-TS; w=1000',
#    'MP-SW-UCB; w=1000',
    'MP-SW-UCB#-A; nu=0.1; l=12.3', 
    #'MP-SW-UCB#-A; nu=0.2; l=12.3', 
    'MP-SW-UCB#-G; ka=0.1; l=4.3', 
    #'MP-SW-UCB#-G; ka=0.2; l=4.3'
]
algs_act = [
    # active
    'MP-GLR-KL-UCB-G',
#    'MP-GLR-KL-UCB-L',
#    'MP-GLR-KL-UCB-G-F',
#    'MP-GLR-KL-UCB-L-F',
    'MP-M-UCB; w=1000; m=10',
#    'MP-M-UCB; w=5000; m=100',
    #'ImpCPD',
    'ImpCPD2',
    #'ImpCPD3', 
    'UCBL-CPD'
]
algs_base = [
    # baselines
    'MP-TS',
    'MP-E-G; e=0.9',
    'OR',
    'OD',
    'OS',
    'CustomOracle'
]

# %%
prettynames = {
    'MP-ADR-Elimination-UCB-ADWIN1; d=0.001' : "ADR-E-UCB",
    'MP-ADS-TS-ADWIN1; d=0.001; r=true': "ADR-TS",
    'MP-ADS-TS-ADWIN1; d=0.001; r=false': "ADS-TS",
    'MP-ADS-KL-UCB-ADWIN1; d=0.001; r=true':'ADR-KL-UCB',
    'MP-D-UCB; g=0.9': "D-UCB",
    'MP-RExp3; b=1000.0': "RExp3",
    'MP-SW-TS; w=1000': "SW-TS",
    'MP-SW-UCB; w=1000': "SW-UCB",
    'MP-SW-UCB#-A; nu=0.1; l=12.3': "SW-UCB\#-A",
    'MP-SW-UCB#-G; ka=0.1; l=4.3': "SW-UCB\#-G",
    # active
    'MP-GLR-KL-UCB-G': 'GLR-KL-UCB',
    'MP-GLR-KL-UCB-L': 'GLR-KL-UCB-L',
    'MP-GLR-KL-UCB-G-F': 'GLR-KL-UCB-G-F',
    'MP-GLR-KL-UCB-L-F': 'GLR-KL-UCB-L-F',
#    'MP-M-UCB; w=1000; m=10': 'M-UCB; w=1000; m=10',
#    'MP-M-UCB; w=5000; m=100': 'M-UCB; w=5000; m=100',
    'MP-M-UCB; w=1000; m=10': 'M-UCB',
    'ImpCPD': 'ImpCPD1',
    'ImpCPD2': 'ImpCPD',
    'ImpCPD3': 'ImpCPD3', 
    'UCBL-CPD': 'UCBL-CPD',
    # baselines
    'MP-TS': 'MP-TS',
    'MP-E-G; e=0.9': 'Espilon-Greedy',
    'OR': "Random Oracle",
    'OD': "Dynamic Oracle",
    'OS': "Static Oracle",
    'CustomOracle': "Custom Oracle"
}

# %%
# compute regret against 'OD', or just the cumulative rewards

# %%
fig, axes = plt.subplots(1, 2, sharey=True, sharex=True, figsize=(14,5), constrained_layout=True)


L = 1

plt.sca(axes[0])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
for bandit in algs_ours + algs_pass:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)/L
    cumsum.plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                markevery=(i*50,400), marker=markers[i] , markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)    
plt.legend(ncol=1)
plt.title("Ours vs. passive approaches")
plt.xlabel("$T$")
plt.ylabel("$\sum_{i}^{K} X_i^T$")

plt.sca(axes[1])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
for bandit in algs_ours + algs_act:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)/L
    cumsum.plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                markevery=(i*50,400), marker=markers[i] , markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)    
plt.legend(ncol=1)
plt.title("Ours vs. active approaches")
plt.xlabel("$T$")

plt.xlim(0,6000) # TODO: Adapt if necessary
plt.ylim(0,5000)
#plt.tight_layout()

plt.suptitle("Cumulative gain over time (Bioliq)", fontsize=25)
plt.savefig("plots/Bioliq_gain_Fig7a.pdf")
