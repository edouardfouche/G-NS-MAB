# %%
import math

import matplotlib as mpl
mpl.rcParams['text.usetex'] = True 
mpl.rcParams['text.latex.preamble'] = [r'\usepackage{libertine}', r'\usepackage{newtxmath}'] 
mpl.rc('font', family='serif')

import numpy as np
import pandas as pd
import seaborn as sns


import matplotlib.pyplot as plt
from matplotlib import rc

from cycler import cycler


mpl.rcParams['ps.usedistiller'] = 'xpdf' 

plt.style.use('seaborn-notebook')
# sns.set_palette("Blues_r")

plt.rcParams['axes.titlesize'] = '25'
plt.rcParams['axes.labelsize'] = '25'
plt.rcParams['legend.fontsize'] = '15'
plt.rcParams['xtick.labelsize'] = '15'
plt.rcParams['ytick.labelsize'] = '15'

monochrome=(cycler('color', sns.color_palette("husl", 8))*2+(cycler('marker', ['v', 's', "o"])*7)[0:16])
plt.rc('axes', prop_cycle=monochrome)

pd.options.display.max_rows = 999
# Out:
# <ipython-input-1-56d1c1821bb1>:5: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   mpl.rcParams['text.latex.preamble'] = [r'\usepackage{libertine}', r'\usepackage{newtxmath}']

# %%
# Change if required
folder = "../experiments/2021-06-09-16-45_BanditRealWorld_Zozo_bts_"
dataset = "BanditRealWorld-Zozo-bts"

# %%
masterdata = pd.read_csv("%s/BanditRealWorld_Zozo_bts.csv"%folder, sep=",")
narms = masterdata.iloc[0]['k']

# %%
sorted(masterdata.bandit.unique())
# Out:
# ['MP-ADR-Elimination-UCB-ADWIN1; d=0.001',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=0.01',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=0.1',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4',
#  'MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5',
#  'MP-ADS-TS-ADWIN1; d=0.001; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.001; r=true',
#  'MP-ADS-TS-ADWIN1; d=0.01; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.01; r=true',
#  'MP-ADS-TS-ADWIN1; d=0.1; r=false',
#  'MP-ADS-TS-ADWIN1; d=0.1; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-4; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-4; r=true',
#  'MP-ADS-TS-ADWIN1; d=1.0E-5; r=false',
#  'MP-ADS-TS-ADWIN1; d=1.0E-5; r=true',
#  'MP-D-TS; g=0.7',
#  'MP-D-TS; g=0.8',
#  'MP-D-TS; g=0.9',
#  'MP-D-TS; g=0.99',
#  'MP-D-UCB; g=0.7',
#  'MP-D-UCB; g=0.8',
#  'MP-D-UCB; g=0.9',
#  'MP-D-UCB; g=0.99',
#  'MP-E-G; e=0.7',
#  'MP-E-G; e=0.8',
#  'MP-E-G; e=0.9',
#  'MP-E-G; e=0.99',
#  'MP-GLR-KL-UCB-G',
#  'MP-GLR-KL-UCB-G-F',
#  'MP-GLR-KL-UCB-L',
#  'MP-GLR-KL-UCB-L-F',
#  'MP-KLUCB',
#  'MP-M-UCB; w=1000; m=10',
#  'MP-M-UCB; w=1000; m=100',
#  'MP-M-UCB; w=5000; m=10',
#  'MP-M-UCB; w=5000; m=100',
#  'MP-RExp3; b=100.0',
#  'MP-RExp3; b=1000.0',
#  'MP-RExp3; b=500.0',
#  'MP-RExp3; b=5000.0',
#  'MP-SW-TS; w=100',
#  'MP-SW-TS; w=1000',
#  'MP-SW-TS; w=500',
#  'MP-SW-TS; w=5000',
#  'MP-SW-UCB#-A; nu=0.1; l=12.3',
#  'MP-SW-UCB#-A; nu=0.2; l=12.3',
#  'MP-SW-UCB#-G; ka=0.1; l=4.3',
#  'MP-SW-UCB#-G; ka=0.2; l=4.3',
#  'MP-SW-UCB; w=100',
#  'MP-SW-UCB; w=1000',
#  'MP-SW-UCB; w=500',
#  'MP-SW-UCB; w=5000',
#  'MP-TS',
#  'OD',
#  'OR',
#  'OS']

# %%
masterdata['reward/arm'] = masterdata['gain']/masterdata['k']

# %%
masterdata.shape
# Out:
# (2257920, 8)

# %%
masterdata.groupby(["scalingstrategy", "bandit"])[['gain', 'k', 'reward/arm', 'cputime']].mean()
# Out:
#                                                              gain  \
# scalingstrategy bandit
# No-1            MP-ADR-Elimination-UCB-ADWIN1; d=0.001   0.105037
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    0.096463
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     0.082503
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  0.102507
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  0.105662
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       0.300616
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true        0.261461
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        0.296162
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         0.246729
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         0.289518
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true          0.214927
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      0.299237
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       0.262496
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      0.298990
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       0.266627
#                 MP-D-TS; g=0.7                           0.085063
#                 MP-D-TS; g=0.8                           0.076089
#                 MP-D-TS; g=0.9                           0.099953
#                 MP-D-TS; g=0.99                          0.295554
#                 MP-D-UCB; g=0.7                          0.149644
#                 MP-D-UCB; g=0.8                          0.149305
#                 MP-D-UCB; g=0.9                          0.148443
#                 MP-D-UCB; g=0.99                         0.145501
#                 MP-E-G; e=0.7                            0.306873
#                 MP-E-G; e=0.8                            0.316272
#                 MP-E-G; e=0.9                            0.327219
#                 MP-E-G; e=0.99                           0.295013
#                 MP-GLR-KL-UCB-G                          0.165724
#                 MP-GLR-KL-UCB-G-F                        0.207249
#                 MP-GLR-KL-UCB-L                          0.160890
#                 MP-GLR-KL-UCB-L-F                        0.209577
#                 MP-KLUCB                                 0.092262
#                 MP-M-UCB; w=1000; m=10                   0.005952
#                 MP-M-UCB; w=1000; m=100                  0.005952
#                 MP-M-UCB; w=5000; m=10                   0.005952
#                 MP-M-UCB; w=5000; m=100                  0.005952
#                 MP-RExp3; b=100.0                        0.121086
#                 MP-RExp3; b=1000.0                       0.120690
#                 MP-RExp3; b=500.0                        0.120680
#                 MP-RExp3; b=5000.0                       0.120956
#                 MP-SW-TS; w=100                          0.161746
#                 MP-SW-TS; w=1000                         0.250512
#                 MP-SW-TS; w=500                          0.215312
#                 MP-SW-TS; w=5000                         0.307909
#                 MP-SW-UCB#-A; nu=0.1; l=12.3             0.073612
#                 MP-SW-UCB#-A; nu=0.2; l=12.3             0.071035
#                 MP-SW-UCB#-G; ka=0.1; l=4.3              0.098298
#                 MP-SW-UCB#-G; ka=0.2; l=4.3              0.093996
#                 MP-SW-UCB; w=100                         0.108381
#                 MP-SW-UCB; w=1000                        0.239196
#                 MP-SW-UCB; w=500                         0.175057
#                 MP-SW-UCB; w=5000                        0.318084
#                 MP-TS                                    0.328380
#                 OD                                       0.930853
#                 OR                                       0.117025
#                 OS                                       0.364683
# No-10           MP-ADR-Elimination-UCB-ADWIN1; d=0.001   0.000000
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    0.000000
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     0.000000
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  0.000000
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  0.000000
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       0.024975
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true        0.026091
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        0.024272
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         0.028621
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         0.028802
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true          0.024206
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      0.021909
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       0.022148
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      0.023434
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       0.025598
#                 MP-D-TS; g=0.7                           0.024003
#                 MP-D-TS; g=0.8                           0.023594
#                 MP-D-TS; g=0.9                           0.022453
#                 MP-D-TS; g=0.99                          0.025368
#                 MP-D-UCB; g=0.7                          0.016890
#                 MP-D-UCB; g=0.8                          0.020032
#                 MP-D-UCB; g=0.9                          0.016352
#                 MP-D-UCB; g=0.99                         0.020196
#                 MP-E-G; e=0.7                            0.002115
#                 MP-E-G; e=0.8                            0.000777
#                 MP-E-G; e=0.9                            0.000334
#                 MP-E-G; e=0.99                           0.000198
#                 MP-GLR-KL-UCB-G                          0.015005
#                 MP-GLR-KL-UCB-G-F                        0.018626
#                 MP-GLR-KL-UCB-L                          0.015284
#                 MP-GLR-KL-UCB-L-F                        0.017840
#                 MP-KLUCB                                 0.000000
#                 MP-M-UCB; w=1000; m=10                   0.000000
#                 MP-M-UCB; w=1000; m=100                  0.000000
#                 MP-M-UCB; w=5000; m=10                   0.000000
#                 MP-M-UCB; w=5000; m=100                  0.000000
#                 MP-RExp3; b=100.0                        0.029744
#                 MP-RExp3; b=1000.0                       0.033738
#                 MP-RExp3; b=500.0                        0.032672
#                 MP-RExp3; b=5000.0                       0.031836
#                 MP-SW-TS; w=100                          0.022843
#                 MP-SW-TS; w=1000                         0.023131
#                 MP-SW-TS; w=500                          0.019947
#                 MP-SW-TS; w=5000                         0.023811
#                 MP-SW-UCB#-A; nu=0.1; l=12.3             0.017262
#                 MP-SW-UCB#-A; nu=0.2; l=12.3             0.016902
#                 MP-SW-UCB#-G; ka=0.1; l=4.3              0.015889
#                 MP-SW-UCB#-G; ka=0.2; l=4.3              0.015962
#                 MP-SW-UCB; w=100                         0.021461
#                 MP-SW-UCB; w=1000                        0.019833
#                 MP-SW-UCB; w=500                         0.017840
#                 MP-SW-UCB; w=5000                        0.019395
#                 MP-TS                                    0.024471
#                 OD                                       3.788889
#                 OR                                       0.027753
#                 OS                                       0.993155
# No-2            MP-ADR-Elimination-UCB-ADWIN1; d=0.001   0.136652
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    0.134249
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     0.130031
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  0.138140
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  0.143732
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       0.519491
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true        0.456045
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        0.514710
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         0.425090
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         0.505190
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true          0.371323
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      0.525674
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       0.466953
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      0.527759
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       0.478783
#                 MP-D-TS; g=0.7                           0.115666
#                 MP-D-TS; g=0.8                           0.167856
#                 MP-D-TS; g=0.9                           0.253124
#                 MP-D-TS; g=0.99                          0.618938
#                 MP-D-UCB; g=0.7                          0.184800
#                 MP-D-UCB; g=0.8                          0.184014
#                 MP-D-UCB; g=0.9                          0.180613
#                 MP-D-UCB; g=0.99                         0.179219
#                 MP-E-G; e=0.7                            0.564668
#                 MP-E-G; e=0.8                            0.575780
#                 MP-E-G; e=0.9                            0.596341
#                 MP-E-G; e=0.99                           0.583372
#                 MP-GLR-KL-UCB-G                          0.356124
#                 MP-GLR-KL-UCB-G-F                        0.377676
#                 MP-GLR-KL-UCB-L                          0.382418
#                 MP-GLR-KL-UCB-L-F                        0.418610
#                 MP-KLUCB                                 0.006845
#                 MP-M-UCB; w=1000; m=10                   0.131203
#                 MP-M-UCB; w=1000; m=100                  0.133362
#                 MP-M-UCB; w=5000; m=10                   0.127412
#                 MP-M-UCB; w=5000; m=100                  0.129663
#                 MP-RExp3; b=100.0                        0.240265
#                 MP-RExp3; b=1000.0                       0.243420
#                 MP-RExp3; b=500.0                        0.240118
#                 MP-RExp3; b=5000.0                       0.239597
#                 MP-SW-TS; w=100                          0.294466
#                 MP-SW-TS; w=1000                         0.497431
#                 MP-SW-TS; w=500                          0.416341
#                 MP-SW-TS; w=5000                         0.597775
#                 MP-SW-UCB#-A; nu=0.1; l=12.3             0.142042
#                 MP-SW-UCB#-A; nu=0.2; l=12.3             0.134089
#                 MP-SW-UCB#-G; ka=0.1; l=4.3              0.200023
#                 MP-SW-UCB#-G; ka=0.2; l=4.3              0.192574
#                 MP-SW-UCB; w=100                         0.172666
#                 MP-SW-UCB; w=1000                        0.443339
#                 MP-SW-UCB; w=500                         0.375092
#                 MP-SW-UCB; w=5000                        0.428765
#                 MP-TS                                    0.609041
#                 OD                                       1.755655
#                 OR                                       0.234644
#                 OS                                       0.627282
# No-5            MP-ADR-Elimination-UCB-ADWIN1; d=0.001   0.018632
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    0.018468
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     0.018688
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  0.017703
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  0.020226
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       0.413367
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true        0.382115
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        0.384958
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         0.359319
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         0.332555
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true          0.312373
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      0.360543
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       0.401563
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      0.418655
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       0.364368
#                 MP-D-TS; g=0.7                           0.158355
#                 MP-D-TS; g=0.8                           0.280302
#                 MP-D-TS; g=0.9                           0.601150
#                 MP-D-TS; g=0.99                          0.396432
#                 MP-D-UCB; g=0.7                          0.081930
#                 MP-D-UCB; g=0.8                          0.072553
#                 MP-D-UCB; g=0.9                          0.079955
#                 MP-D-UCB; g=0.99                         0.076604
#                 MP-E-G; e=0.7                            0.411365
#                 MP-E-G; e=0.8                            0.339827
#                 MP-E-G; e=0.9                            0.196951
#                 MP-E-G; e=0.99                           0.112748
#                 MP-GLR-KL-UCB-G                          0.102369
#                 MP-GLR-KL-UCB-G-F                        0.100312
#                 MP-GLR-KL-UCB-L                          0.101831
#                 MP-GLR-KL-UCB-L-F                        0.099544
#                 MP-KLUCB                                 0.000595
#                 MP-M-UCB; w=1000; m=10                   0.076707
#                 MP-M-UCB; w=1000; m=100                  0.074327
#                 MP-M-UCB; w=5000; m=10                   0.076073
#                 MP-M-UCB; w=5000; m=100                  0.079584
#                 MP-RExp3; b=100.0                        0.340427
#                 MP-RExp3; b=1000.0                       0.340171
#                 MP-RExp3; b=500.0                        0.345370
#                 MP-RExp3; b=5000.0                       0.344509
#                 MP-SW-TS; w=100                          0.307753
#                 MP-SW-TS; w=1000                         0.399860
#                 MP-SW-TS; w=500                          0.362498
#                 MP-SW-TS; w=5000                         0.380514
#                 MP-SW-UCB#-A; nu=0.1; l=12.3             0.078762
#                 MP-SW-UCB#-A; nu=0.2; l=12.3             0.078324
#                 MP-SW-UCB#-G; ka=0.1; l=4.3              0.149814
#                 MP-SW-UCB#-G; ka=0.2; l=4.3              0.132163
#                 MP-SW-UCB; w=100                         0.084026
#                 MP-SW-UCB; w=1000                        0.094682
#                 MP-SW-UCB; w=500                         0.094134
#                 MP-SW-UCB; w=5000                        0.091688
#                 MP-TS                                    0.375970
#                 OD                                       3.348810
#                 OR                                       0.322497
#                 OS                                       1.067361
#
#                                                                    k  \
# scalingstrategy bandit
# No-1            MP-ADR-Elimination-UCB-ADWIN1; d=0.001     24.147057
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01      24.304826
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1       26.376119
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4    23.528200
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5    23.858405
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false          2.187882
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true           3.156527
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false           2.205920
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true            3.350135
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false            2.263283
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true             3.835094
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false         2.169002
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true          3.020693
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false         2.168408
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true          2.929542
#                 MP-D-TS; g=0.7                             12.694847
#                 MP-D-TS; g=0.8                             13.407054
#                 MP-D-TS; g=0.9                             10.758155
#                 MP-D-TS; g=0.99                             2.837053
#                 MP-D-UCB; g=0.7                            14.140908
#                 MP-D-UCB; g=0.8                            13.763042
#                 MP-D-UCB; g=0.9                            13.607452
#                 MP-D-UCB; g=0.99                           14.463419
#                 MP-E-G; e=0.7                               1.967473
#                 MP-E-G; e=0.8                               2.153280
#                 MP-E-G; e=0.9                               3.188970
#                 MP-E-G; e=0.99                             12.167250
#                 MP-GLR-KL-UCB-G                            37.775652
#                 MP-GLR-KL-UCB-G-F                          42.388505
#                 MP-GLR-KL-UCB-L                            42.689972
#                 MP-GLR-KL-UCB-L-F                          43.103613
#                 MP-KLUCB                                   77.558036
#                 MP-M-UCB; w=1000; m=10                     91.750000
#                 MP-M-UCB; w=1000; m=100                    91.750000
#                 MP-M-UCB; w=5000; m=10                     91.750000
#                 MP-M-UCB; w=5000; m=100                    91.750000
#                 MP-RExp3; b=100.0                           2.622912
#                 MP-RExp3; b=1000.0                          2.621560
#                 MP-RExp3; b=500.0                           2.620641
#                 MP-RExp3; b=5000.0                          2.624819
#                 MP-SW-TS; w=100                             3.644563
#                 MP-SW-TS; w=1000                            2.765989
#                 MP-SW-TS; w=500                             3.350943
#                 MP-SW-TS; w=5000                            1.884038
#                 MP-SW-UCB#-A; nu=0.1; l=12.3               27.996263
#                 MP-SW-UCB#-A; nu=0.2; l=12.3               29.655888
#                 MP-SW-UCB#-G; ka=0.1; l=4.3                14.330217
#                 MP-SW-UCB#-G; ka=0.2; l=4.3                14.504523
#                 MP-SW-UCB; w=100                           18.501072
#                 MP-SW-UCB; w=1000                          10.732092
#                 MP-SW-UCB; w=500                           14.888117
#                 MP-SW-UCB; w=5000                           6.796451
#                 MP-TS                                       1.696622
#                 OD                                          1.000000
#                 OR                                          2.637757
#                 OS                                          6.333036
# No-10           MP-ADR-Elimination-UCB-ADWIN1; d=0.001   1000.000000
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    1000.000000
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     1000.000000
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  1000.000000
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  1000.000000
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false        998.164682
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true         998.809523
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false         998.933531
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true          998.614417
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false          998.286326
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true           998.586309
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false       998.875661
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true        998.668980
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false       998.741024
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true        998.344197
#                 MP-D-TS; g=0.7                            998.424271
#                 MP-D-TS; g=0.8                            999.355159
#                 MP-D-TS; g=0.9                            998.404431
#                 MP-D-TS; g=0.99                           998.052247
#                 MP-D-UCB; g=0.7                           999.305556
#                 MP-D-UCB; g=0.8                           999.115410
#                 MP-D-UCB; g=0.9                           999.338624
#                 MP-D-UCB; g=0.99                          998.801256
#                 MP-E-G; e=0.7                             999.625771
#                 MP-E-G; e=0.8                             999.724978
#                 MP-E-G; e=0.9                             999.746896
#                 MP-E-G; e=0.99                            999.925595
#                 MP-GLR-KL-UCB-G                           999.069113
#                 MP-GLR-KL-UCB-G-F                         998.859126
#                 MP-GLR-KL-UCB-L                           998.903217
#                 MP-GLR-KL-UCB-L-F                         998.751652
#                 MP-KLUCB                                 1000.000000
#                 MP-M-UCB; w=1000; m=10                   1000.000000
#                 MP-M-UCB; w=1000; m=100                  1000.000000
#                 MP-M-UCB; w=5000; m=10                   1000.000000
#                 MP-M-UCB; w=5000; m=100                  1000.000000
#                 MP-RExp3; b=100.0                         998.420964
#                 MP-RExp3; b=1000.0                        998.090277
#                 MP-RExp3; b=500.0                         998.520171
#                 MP-RExp3; b=5000.0                        997.577710
#                 MP-SW-TS; w=100                           998.850859
#                 MP-SW-TS; w=1000                          998.387896
#                 MP-SW-TS; w=500                           998.559146
#                 MP-SW-TS; w=5000                          998.611110
#                 MP-SW-UCB#-A; nu=0.1; l=12.3              998.916171
#                 MP-SW-UCB#-A; nu=0.2; l=12.3              998.862434
#                 MP-SW-UCB#-G; ka=0.1; l=4.3               999.007936
#                 MP-SW-UCB#-G; ka=0.2; l=4.3               998.520171
#                 MP-SW-UCB; w=100                          998.710316
#                 MP-SW-UCB; w=1000                         998.553240
#                 MP-SW-UCB; w=500                          998.900461
#                 MP-SW-UCB; w=5000                         998.660713
#                 MP-TS                                     998.859126
#                 OD                                         10.000000
#                 OR                                        998.106812
#                 OS                                        649.276786
# No-2            MP-ADR-Elimination-UCB-ADWIN1; d=0.001    110.685402
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01     111.486861
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1      113.440381
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4   112.313241
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5   110.968624
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false         12.869734
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true          18.974332
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false          13.237046
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true           21.484129
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false           13.800097
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true            26.162032
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false        12.994979
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true         18.441295
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false        12.151849
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true         17.289266
#                 MP-D-TS; g=0.7                            108.245153
#                 MP-D-TS; g=0.8                             92.620102
#                 MP-D-TS; g=0.9                             69.206048
#                 MP-D-TS; g=0.99                            12.013467
#                 MP-D-UCB; g=0.7                            98.598341
#                 MP-D-UCB; g=0.8                            97.993587
#                 MP-D-UCB; g=0.9                            98.785921
#                 MP-D-UCB; g=0.99                           99.680641
#                 MP-E-G; e=0.7                              17.323966
#                 MP-E-G; e=0.8                              21.342222
#                 MP-E-G; e=0.9                              25.114308
#                 MP-E-G; e=0.99                             31.775595
#                 MP-GLR-KL-UCB-G                            82.341217
#                 MP-GLR-KL-UCB-G-F                          81.005340
#                 MP-GLR-KL-UCB-L                            79.192952
#                 MP-GLR-KL-UCB-L-F                          76.130861
#                 MP-KLUCB                                  194.617857
#                 MP-M-UCB; w=1000; m=10                    121.471915
#                 MP-M-UCB; w=1000; m=100                   120.037507
#                 MP-M-UCB; w=5000; m=10                    120.318825
#                 MP-M-UCB; w=5000; m=100                   121.155863
#                 MP-RExp3; b=100.0                          15.995011
#                 MP-RExp3; b=1000.0                         16.114876
#                 MP-RExp3; b=500.0                          16.046384
#                 MP-RExp3; b=5000.0                         15.997248
#                 MP-SW-TS; w=100                            34.654277
#                 MP-SW-TS; w=1000                           13.026437
#                 MP-SW-TS; w=500                            17.473976
#                 MP-SW-TS; w=5000                           10.013102
#                 MP-SW-UCB#-A; nu=0.1; l=12.3              114.967617
#                 MP-SW-UCB#-A; nu=0.2; l=12.3              116.226454
#                 MP-SW-UCB#-G; ka=0.1; l=4.3                37.235906
#                 MP-SW-UCB#-G; ka=0.2; l=4.3                42.670340
#                 MP-SW-UCB; w=100                          112.486464
#                 MP-SW-UCB; w=1000                          60.703112
#                 MP-SW-UCB; w=500                           77.597406
#                 MP-SW-UCB; w=5000                          62.605117
#                 MP-TS                                       9.372182
#                 OD                                          2.000000
#                 OR                                         16.147327
#                 OS                                         22.035714
# No-5            MP-ADR-Elimination-UCB-ADWIN1; d=0.001    496.215451
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01     496.391541
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1      495.623520
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4   495.985623
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5   496.103017
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false        399.257167
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true         406.601445
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false         410.223149
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true          410.715349
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false          418.319258
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true           424.098265
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false       411.893339
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true        403.221013
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false       397.709931
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true        411.196817
#                 MP-D-TS; g=0.7                            465.072794
#                 MP-D-TS; g=0.8                            446.825632
#                 MP-D-TS; g=0.9                            374.391026
#                 MP-D-TS; g=0.99                           403.601766
#                 MP-D-UCB; g=0.7                           482.179549
#                 MP-D-UCB; g=0.8                           482.049147
#                 MP-D-UCB; g=0.9                           481.844021
#                 MP-D-UCB; g=0.99                          482.215038
#                 MP-E-G; e=0.7                             415.559719
#                 MP-E-G; e=0.8                             433.004325
#                 MP-E-G; e=0.9                             469.338837
#                 MP-E-G; e=0.99                            487.059203
#                 MP-GLR-KL-UCB-G                           475.016032
#                 MP-GLR-KL-UCB-G-F                         475.521910
#                 MP-GLR-KL-UCB-L                           476.366510
#                 MP-GLR-KL-UCB-L-F                         475.108249
#                 MP-KLUCB                                  498.772321
#                 MP-M-UCB; w=1000; m=10                    480.943750
#                 MP-M-UCB; w=1000; m=100                   481.700294
#                 MP-M-UCB; w=5000; m=10                    479.870196
#                 MP-M-UCB; w=5000; m=100                   478.342090
#                 MP-RExp3; b=100.0                         388.234202
#                 MP-RExp3; b=1000.0                        390.211632
#                 MP-RExp3; b=500.0                         387.873966
#                 MP-RExp3; b=5000.0                        386.910158
#                 MP-SW-TS; w=100                           428.022294
#                 MP-SW-TS; w=1000                          400.498744
#                 MP-SW-TS; w=500                           412.704425
#                 MP-SW-TS; w=5000                          407.200199
#                 MP-SW-UCB#-A; nu=0.1; l=12.3              479.524802
#                 MP-SW-UCB#-A; nu=0.2; l=12.3              480.111773
#                 MP-SW-UCB#-G; ka=0.1; l=4.3               456.682276
#                 MP-SW-UCB#-G; ka=0.2; l=4.3               459.879566
#                 MP-SW-UCB; w=100                          482.143426
#                 MP-SW-UCB; w=1000                         480.260763
#                 MP-SW-UCB; w=500                          480.232531
#                 MP-SW-UCB; w=5000                         480.934728
#                 MP-TS                                     409.842554
#                 OD                                          5.000000
#                 OR                                        388.666249
#                 OS                                        146.723214
#
#                                                            reward/arm  \
# scalingstrategy bandit
# No-1            MP-ADR-Elimination-UCB-ADWIN1; d=0.001   1.715728e-02
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    1.477641e-02
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     1.247740e-02
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  1.689654e-02
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  1.755537e-02
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       1.924363e-01
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true        1.320452e-01
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        1.842903e-01
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         1.150924e-01
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         1.754305e-01
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true          7.911903e-02
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      1.911962e-01
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       1.335343e-01
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      1.949910e-01
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       1.388262e-01
#                 MP-D-TS; g=0.7                           1.207447e-02
#                 MP-D-TS; g=0.8                           9.681268e-03
#                 MP-D-TS; g=0.9                           1.442599e-02
#                 MP-D-TS; g=0.99                          1.327741e-01
#                 MP-D-UCB; g=0.7                          2.915542e-02
#                 MP-D-UCB; g=0.8                          2.856256e-02
#                 MP-D-UCB; g=0.9                          2.800885e-02
#                 MP-D-UCB; g=0.99                         2.739184e-02
#                 MP-E-G; e=0.7                            2.258847e-01
#                 MP-E-G; e=0.8                            2.444841e-01
#                 MP-E-G; e=0.9                            2.627073e-01
#                 MP-E-G; e=0.99                           2.483459e-01
#                 MP-GLR-KL-UCB-G                          3.600952e-02
#                 MP-GLR-KL-UCB-G-F                        4.835968e-02
#                 MP-GLR-KL-UCB-L                          3.716917e-02
#                 MP-GLR-KL-UCB-L-F                        4.877918e-02
#                 MP-KLUCB                                 9.226190e-02
#                 MP-M-UCB; w=1000; m=10                   5.952381e-03
#                 MP-M-UCB; w=1000; m=100                  5.952381e-03
#                 MP-M-UCB; w=5000; m=10                   5.952381e-03
#                 MP-M-UCB; w=5000; m=100                  5.952381e-03
#                 MP-RExp3; b=100.0                        4.935892e-02
#                 MP-RExp3; b=1000.0                       4.908151e-02
#                 MP-RExp3; b=500.0                        4.910643e-02
#                 MP-RExp3; b=5000.0                       4.914447e-02
#                 MP-SW-TS; w=100                          7.200107e-02
#                 MP-SW-TS; w=1000                         1.229572e-01
#                 MP-SW-TS; w=500                          8.168972e-02
#                 MP-SW-TS; w=5000                         2.205378e-01
#                 MP-SW-UCB#-A; nu=0.1; l=12.3             9.116136e-03
#                 MP-SW-UCB#-A; nu=0.2; l=12.3             8.839810e-03
#                 MP-SW-UCB#-G; ka=0.1; l=4.3              3.799783e-02
#                 MP-SW-UCB#-G; ka=0.2; l=4.3              3.454111e-02
#                 MP-SW-UCB; w=100                         1.297099e-02
#                 MP-SW-UCB; w=1000                        5.164643e-02
#                 MP-SW-UCB; w=500                         2.300638e-02
#                 MP-SW-UCB; w=5000                        1.562988e-01
#                 MP-TS                                    2.595637e-01
#                 OD                                       9.308532e-01
#                 OR                                       4.723280e-02
#                 OS                                       3.646825e-01
# No-10           MP-ADR-Elimination-UCB-ADWIN1; d=0.001   0.000000e+00
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    0.000000e+00
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     0.000000e+00
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  0.000000e+00
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  0.000000e+00
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       2.817461e-05
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true        2.916667e-05
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        2.678274e-05
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         3.174605e-05
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         3.333236e-05
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true          2.797520e-05
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      2.450694e-05
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       2.569446e-05
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      2.668353e-05
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       2.946725e-05
#                 MP-D-TS; g=0.7                           2.827382e-05
#                 MP-D-TS; g=0.8                           2.509721e-05
#                 MP-D-TS; g=0.9                           2.509822e-05
#                 MP-D-TS; g=0.99                          3.075200e-05
#                 MP-D-UCB; g=0.7                          1.775794e-05
#                 MP-D-UCB; g=0.8                          2.212401e-05
#                 MP-D-UCB; g=0.9                          1.765774e-05
#                 MP-D-UCB; g=0.99                         2.251885e-05
#                 MP-E-G; e=0.7                            5.364319e-06
#                 MP-E-G; e=0.8                            4.964133e-06
#                 MP-E-G; e=0.9                            6.753243e-06
#                 MP-E-G; e=0.99                           7.936508e-07
#                 MP-GLR-KL-UCB-G                          1.755953e-05
#                 MP-GLR-KL-UCB-G-F                        2.123017e-05
#                 MP-GLR-KL-UCB-L                          1.776192e-05
#                 MP-GLR-KL-UCB-L-F                        2.122918e-05
#                 MP-KLUCB                                 0.000000e+00
#                 MP-M-UCB; w=1000; m=10                   0.000000e+00
#                 MP-M-UCB; w=1000; m=100                  0.000000e+00
#                 MP-M-UCB; w=5000; m=10                   0.000000e+00
#                 MP-M-UCB; w=5000; m=100                  0.000000e+00
#                 MP-RExp3; b=100.0                        3.392462e-05
#                 MP-RExp3; b=1000.0                       3.829266e-05
#                 MP-RExp3; b=500.0                        3.591171e-05
#                 MP-RExp3; b=5000.0                       3.700200e-05
#                 MP-SW-TS; w=100                          2.510317e-05
#                 MP-SW-TS; w=1000                         2.698215e-05
#                 MP-SW-TS; w=500                          2.351091e-05
#                 MP-SW-TS; w=5000                         2.629267e-05
#                 MP-SW-UCB#-A; nu=0.1; l=12.3             2.033730e-05
#                 MP-SW-UCB#-A; nu=0.2; l=12.3             1.924703e-05
#                 MP-SW-UCB#-G; ka=0.1; l=4.3              1.755753e-05
#                 MP-SW-UCB#-G; ka=0.2; l=4.3              1.904168e-05
#                 MP-SW-UCB; w=100                         2.361012e-05
#                 MP-SW-UCB; w=1000                        2.420833e-05
#                 MP-SW-UCB; w=500                         2.023712e-05
#                 MP-SW-UCB; w=5000                        2.152778e-05
#                 MP-TS                                    2.688592e-05
#                 OD                                       3.788889e-01
#                 OR                                       3.125000e-05
#                 OS                                       9.931548e-02
# No-2            MP-ADR-Elimination-UCB-ADWIN1; d=0.001   3.623615e-03
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    3.617360e-03
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     3.497983e-03
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  3.668555e-03
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  3.684708e-03
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       8.619710e-02
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true        4.606125e-02
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        8.073866e-02
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         3.434729e-02
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         7.135049e-02
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true          2.319656e-02
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      9.079901e-02
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       5.464140e-02
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      9.245129e-02
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       6.022431e-02
#                 MP-D-TS; g=0.7                           2.431823e-03
#                 MP-D-TS; g=0.8                           3.850329e-03
#                 MP-D-TS; g=0.9                           7.520107e-03
#                 MP-D-TS; g=0.99                          1.114083e-01
#                 MP-D-UCB; g=0.7                          4.556786e-03
#                 MP-D-UCB; g=0.8                          4.568902e-03
#                 MP-D-UCB; g=0.9                          4.259820e-03
#                 MP-D-UCB; g=0.99                         4.385982e-03
#                 MP-E-G; e=0.7                            1.477182e-01
#                 MP-E-G; e=0.8                            1.691726e-01
#                 MP-E-G; e=0.9                            1.934697e-01
#                 MP-E-G; e=0.99                           1.959903e-01
#                 MP-GLR-KL-UCB-G                          1.154143e-02
#                 MP-GLR-KL-UCB-G-F                        1.343753e-02
#                 MP-GLR-KL-UCB-L                          1.297236e-02
#                 MP-GLR-KL-UCB-L-F                        1.668035e-02
#                 MP-KLUCB                                 3.422619e-03
#                 MP-M-UCB; w=1000; m=10                   2.965500e-03
#                 MP-M-UCB; w=1000; m=100                  3.019919e-03
#                 MP-M-UCB; w=5000; m=10                   2.976591e-03
#                 MP-M-UCB; w=5000; m=100                  3.027345e-03
#                 MP-RExp3; b=100.0                        2.033174e-02
#                 MP-RExp3; b=1000.0                       2.046289e-02
#                 MP-RExp3; b=500.0                        2.037948e-02
#                 MP-RExp3; b=5000.0                       2.037603e-02
#                 MP-SW-TS; w=100                          1.971134e-02
#                 MP-SW-TS; w=1000                         7.032498e-02
#                 MP-SW-TS; w=500                          4.230391e-02
#                 MP-SW-TS; w=5000                         1.774999e-01
#                 MP-SW-UCB#-A; nu=0.1; l=12.3             2.822712e-03
#                 MP-SW-UCB#-A; nu=0.2; l=12.3             2.876211e-03
#                 MP-SW-UCB#-G; ka=0.1; l=4.3              1.245777e-02
#                 MP-SW-UCB#-G; ka=0.2; l=4.3              1.037161e-02
#                 MP-SW-UCB; w=100                         3.417589e-03
#                 MP-SW-UCB; w=1000                        2.376077e-02
#                 MP-SW-UCB; w=500                         1.351113e-02
#                 MP-SW-UCB; w=5000                        2.541752e-02
#                 MP-TS                                    1.939219e-01
#                 OD                                       8.778274e-01
#                 OR                                       1.950061e-02
#                 OS                                       3.136409e-01
# No-5            MP-ADR-Elimination-UCB-ADWIN1; d=0.001   1.517717e-04
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    1.499959e-04
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     1.523750e-04
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  1.523789e-04
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  1.575494e-04
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       1.870890e-03
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true        1.705212e-03
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        1.619735e-03
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         1.553913e-03
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         1.356451e-03
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true          1.235779e-03
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      1.535127e-03
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       1.805489e-03
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      1.966971e-03
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       1.582950e-03
#                 MP-D-TS; g=0.7                           5.180726e-04
#                 MP-D-TS; g=0.8                           9.745627e-04
#                 MP-D-TS; g=0.9                           3.070117e-03
#                 MP-D-TS; g=0.99                          1.764700e-03
#                 MP-D-UCB; g=0.7                          2.430195e-04
#                 MP-D-UCB; g=0.8                          2.315470e-04
#                 MP-D-UCB; g=0.9                          2.420115e-04
#                 MP-D-UCB; g=0.99                         2.323448e-04
#                 MP-E-G; e=0.7                            2.653785e-03
#                 MP-E-G; e=0.8                            1.932615e-03
#                 MP-E-G; e=0.9                            7.151553e-04
#                 MP-E-G; e=0.99                           3.995556e-04
#                 MP-GLR-KL-UCB-G                          3.283310e-04
#                 MP-GLR-KL-UCB-G-F                        3.246861e-04
#                 MP-GLR-KL-UCB-L                          3.281619e-04
#                 MP-GLR-KL-UCB-L-F                        3.273684e-04
#                 MP-KLUCB                                 1.190476e-04
#                 MP-M-UCB; w=1000; m=10                   2.443962e-04
#                 MP-M-UCB; w=1000; m=100                  2.360730e-04
#                 MP-M-UCB; w=5000; m=10                   2.422393e-04
#                 MP-M-UCB; w=5000; m=100                  2.541422e-04
#                 MP-RExp3; b=100.0                        1.642993e-03
#                 MP-RExp3; b=1000.0                       1.608068e-03
#                 MP-RExp3; b=500.0                        1.659726e-03
#                 MP-RExp3; b=5000.0                       1.623834e-03
#                 MP-SW-TS; w=100                          1.178990e-03
#                 MP-SW-TS; w=1000                         1.848884e-03
#                 MP-SW-TS; w=500                          1.554247e-03
#                 MP-SW-TS; w=5000                         1.683568e-03
#                 MP-SW-UCB#-A; nu=0.1; l=12.3             2.537438e-04
#                 MP-SW-UCB#-A; nu=0.2; l=12.3             2.439914e-04
#                 MP-SW-UCB#-G; ka=0.1; l=4.3              5.487620e-04
#                 MP-SW-UCB#-G; ka=0.2; l=4.3              4.841244e-04
#                 MP-SW-UCB; w=100                         2.543331e-04
#                 MP-SW-UCB; w=1000                        2.932017e-04
#                 MP-SW-UCB; w=500                         2.758032e-04
#                 MP-SW-UCB; w=5000                        2.771226e-04
#                 MP-TS                                    1.609843e-03
#                 OD                                       6.697619e-01
#                 OR                                       1.550213e-03
#                 OS                                       2.134722e-01
#
#                                                            cputime
# scalingstrategy bandit
# No-1            MP-ADR-Elimination-UCB-ADWIN1; d=0.001    2.315733
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01     5.655673
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1      7.035512
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4   4.032860
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5   3.359879
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false        0.453414
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true         0.331320
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false         0.659477
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true          0.340804
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false          0.320132
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true           0.385500
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false       0.534993
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true        0.838174
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false       0.321565
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true        0.454741
#                 MP-D-TS; g=0.7                            1.931447
#                 MP-D-TS; g=0.8                            2.739335
#                 MP-D-TS; g=0.9                            2.156802
#                 MP-D-TS; g=0.99                           0.492416
#                 MP-D-UCB; g=0.7                           5.978399
#                 MP-D-UCB; g=0.8                           6.899179
#                 MP-D-UCB; g=0.9                           4.613767
#                 MP-D-UCB; g=0.99                          2.563525
#                 MP-E-G; e=0.7                             0.190712
#                 MP-E-G; e=0.8                             0.202072
#                 MP-E-G; e=0.9                             0.307802
#                 MP-E-G; e=0.99                            0.868685
#                 MP-GLR-KL-UCB-G                           9.916949
#                 MP-GLR-KL-UCB-G-F                        11.655272
#                 MP-GLR-KL-UCB-L                          10.722520
#                 MP-GLR-KL-UCB-L-F                         9.117547
#                 MP-KLUCB                                 21.473343
#                 MP-M-UCB; w=1000; m=10                    9.948402
#                 MP-M-UCB; w=1000; m=100                  12.108652
#                 MP-M-UCB; w=5000; m=10                   17.974649
#                 MP-M-UCB; w=5000; m=100                   9.359365
#                 MP-RExp3; b=100.0                         0.616556
#                 MP-RExp3; b=1000.0                        0.577214
#                 MP-RExp3; b=500.0                         0.474151
#                 MP-RExp3; b=5000.0                        0.461326
#                 MP-SW-TS; w=100                           0.712468
#                 MP-SW-TS; w=1000                          0.170943
#                 MP-SW-TS; w=500                           0.612842
#                 MP-SW-TS; w=5000                          0.365360
#                 MP-SW-UCB#-A; nu=0.1; l=12.3              3.692257
#                 MP-SW-UCB#-A; nu=0.2; l=12.3              3.327769
#                 MP-SW-UCB#-G; ka=0.1; l=4.3               1.462881
#                 MP-SW-UCB#-G; ka=0.2; l=4.3               2.231685
#                 MP-SW-UCB; w=100                          3.137930
#                 MP-SW-UCB; w=1000                         0.853956
#                 MP-SW-UCB; w=500                          2.237616
#                 MP-SW-UCB; w=5000                         0.503066
#                 MP-TS                                     0.264264
#                 OD                                        0.174816
#                 OR                                        0.153340
#                 OS                                        0.098199
# No-10           MP-ADR-Elimination-UCB-ADWIN1; d=0.001   14.438004
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    25.214214
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     12.711137
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  18.834578
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  17.604187
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       20.060641
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true         2.410634
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        17.795719
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true          2.436028
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false         11.862917
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true           5.358134
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false      11.770059
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       17.446786
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      18.070659
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true        8.964360
#                 MP-D-TS; g=0.7                           12.496074
#                 MP-D-TS; g=0.8                           26.224651
#                 MP-D-TS; g=0.9                           23.436968
#                 MP-D-TS; g=0.99                          14.717012
#                 MP-D-UCB; g=0.7                          18.490890
#                 MP-D-UCB; g=0.8                          41.097667
#                 MP-D-UCB; g=0.9                          41.636988
#                 MP-D-UCB; g=0.99                         37.522132
#                 MP-E-G; e=0.7                            11.037281
#                 MP-E-G; e=0.8                             6.214179
#                 MP-E-G; e=0.9                            12.737828
#                 MP-E-G; e=0.99                            8.834864
#                 MP-GLR-KL-UCB-G                          11.059867
#                 MP-GLR-KL-UCB-G-F                        20.701996
#                 MP-GLR-KL-UCB-L                          12.838103
#                 MP-GLR-KL-UCB-L-F                        14.854960
#                 MP-KLUCB                                  7.946660
#                 MP-M-UCB; w=1000; m=10                    9.460169
#                 MP-M-UCB; w=1000; m=100                   8.446296
#                 MP-M-UCB; w=5000; m=10                   13.019090
#                 MP-M-UCB; w=5000; m=100                  13.112382
#                 MP-RExp3; b=100.0                        36.722005
#                 MP-RExp3; b=1000.0                       22.858239
#                 MP-RExp3; b=500.0                        22.543860
#                 MP-RExp3; b=5000.0                       20.360357
#                 MP-SW-TS; w=100                          21.005215
#                 MP-SW-TS; w=1000                         18.408607
#                 MP-SW-TS; w=500                          21.653628
#                 MP-SW-TS; w=5000                         16.586069
#                 MP-SW-UCB#-A; nu=0.1; l=12.3             16.704906
#                 MP-SW-UCB#-A; nu=0.2; l=12.3             13.579087
#                 MP-SW-UCB#-G; ka=0.1; l=4.3              12.981753
#                 MP-SW-UCB#-G; ka=0.2; l=4.3              30.344419
#                 MP-SW-UCB; w=100                         17.843247
#                 MP-SW-UCB; w=1000                        19.469428
#                 MP-SW-UCB; w=500                         14.649944
#                 MP-SW-UCB; w=5000                        13.475117
#                 MP-TS                                    25.468301
#                 OD                                        0.176962
#                 OR                                        4.819732
#                 OS                                        2.032084
# No-2            MP-ADR-Elimination-UCB-ADWIN1; d=0.001    5.837971
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01     7.569447
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1      3.020967
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4   6.389751
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5   6.531610
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false        1.058214
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true         0.212470
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false         1.255604
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true          0.326311
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false          1.654096
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true           1.114381
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false       0.883861
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true        1.138973
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false       0.742709
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true        0.865417
#                 MP-D-TS; g=0.7                            9.410993
#                 MP-D-TS; g=0.8                            9.753080
#                 MP-D-TS; g=0.9                            9.266858
#                 MP-D-TS; g=0.99                           1.098415
#                 MP-D-UCB; g=0.7                          16.148409
#                 MP-D-UCB; g=0.8                          23.989660
#                 MP-D-UCB; g=0.9                          19.323264
#                 MP-D-UCB; g=0.99                         19.426348
#                 MP-E-G; e=0.7                             1.508530
#                 MP-E-G; e=0.8                             0.835928
#                 MP-E-G; e=0.9                             1.482981
#                 MP-E-G; e=0.99                            1.469898
#                 MP-GLR-KL-UCB-G                          14.265976
#                 MP-GLR-KL-UCB-G-F                        10.208067
#                 MP-GLR-KL-UCB-L                          11.016846
#                 MP-GLR-KL-UCB-L-F                         9.055217
#                 MP-KLUCB                                 28.725347
#                 MP-M-UCB; w=1000; m=10                   12.109201
#                 MP-M-UCB; w=1000; m=100                  10.285646
#                 MP-M-UCB; w=5000; m=10                   10.322214
#                 MP-M-UCB; w=5000; m=100                   8.361947
#                 MP-RExp3; b=100.0                         2.777827
#                 MP-RExp3; b=1000.0                        2.718202
#                 MP-RExp3; b=500.0                         3.149243
#                 MP-RExp3; b=5000.0                        1.759214
#                 MP-SW-TS; w=100                           3.680342
#                 MP-SW-TS; w=1000                          1.382162
#                 MP-SW-TS; w=500                           1.789016
#                 MP-SW-TS; w=5000                          1.128242
#                 MP-SW-UCB#-A; nu=0.1; l=12.3             10.815913
#                 MP-SW-UCB#-A; nu=0.2; l=12.3              5.722734
#                 MP-SW-UCB#-G; ka=0.1; l=4.3               3.605575
#                 MP-SW-UCB#-G; ka=0.2; l=4.3               4.078526
#                 MP-SW-UCB; w=100                          9.138482
#                 MP-SW-UCB; w=1000                         8.418558
#                 MP-SW-UCB; w=500                          8.049383
#                 MP-SW-UCB; w=5000                         4.711318
#                 MP-TS                                     0.672780
#                 OD                                        0.209600
#                 OR                                        0.458307
#                 OS                                        0.190884
# No-5            MP-ADR-Elimination-UCB-ADWIN1; d=0.001   16.595413
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.01    21.600397
#                 MP-ADR-Elimination-UCB-ADWIN1; d=0.1     18.817034
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-4  23.931995
#                 MP-ADR-Elimination-UCB-ADWIN1; d=1.0E-5  15.944335
#                 MP-ADS-TS-ADWIN1; d=0.001; r=false       13.543416
#                 MP-ADS-TS-ADWIN1; d=0.001; r=true         9.834398
#                 MP-ADS-TS-ADWIN1; d=0.01; r=false        17.256431
#                 MP-ADS-TS-ADWIN1; d=0.01; r=true         13.480196
#                 MP-ADS-TS-ADWIN1; d=0.1; r=false          9.969786
#                 MP-ADS-TS-ADWIN1; d=0.1; r=true           8.998238
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=false       9.139147
#                 MP-ADS-TS-ADWIN1; d=1.0E-4; r=true       15.715572
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=false      10.594015
#                 MP-ADS-TS-ADWIN1; d=1.0E-5; r=true       14.587435
#                 MP-D-TS; g=0.7                           17.209276
#                 MP-D-TS; g=0.8                           18.088777
#                 MP-D-TS; g=0.9                           13.949628
#                 MP-D-TS; g=0.99                          20.868921
#                 MP-D-UCB; g=0.7                          38.570459
#                 MP-D-UCB; g=0.8                          33.588450
#                 MP-D-UCB; g=0.9                          34.717889
#                 MP-D-UCB; g=0.99                         28.433846
#                 MP-E-G; e=0.7                             9.661067
#                 MP-E-G; e=0.8                             9.659510
#                 MP-E-G; e=0.9                            14.163022
#                 MP-E-G; e=0.99                           11.967953
#                 MP-GLR-KL-UCB-G                          29.539410
#                 MP-GLR-KL-UCB-G-F                        23.093489
#                 MP-GLR-KL-UCB-L                          28.733142
#                 MP-GLR-KL-UCB-L-F                        23.957579
#                 MP-KLUCB                                 20.944954
#                 MP-M-UCB; w=1000; m=10                   10.350739
#                 MP-M-UCB; w=1000; m=100                  10.138634
#                 MP-M-UCB; w=5000; m=10                   17.508232
#                 MP-M-UCB; w=5000; m=100                  16.798119
#                 MP-RExp3; b=100.0                        23.936901
#                 MP-RExp3; b=1000.0                       21.787972
#                 MP-RExp3; b=500.0                        29.865960
#                 MP-RExp3; b=5000.0                       23.346923
#                 MP-SW-TS; w=100                          15.695300
#                 MP-SW-TS; w=1000                         15.579654
#                 MP-SW-TS; w=500                          19.572507
#                 MP-SW-TS; w=5000                          9.431590
#                 MP-SW-UCB#-A; nu=0.1; l=12.3             13.071630
#                 MP-SW-UCB#-A; nu=0.2; l=12.3             10.632293
#                 MP-SW-UCB#-G; ka=0.1; l=4.3              10.275748
#                 MP-SW-UCB#-G; ka=0.2; l=4.3              17.699982
#                 MP-SW-UCB; w=100                         17.688579
#                 MP-SW-UCB; w=1000                        11.086178
#                 MP-SW-UCB; w=500                         15.555836
#                 MP-SW-UCB; w=5000                         9.422320
#                 MP-TS                                    20.226163
#                 OD                                        0.196894
#                 OR                                        4.034190
#                 OS                                        0.563452

# %%
from matplotlib.markers import TICKLEFT, TICKRIGHT, TICKUP, TICKDOWN, CARETLEFT, CARETRIGHT, CARETUP, CARETDOWN
markers = [
#    '.',
#    ',',
    'v',
    'o',
    '^',
    '<',
    '>',
#    '1',
#    '2',
#    '3',
#    '4',
#    '8',
    's',
    'p',
    '*',
#    'h',
    'H',
    '+',
    'x',
    'D',
#    'd',
    '|',
    '_',
    TICKLEFT,
    TICKRIGHT,
    TICKUP,
    TICKDOWN,
    CARETLEFT,
    CARETRIGHT,
    CARETUP,
    CARETDOWN,
]

# %%
algs_ours = [    
    # ours
    'MP-ADR-Elimination-UCB-ADWIN1; d=0.001',
    'MP-ADS-TS-ADWIN1; d=0.001; r=true',
#    'MP-ADS-TS-ADWIN1; d=0.001; r=false'
]
algs_pass = [
    # passive
    'MP-D-UCB; g=0.9',
    'MP-RExp3; b=1000.0',
    'MP-SW-TS; w=1000',
#    'MP-SW-UCB; w=1000',
    'MP-SW-UCB#-A; nu=0.1; l=12.3', 
    #'MP-SW-UCB#-A; nu=0.2; l=12.3', 
    'MP-SW-UCB#-G; ka=0.1; l=4.3', 
    #'MP-SW-UCB#-G; ka=0.2; l=4.3'
]
algs_act = [
    # active
    'MP-GLR-KL-UCB-G',
#    'MP-GLR-KL-UCB-L',
#    'MP-GLR-KL-UCB-G-F',
#    'MP-GLR-KL-UCB-L-F',
    'MP-M-UCB; w=1000; m=10',
#    'MP-M-UCB; w=5000; m=100',
]
algs_base = [
    # baselines
    'MP-TS',
    'MP-E-G; e=0.9',
    'OR',
    'OD',
    'OS',
    'CustomOracle'
]

# %%
prettynames = {
    'MP-ADR-Elimination-UCB-ADWIN1; d=0.001' : "ADR-E-UCB",
    'MP-ADS-TS-ADWIN1; d=0.001; r=true': "ADR-TS",
    'MP-ADS-TS-ADWIN1; d=0.001; r=false': "ADS-TS",
    'MP-D-UCB; g=0.9': "D-UCB",
    'MP-RExp3; b=1000.0': "RExp3",
    'MP-SW-TS; w=1000': "SW-TS",
    'MP-SW-UCB; w=1000': "SW-UCB",
    'MP-SW-UCB#-A; nu=0.1; l=12.3': "SW-UCB\#-A",
    'MP-SW-UCB#-G; ka=0.1; l=4.3': "SW-UCB\#-G",
    # active
    'MP-GLR-KL-UCB-G': 'GLR-KL-UCB',
    'MP-GLR-KL-UCB-L': 'GLR-KL-UCB-L',
    'MP-GLR-KL-UCB-G-F': 'GLR-KL-UCB-G-F',
    'MP-GLR-KL-UCB-L-F': 'GLR-KL-UCB-L-F',
    'MP-M-UCB; w=1000; m=10': 'M-UCB; w=1000; m=10',
#    'MP-M-UCB; w=5000; m=100': 'M-UCB; w=5000; m=100',
    'MP-M-UCB; w=1000; m=10': 'M-UCB',
    # baselines
    'MP-TS': 'MP-TS',
    'MP-E-G; e=0.9': 'Espilon-Greedy',
    'OR': "Random Oracle",
    'OD': "Dynamic Oracle",
    'OS': "Static Oracle",
    'CustomOracle': "Custom Oracle"
}

# %%
# compute regret against 'OD', or just the cumulative rewards

# %%
strategy = "No-1"

# %%
fig, axes = plt.subplots(2, 2, sharey=True, sharex=True, figsize=(14,10), constrained_layout=True)

L = 2

plt.sca(axes[0][0])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
for bandit in algs_ours + algs_pass:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)/L
    cumsum.plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                markevery=(i*50,400), marker=markers[i] , markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20) 
plt.legend(ncol=1)
plt.ylabel("$\sum_{i}^{K} X_i^T/L$")
plt.title("Ours vs. passive approaches ($L = %s$)"%L)

plt.sca(axes[1][0])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
for bandit in algs_ours + algs_act:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)/L
    cumsum.plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                markevery=(i*50,400), marker=markers[i] , markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20) 
plt.legend(ncol=1)
plt.ylabel("$\sum_{i}^{K} X_i^T/L$")
plt.title("Ours vs. active approaches ($L = %s$)"%L)
plt.xlabel("$T$")

L = 1

plt.sca(axes[0][1])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
for bandit in algs_ours + algs_pass:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)/L
    cumsum.plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                markevery=(i*50,400), marker=markers[i] , markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20) 
plt.legend(ncol=1)
plt.title("Ours vs. passive approaches ($L = %s$)"%L)

plt.sca(axes[1][1])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
for bandit in algs_ours + algs_act:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)/L
    cumsum.plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                markevery=(i*50,400), marker=markers[i] , markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20) 
plt.legend(ncol=1)
plt.xlabel("$T$")
plt.title("Ours vs. active approaches ($L = %s$)"%L)

plt.suptitle("Cumulative gain over time (Zozo bts)", fontsize=25)
plt.savefig("plots/Zozo_bts_gain_full.pdf")

# %%
fig, axes = plt.subplots(1, 2, sharey=True, sharex=True, figsize=(14,5), constrained_layout=True)

L = 1

plt.sca(axes[0])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
for bandit in algs_ours + algs_pass:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)/L
    cumsum.plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                markevery=(i*50,400), marker=markers[i] , markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20) 
plt.legend(ncol=1)
plt.xlabel("$T$")
plt.ylabel("$\sum_{i}^{K} X_i^T$")
plt.title("Ours vs. passive approaches")

plt.sca(axes[1])

i = 0
subdata = masterdata[masterdata["scalingstrategy"] == "No-%s"%L]
for bandit in algs_ours + algs_act:
    toplot = subdata[subdata["bandit"] == bandit]
    cumsum = toplot.gain.cumsum().reset_index(drop=True)/L
    cumsum.plot(label=prettynames[bandit],linewidth=1, alpha=0.7,
                markevery=(i*50,400), marker=markers[i] , markersize=10)
    i+=1

plt.xticks(fontsize=20)
plt.yticks(fontsize=20) 
plt.legend(ncol=1)
plt.xlabel("$T$")
plt.title("Ours vs. active approaches")

plt.suptitle("Cumulative gain over time (Zozo bts)", fontsize=25)
plt.savefig("plots/Zozo_bts_gain.pdf")
